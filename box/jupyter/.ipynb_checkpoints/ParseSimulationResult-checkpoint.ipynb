# %%
# %matplotlib notebook
import re
import sys
import inspect
from math import sqrt
import numpy as np
from scipy import integrate
from matplotlib import pyplot as plt
import matplotlib as mpl
from matplotlib import cm
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import cnames
from matplotlib import animation
#==================================
# This parse script won't parse sprayandwait yet, would cause mass
##################
# define handy func
def nums(s):
    try:
        return int(s)
    except ValueError:
        return float(s)
################
#====
# read the result file
simulation_result_file = open("../../box/dtn_simulation_result/dtnrunninglog.txt", "r")
lines = simulation_result_file.readlines();
simulation_result_file.close()
#====
x_is_one_delivery_route = False
x_simulation_time = -1
x_nodes = -1
x_sch_n = -1
x_arrive_n = 0
x_tosend_list = [] # element is also a list [source, time, destination, seqno] this is used to substitude x_schedule_list
x_schedule_list = [] # element is also a list[source, time, destination, seqno]
x_pkt_trace_map = {} # seqno -> [one_hop_snap, one_hop_snap... destination_snap]
# hop_snap , destination_snap = 
#[receive_time, receive_id, dest_id, source_id, seqno, src_generate_time, hop_transmit_time, pkt_type, is_dst, hop_id]
############
# define
def snap_print(snap) :
    print('''seqno :{0}, pkt-type={4}, receive at time-{1} at node-{2}, transmit at time-{3} at node-{5}'''
          .format(snap[4], snap[0], snap[1], snap[6], snap[7], snap[9]))
#############
test_string = r'Here In DtnExampleInterface::ReportExBundleTrace:node_number_=5;simulation_duration_=802'
r11 = re.compile(r'BundleTrace:node_number_=(\d+\.*\d*);simulation_duration_=(\d+\.*\d*)', re.VERBOSE)
test_regx = r11.search(test_string)
if test_regx :
    print("good0")
else :
    print("bad0")
    sys.exit()
    
strss = "[time-5.40052;node-1;line-638]NOTE:BundleTrace:good! one bun\
dle recept, it's one hop! bp_header=,destination ip=10.0.0.3,sour\
ce ip=10.0.0.1,source seqno=139,payload size=345,offset size=345,src time sta\
mp=5,hop time stamp=5,bundle type=BundlePacket"
r22 = re.compile(r'\[time-(\d+\.*\d*);node-(\d+\.*\d*);line-(\d+\.*\d*)\]NOTE:BundleTr\
ace:good!\sone\sbundle\srecept,\sit\'s\sone\shop!\sbp_header=,destination\sip=10.0.0.(\d+\.*\d*),sou\
rce\sip=10.0.0.(\d+\.*\d*),source\sseqno=(\d+\.*\d*),payload\ssize=(\d+\.*\d*),offset\ssi\
ze=(\d+\.*\d*),src\stime\sstamp=(\d+\.*\d*),hop\stime\sstamp=(\d+\.*\d*),bundle\stype=([a-zA-Z]+)', re.VERBOSE)
hopt = r22.match(strss)
if hopt :
    print("good1")
else :
    print("bad1")
    sys.exit()
    
#================================================ dividing parse ========================================
# parse for x_ nodes and x_ simualtion_time
# parse for bundle trace and schedule
avoid_log_twice_bug = False
for line in lines :
    #In DtnExampleRunner
    r0 = re.compile(r'In\sDtnExampleRunner', re.VERBOSE)
    parse_begin = r0.search(line)
    if parse_begin :
        avoid_log_twice_bug = True
        continue
    elif avoid_log_twice_bug :
        # do nothing
        onenomeaning = 1
    else :
        continue
    
    #BundleTrace:node_number_=5;simulation_duration_=802
    r1 = re.compile(r'BundleTrace:node_number_=(\d+\.*\d*);simulation_duration_=(\d+\.*\d*)', re.VERBOSE)
    simulation_preview = r1.search(line)
    
    #[time-5.40052;node-1;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.3,source ip=10.0.0.1,source seqno=139,payload size=345,offset size=345,src time stamp=5,hop time stamp=5,bundle type=BundlePacket
    r2 = re.compile(r'''\[time\-(\d+\.*\d*);node\-(\d+\.*\d*);line\-(\d+\.*\d*)\]NOTE:BundleTrace:go
    od!\sone\sbundle\srecept\,\sit\'s\sone\shop!\sbp_header=\,destination\sip=10\.0\.0\.(\d+\.*\d*)\,sour
    ce\sip=10\.0\.0\.(\d+\.*\d*)\,source\sseqno=(\d+\.*\d*)\,payload\ssize=(\d+\.*\d*)\,offset\ssiz
    e=(\d+\.*\d*)\,src\stime\sstamp=(\d+\.*\d*)\,hop\stime\ssta
    mp=(\d+\.*\d*)\,hop\sip=10\.0\.0\.(\d+\.*\d*)\,bundle\stype=([a-zA-Z]+)''', re.VERBOSE)
    hop = r2.search(line)
    
    #[time-3.30744;node-1;line-630]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.2,source ip=10.0.0.1,source seqno=75,payload size=345,offset size=345,src time stamp=3,hop time stamp=3,bundle type=BundlePacket
    r3 = re.compile(r'''\[time\-(\d+\.*\d*);node\-(\d+\.*\d*);line\-(\d+\.*\d*)\]NOTE:BundleTrace:Great!\son
    e\sbundle\sarrive\sdestination!\sbp_header=\,destination\sip=10\.0\.0\.(\d+\.*\d*)\,so
    urce\sip=10\.0\.0\.(\d+\.*\d*)\,source\sseqno=(\d+\.*\d*)\,payload\ssize=(\d+\.*\d*)\,offset\ss
    ize=(\d+\.*\d*)\,src\stime\sstamp=(\d+\.*\d*)\,hop\stime\ssta
    mp=(\d+\.*\d*)\,hop\sip=10\.0\.0\.(\d+\.*\d*)\,bundle\stype=([a-zA-Z]+)''', re.VERBOSE)
    destination = r3.search(line)
    
    #[time-0;node-0;line-1553]enter ScheduleTx(), time-+3000000000.0ns,size=345, to node-1
    r4 = re.compile(r'''node\-(\d+\.*\d*);line\-(\d+\.*\d*)]enter\sScheduleTx\(\)\,\sti
    me\-\+(\d+\.*\d*)ns\,size=(\d+\.*\d*)\,\sto\snode\-(\d+\.*\d*)''', re.VERBOSE)
    schedule = r4.search(line)
    
    #BundleTrace:Itisonedeliverymethon
    r5 = re.compile(r'''BundleTrace:Itisonedeliverymethon''', re.VERBOSE)
    isonedelivery = r5.search(line)
    
    #ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.4,source ip=10.0.0.3,source seqno=47,payload size=345,offset size=345,src time stamp=0.562494,hop time stamp=0.562494,hop ip=10.0.0.3,bundle type=BundlePacket
    r6 = re.compile(r'''ScheduleTx\,inToSendBundle\(\)\,bp_header=\,destination\sip=10\.0\.0\.(\d+\.*\d*)\,so
    urce\sip=10\.0\.0\.(\d+\.*\d*)\,source\sseqno=(\d+\.*\d*)\,payload\ssize=(\d+\.*\d*)\,offset\ss
    ize=(\d+\.*\d*)\,src\stime\sstamp=(\d+\.*\d*)\,hop\stime\ssta
    mp=(\d+\.*\d*)\,hop\sip=10\.0\.0\.(\d+\.*\d*)\,bundle\stype=([a-zA-Z]+)''', re.VERBOSE)
    tosendbundle = r6.search(line)
    
    if schedule :
        print(line)
        sche_source = int(nums(schedule.group(1)))
        sche_time = float(nums(schedule.group(3)) / 1000000000.0)
        sche_destination = int(nums(schedule.group(5)))
        tmp = [sche_source, sche_time, sche_destination, -1]
        x_schedule_list.append(tmp)
    elif tosendbundle :
        print(line)
        tosend_source = int(nums(tosendbundle.group(2)) - int(1))
        tosend_time = float(nums(tosendbundle.group(6)))
        tosend_destination = int(nums(tosendbundle.group(1)) - int(1))
        tosend_seqno = int(nums(tosendbundle.group(3)))
        tmp = [tosend_source, tosend_time, tosend_destination, tosend_seqno]
        x_tosend_list.append(tmp)
    elif isonedelivery :
        print(line)
        x_is_one_delivery_route = True
    elif hop :
        print(line)
        hop_receive_time = float(nums(hop.group(1)))
        hop_receive_id = int(nums(hop.group(2)))
        hop_dest_id = int(nums(hop.group(4)) - int(1))
        hop_source_id = int(nums(hop.group(5)) - int(1))
        hop_seqno = int(nums(hop.group(6)))
        hop_src_generate_time = float(nums(hop.group(9))) # TODO
        hop_hop_transmit_time = float(nums(hop.group(10)))
        hop_hop_id = int(nums(hop.group(11)) - int(1))
        hop_pkt_type = hop.group(12)
        if (hop_hop_transmit_time > hop_receive_time) :
            print('receive time:{0} should < hop_transmit time{1}'.format(hop_receive_time, hop_hop_transmit_time))
            sys.exit()
        tmp = [hop_receive_time, hop_receive_id, hop_dest_id, hop_source_id, hop_seqno,
               hop_src_generate_time, hop_hop_transmit_time, hop_pkt_type, False, hop_hop_id]
        if hop_seqno in x_pkt_trace_map.keys():
            old_list = x_pkt_trace_map[hop_seqno]
            old_list.append(tmp)
            old_list.sort(key=lambda tup: tup[0])
            x_pkt_trace_map[hop_seqno] = old_list
        else:
            new_list = []
            new_list.append(tmp)
            x_pkt_trace_map[hop_seqno] = new_list
    elif simulation_preview :
        print(line)
        x_nodes = int(simulation_preview.group(1))
        x_simulation_time = float(simulation_preview.group(2))
    elif destination :
        print(line)
        dst_receive_time = float(nums(destination.group(1)))
        dst_receive_id = int(nums(destination.group(2)))
        dst_dst_id = int(nums(destination.group(4)) - int(1))
        dst_src_id = int(nums(destination.group(5)) - int(1))
        dst_seqno = int(nums(destination.group(6)))
        dst_src_generate_time = float(nums(destination.group(9)))
        dst_hop_transmit_time = float(nums(destination.group(10)))
        dst_hop_id = int(nums(destination.group(11)) - int(1))
        dst_pkt_type = destination.group(12)
        if (dst_hop_transmit_time > dst_receive_time) :
            print('receive time')
            sys.exit()
        tmp = [dst_receive_time, dst_receive_id, dst_dst_id, dst_src_id, dst_seqno,
               dst_src_generate_time, dst_hop_transmit_time, dst_pkt_type, True, dst_hop_id]
        if dst_seqno in x_pkt_trace_map.keys() :
            old_list = x_pkt_trace_map[dst_seqno]
            old_list.append(tmp)
            old_list.sort(key=lambda tup: tup[0])
            x_pkt_trace_map[dst_seqno] = old_list
        else :
            new_list = []
            new_list.append(tmp)
            x_pkt_trace_map[dst_seqno] = new_list
            
#========================================= end of parse ===================================================

print(r'============= dividing end of parse =============')
if (x_nodes == -1) or (x_simulation_time == -1) :
    print('error_04')
    sys.exit()
#================ now we have every thing we need, refine the data and prepare for visualization
#===== refine x_schedule_list
for sch in x_schedule_list :
    sk = [sch[0], sch[1], sch[2]] # s, t, d
    sn = sch[3]
    if sn != -1 :
        print('error_03')
        sys.exit()
    for key, value in x_pkt_trace_map.items() : #
        #print('value len={0}'.format(len(value)))
        #print(value)
        tk = [value[0][3], value[0][5], value[0][2]]
        seqno = value[0][4]
        if (tk[0] == sk[0] and tk[2] == sk[2] and tk[1] - sk[1] < 0.1) :
            sn = seqno
            break
    if (sn != -1) :
        sch[3] = sn
    else :
        print('warn_05:this may happen when one pkt scheduled but not successfully hoped')

print('============= \n === print your schedule')
print(x_schedule_list)
print('============= \n === print your tosendbundle')
print(x_tosend_list)
#===================================== get graph needed list
#
#                                                                                    dstination
x_time_trace_map = {} # seqno -> [src_t, sr_id, hop_t, rec_t, rec_id, hop_t, ... , rec_t, rec_id, x_simulation_time]
x_sch_n = len(x_tosend_list)
print('==============\n print your x_pkt_trace_map')
print(x_pkt_trace_map)
####################
#definition
def get_x_time_trace_map(p_x_time_trace_map, p_x_tosend_list, p_x_pkt_trace_map, ref_x_arrive_n) :
    ref_x_arrive_n = 0
    if x_is_one_delivery_route :
        for sch in p_x_tosend_list :
            src_t = sch[1]
            seqno = sch[3]
            if seqno == -1 :
                print('error_01')
                sys.exit()
            sr_id = sch[0]
            tmp = []
            tmp.extend([src_t, sr_id])
            if seqno in p_x_pkt_trace_map :
                print('key exist')
                for trace in p_x_pkt_trace_map[seqno] :
                    if trace[4] != seqno :
                        print('error_02')
                        sys.exit()
                    is_dst = bool(trace[8])
                    hop_t = trace[6]
                    rec_t = trace[0]
                    rec_id = trace[1]
                    tmp.extend([hop_t, rec_t, rec_id])
                    if is_dst :
                        tmp.append(x_simulation_time)
                if len(tmp) % 3 == 0 :
                    ref_x_arrive_n += 1
                    p_x_time_trace_map[seqno] = tmp 
                else :
                    print('there is one pkt don\'t arrive destination')
                    p_x_time_trace_map[seqno] = tmp
            else :
                print('key not exist-{0}'.format(seqno))
                p_x_time_trace_map[seqno] = tmp
    else :
        print('if not one delivery route, this would cause one seqno -> multiply path, it\'s hard to parse, would\
        do this latter')
        print('============ print all hop snap and end ==============')
        for key, snaps in p_x_pkt_trace_map.items() :
            for snap in snaps :
                snap_print(snap)
        print('normal exit')
        sys.exit()
    return ref_x_arrive_n
#end of definition
#################################
x_arrive_n = get_x_time_trace_map(x_time_trace_map, x_tosend_list, x_pkt_trace_map, x_arrive_n)
#===== gonna to make graph|
print('===================================================================================================\
\n===================== report parse result ================')
title_str = '{0} / {1} arrived'.format(x_arrive_n, x_sch_n)
#print(x_time_trace_map)
print(title_str)
###############
# define
def handy_print_2(seqno) :
    for xs in x_tosend_list :
        if xs[3] == seqno :
            print('schedule is: from node-{0} to node-{1} at time-{2}'.format(xs[0], xs[2], xs[1]))
            break
def handy_print_0(st, et, nid) :
    print('from time-{0} => time-{1} in node-{2}'.format(st, et, nid))
def handy_print_1(key, value) :
    print('==================\npkt-seqno:{0}, trace is: '.format(key))
    n_v = int(len(value) / 3)
    is_arrived_traffic = False
    if (n_v * 3 == len(value)) :
        is_arrived_traffic = True
    if (is_arrived_traffic) :
        for cur in range(0, n_v, 1) :
            if cur == n_v - 1 :
                print('received by node-{1} at time-{0} destination :)'.format(value[cur * 3], value[cur * 3 + 1]))
            else :
                handy_print_0(value[cur * 3], value[cur * 3 + 2], value[cur * 3 + 1])
        print('arrived destination\n')
    else :
        for cur in range(0, n_v + 1, 1) :
            if cur == n_v :
                print('received by node-{1} at time-{0}, not destination :('.format(value[cur * 3], value[cur * 3 + 1]))
                if cur == 0 :
                    print('this bundle may not be transmit out from source')
            else :
                handy_print_0(value[cur * 3], value[cur * 3 + 2], value[cur * 3 + 1])
        print('not arrived destination\n')
    handy_print_2(key)
def handy_draw_0(ax0, st, et, nid, seqnoindex, c) :
    dx = et - st
    ax0.bar3d(st, seqnoindex, nid, dx + 1.0, 0.2, 0.2, alpha=0.1, color=c, linewidth=0) # alpha = abs(dz[i]/max(dz))
###################################

for key, value in x_time_trace_map.items() :
    handy_print_1(key, value)
print(x_time_trace_map)
#===============
fig = plt.figure()
ax = fig.gca(projection='3d')
colors = plt.cm.jet(np.linspace(0, 1, len(x_tosend_list)))
seqno_number_list = []
for xsele in x_tosend_list :
    seqno_number_list.append(xsele[3])

#=======    
print('colors count={0}'.format(len(colors)))
print('len of seqno_number_list={0}'.format(len(seqno_number_list)))
print(range(0, len(seqno_number_list), 1))

for c, zseqnoindex in zip(colors, range(0, len(seqno_number_list), 1)):
    this_seqno_no = seqno_number_list[zseqnoindex]
    trace_list_of_seqno = x_time_trace_map[this_seqno_no]
    rt_count = int(len(trace_list_of_seqno) / 3)
    is_arrived_traffic_0 = False
    if (rt_count * 3 == len(trace_list_of_seqno)) :
        is_arrived_traffic_0 = True
        
    if is_arrived_traffic_0 :
        for cur in range(0, rt_count, 1) :
            if cur == rt_count - 1 :
                handy_draw_0(ax, trace_list_of_seqno[cur * 3], trace_list_of_seqno[cur * 3 + 2], \
                             trace_list_of_seqno[cur * 3 + 1], zseqnoindex, c)
                ax.text(x_simulation_time, zseqnoindex, 0\
                        , 'arrived! seqno={0}'.format(seqno_number_list[zseqnoindex]), 'x')
            else :
                handy_draw_0(ax, trace_list_of_seqno[cur * 3], trace_list_of_seqno[cur * 3 + 2], \
                             trace_list_of_seqno[cur * 3 + 1], zseqnoindex, c)
    else :
        for cur in range(0, rt_count + 1, 1) :
            if cur == rt_count :
                handy_draw_0(ax, trace_list_of_seqno[cur * 3], trace_list_of_seqno[cur * 3] + 1, \
                             trace_list_of_seqno[cur * 3 + 1], zseqnoindex, c)
                ax.text(x_simulation_time, zseqnoindex, 0\
                        , 'missed! seqno={0}'.format(seqno_number_list[zseqnoindex]), 'x')
            else :
                handy_draw_0(ax, trace_list_of_seqno[cur * 3], trace_list_of_seqno[cur * 3 + 2], \
                             trace_list_of_seqno[cur * 3 + 1], zseqnoindex, c)
#======
ax.set_xlabel('time')
#ax.set_ylabel('')
ax.set_zlabel('node')
plt.show()
#==================
# Out:
# good0
# good1
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# Here In DtnExampleInterface::ReportExBundleTrace:node_number_=20;simulation_duration_=802
#
# [time-0;node-0;line-1598]enter ScheduleTx(), time-+33518322644.0ns,size=345, to node-17
#
# [time-0;node-0;line-1598]enter ScheduleTx(), time-+53355341622.0ns,size=345, to node-15
#
# [time-0;node-1;line-1598]enter ScheduleTx(), time-+6646831232.0ns,size=345, to node-12
#
# [time-0;node-1;line-1598]enter ScheduleTx(), time-+24282345216.0ns,size=345, to node-19
#
# [time-0;node-2;line-1598]enter ScheduleTx(), time-+39598923197.0ns,size=345, to node-18
#
# [time-0;node-2;line-1598]enter ScheduleTx(), time-+27949926239.0ns,size=345, to node-12
#
# [time-0;node-3;line-1598]enter ScheduleTx(), time-+25180109747.0ns,size=345, to node-1
#
# [time-0;node-3;line-1598]enter ScheduleTx(), time-+40138362624.0ns,size=345, to node-11
#
# [time-0;node-4;line-1598]enter ScheduleTx(), time-+31826200912.0ns,size=345, to node-6
#
# [time-0;node-4;line-1598]enter ScheduleTx(), time-+35170986309.0ns,size=345, to node-8
#
# [time-0;node-5;line-1598]enter ScheduleTx(), time-+27096472304.0ns,size=345, to node-4
#
# [time-0;node-5;line-1598]enter ScheduleTx(), time-+32892907076.0ns,size=345, to node-17
#
# [time-0;node-6;line-1598]enter ScheduleTx(), time-+23842863354.0ns,size=345, to node-10
#
# [time-0;node-6;line-1598]enter ScheduleTx(), time-+56043573594.0ns,size=345, to node-11
#
# [time-0;node-7;line-1598]enter ScheduleTx(), time-+3930887874.0ns,size=345, to node-9
#
# [time-0;node-7;line-1598]enter ScheduleTx(), time-+47017271831.0ns,size=345, to node-15
#
# [time-0;node-8;line-1598]enter ScheduleTx(), time-+36040635763.0ns,size=345, to node-6
#
# [time-0;node-8;line-1598]enter ScheduleTx(), time-+57564998533.0ns,size=345, to node-1
#
# [time-0;node-9;line-1598]enter ScheduleTx(), time-+27230799567.0ns,size=345, to node-16
#
# [time-0;node-9;line-1598]enter ScheduleTx(), time-+44367384108.0ns,size=345, to node-18
#
# [time-0;node-10;line-1598]enter ScheduleTx(), time-+37695146974.0ns,size=345, to node-7
#
# [time-0;node-10;line-1598]enter ScheduleTx(), time-+20115547990.0ns,size=345, to node-4
#
# [time-0;node-11;line-1598]enter ScheduleTx(), time-+18857727739.0ns,size=345, to node-9
#
# [time-0;node-11;line-1598]enter ScheduleTx(), time-+54680461943.0ns,size=345, to node-6
#
# [time-0;node-12;line-1598]enter ScheduleTx(), time-+14292817724.0ns,size=345, to node-2
#
# [time-0;node-12;line-1598]enter ScheduleTx(), time-+48666164228.0ns,size=345, to node-7
#
# [time-0;node-13;line-1598]enter ScheduleTx(), time-+29347602310.0ns,size=345, to node-4
#
# [time-0;node-13;line-1598]enter ScheduleTx(), time-+39835901514.0ns,size=345, to node-4
#
# [time-0;node-14;line-1598]enter ScheduleTx(), time-+27671870941.0ns,size=345, to node-5
#
# [time-0;node-14;line-1598]enter ScheduleTx(), time-+34273139318.0ns,size=345, to node-5
#
# [time-0;node-15;line-1598]enter ScheduleTx(), time-+29371539029.0ns,size=345, to node-0
#
# [time-0;node-15;line-1598]enter ScheduleTx(), time-+22432397460.0ns,size=345, to node-12
#
# [time-0;node-16;line-1598]enter ScheduleTx(), time-+29680338405.0ns,size=345, to node-3
#
# [time-0;node-16;line-1598]enter ScheduleTx(), time-+28848425077.0ns,size=345, to node-6
#
# [time-0;node-17;line-1598]enter ScheduleTx(), time-+17894444142.0ns,size=345, to node-6
#
# [time-0;node-17;line-1598]enter ScheduleTx(), time-+51274135926.0ns,size=345, to node-0
#
# [time-0;node-18;line-1598]enter ScheduleTx(), time-+13717146480.0ns,size=345, to node-13
#
# [time-0;node-18;line-1598]enter ScheduleTx(), time-+44827339525.0ns,size=345, to node-8
#
# [time-0;node-19;line-1598]enter ScheduleTx(), time-+17670651619.0ns,size=345, to node-1
#
# [time-0;node-19;line-1598]enter ScheduleTx(), time-+57554921367.0ns,size=345, to node-13
#
# [time-3.93089;node-7;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.10,source ip=10.0.0.8,source seqno=384,payload size=345,offset size=345,src time stamp=3.93,hop time stamp=3.93,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-4.5153;node-9;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.10,source ip=10.0.0.8,source seqno=384,payload size=345,offset size=345,src time stamp=3.93,hop time stamp=4.499,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-6.64683;node-1;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.13,source ip=10.0.0.2,source seqno=669,payload size=345,offset size=345,src time stamp=6.646,hop time stamp=6.646,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-6.91402;node-3;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.13,source ip=10.0.0.2,source seqno=669,payload size=345,offset size=345,src time stamp=6.646,hop time stamp=6.899,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-13.7171;node-18;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.14,source ip=10.0.0.19,source seqno=1386,payload size=345,offset size=345,src time stamp=13.717,hop time stamp=13.717,hop ip=10.0.0.19,bundle type=BundlePacket
#
# [time-14.1143;node-15;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.14,source ip=10.0.0.19,source seqno=1386,payload size=345,offset size=345,src time stamp=13.717,hop time stamp=14.099,hop ip=10.0.0.19,bundle type=BundlePacket
#
# [time-14.2928;node-12;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.3,source ip=10.0.0.13,source seqno=1454,payload size=345,offset size=345,src time stamp=14.292,hop time stamp=14.292,hop ip=10.0.0.13,bundle type=BundlePacket
#
# [time-14.7122;node-11;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.3,source ip=10.0.0.13,source seqno=1454,payload size=345,offset size=345,src time stamp=14.292,hop time stamp=14.699,hop ip=10.0.0.13,bundle type=BundlePacket
#
# [time-17.6707;node-19;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.2,source ip=10.0.0.20,source seqno=1802,payload size=345,offset size=345,src time stamp=17.67,hop time stamp=17.67,hop ip=10.0.0.20,bundle type=BundlePacket
#
# [time-17.8944;node-17;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.7,source ip=10.0.0.18,source seqno=1825,payload size=345,offset size=345,src time stamp=17.894,hop time stamp=17.894,hop ip=10.0.0.18,bundle type=BundlePacket
#
# [time-18.3095;node-15;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.18,source seqno=1825,payload size=345,offset size=345,src time stamp=17.894,hop time stamp=18.299,hop ip=10.0.0.18,bundle type=BundlePacket
#
# [time-18.317;node-15;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.2,source ip=10.0.0.20,source seqno=1802,payload size=345,offset size=345,src time stamp=17.67,hop time stamp=18.299,hop ip=10.0.0.20,bundle type=BundlePacket
#
# [time-18.8577;node-11;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.10,source ip=10.0.0.12,source seqno=1940,payload size=345,offset size=345,src time stamp=18.857,hop time stamp=18.857,hop ip=10.0.0.12,bundle type=BundlePacket
#
# [time-20.1155;node-10;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.5,source ip=10.0.0.11,source seqno=2067,payload size=345,offset size=345,src time stamp=20.115,hop time stamp=20.115,hop ip=10.0.0.11,bundle type=BundlePacket
#
# [time-20.713;node-11;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.5,source ip=10.0.0.11,source seqno=2067,payload size=345,offset size=345,src time stamp=20.115,hop time stamp=20.699,hop ip=10.0.0.11,bundle type=BundlePacket
#
# [time-22.4324;node-15;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.13,source ip=10.0.0.16,source seqno=2309,payload size=345,offset size=345,src time stamp=22.432,hop time stamp=22.432,hop ip=10.0.0.16,bundle type=BundlePacket
#
# [time-23.8429;node-6;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.11,source ip=10.0.0.7,source seqno=2451,payload size=345,offset size=345,src time stamp=23.842,hop time stamp=23.842,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-24.2823;node-1;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.20,source ip=10.0.0.2,source seqno=2496,payload size=345,offset size=345,src time stamp=24.282,hop time stamp=24.282,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-24.3082;node-5;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.11,source ip=10.0.0.7,source seqno=2451,payload size=345,offset size=345,src time stamp=23.842,hop time stamp=24.299,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-24.609;node-5;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.20,source ip=10.0.0.2,source seqno=2496,payload size=345,offset size=345,src time stamp=24.282,hop time stamp=24.599,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-24.9019;node-1;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.11,source ip=10.0.0.7,source seqno=2451,payload size=345,offset size=345,src time stamp=23.842,hop time stamp=24.899,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-25.1801;node-3;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.2,source ip=10.0.0.4,source seqno=2608,payload size=345,offset size=345,src time stamp=25.18,hop time stamp=25.18,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-25.2133;node-7;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.20,source ip=10.0.0.2,source seqno=2496,payload size=345,offset size=345,src time stamp=24.282,hop time stamp=25.199,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-25.5021;node-3;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.11,source ip=10.0.0.7,source seqno=2451,payload size=345,offset size=345,src time stamp=23.842,hop time stamp=25.499,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-25.5036;node-1;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.2,source ip=10.0.0.4,source seqno=2608,payload size=345,offset size=345,src time stamp=25.18,hop time stamp=25.499,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-27.009;node-11;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.11,source ip=10.0.0.7,source seqno=2451,payload size=345,offset size=345,src time stamp=23.842,hop time stamp=26.999,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-27.0146;node-15;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.20,source ip=10.0.0.2,source seqno=2496,payload size=345,offset size=345,src time stamp=24.282,hop time stamp=26.999,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-27.0965;node-5;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.5,source ip=10.0.0.6,source seqno=2848,payload size=345,offset size=345,src time stamp=27.096,hop time stamp=27.096,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-27.2308;node-9;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.17,source ip=10.0.0.10,source seqno=2863,payload size=345,offset size=345,src time stamp=27.23,hop time stamp=27.23,hop ip=10.0.0.10,bundle type=BundlePacket
#
# [time-27.3005;node-7;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.14,source ip=10.0.0.19,source seqno=1386,payload size=345,offset size=345,src time stamp=13.717,hop time stamp=27.299,hop ip=10.0.0.16,bundle type=BundlePacket
#
# [time-27.3018;node-3;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.3,source ip=10.0.0.13,source seqno=1454,payload size=345,offset size=345,src time stamp=14.292,hop time stamp=27.299,hop ip=10.0.0.12,bundle type=BundlePacket
#
# [time-27.3026;node-11;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.13,source ip=10.0.0.2,source seqno=669,payload size=345,offset size=345,src time stamp=6.646,hop time stamp=27.299,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-27.3145;node-4;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.5,source ip=10.0.0.6,source seqno=2848,payload size=345,offset size=345,src time stamp=27.096,hop time stamp=27.299,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-27.602;node-7;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.18,source seqno=1825,payload size=345,offset size=345,src time stamp=17.894,hop time stamp=27.599,hop ip=10.0.0.16,bundle type=BundlePacket
#
# [time-27.6029;node-3;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.10,source ip=10.0.0.12,source seqno=1940,payload size=345,offset size=345,src time stamp=18.857,hop time stamp=27.599,hop ip=10.0.0.12,bundle type=BundlePacket
#
# [time-27.6171;node-2;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.3,source ip=10.0.0.13,source seqno=1454,payload size=345,offset size=345,src time stamp=14.292,hop time stamp=27.599,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-27.6719;node-14;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.6,source ip=10.0.0.15,source seqno=2946,payload size=345,offset size=345,src time stamp=27.671,hop time stamp=27.671,hop ip=10.0.0.15,bundle type=BundlePacket
#
# [time-27.9017;node-7;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.17,source ip=10.0.0.10,source seqno=2863,payload size=345,offset size=345,src time stamp=27.23,hop time stamp=27.899,hop ip=10.0.0.10,bundle type=BundlePacket
#
# [time-27.9026;node-7;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.2,source ip=10.0.0.20,source seqno=1802,payload size=345,offset size=345,src time stamp=17.67,hop time stamp=27.899,hop ip=10.0.0.16,bundle type=BundlePacket
#
# [time-27.9035;node-5;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.14,source ip=10.0.0.19,source seqno=1386,payload size=345,offset size=345,src time stamp=13.717,hop time stamp=27.899,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-27.9035;node-3;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.5,source ip=10.0.0.11,source seqno=2067,payload size=345,offset size=345,src time stamp=20.115,hop time stamp=27.899,hop ip=10.0.0.12,bundle type=BundlePacket
#
# [time-27.9086;node-1;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.10,source ip=10.0.0.12,source seqno=1940,payload size=345,offset size=345,src time stamp=18.857,hop time stamp=27.899,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-27.9499;node-2;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.13,source ip=10.0.0.3,source seqno=2990,payload size=345,offset size=345,src time stamp=27.949,hop time stamp=27.949,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-28.2034;node-10;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.11,source ip=10.0.0.7,source seqno=2451,payload size=345,offset size=345,src time stamp=23.842,hop time stamp=28.199,hop ip=10.0.0.12,bundle type=BundlePacket
#
# [time-28.2049;node-7;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.13,source ip=10.0.0.16,source seqno=2309,payload size=345,offset size=345,src time stamp=22.432,hop time stamp=28.199,hop ip=10.0.0.16,bundle type=BundlePacket
#
# [time-28.2078;node-9;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.10,source ip=10.0.0.12,source seqno=1940,payload size=345,offset size=345,src time stamp=18.857,hop time stamp=28.199,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-28.2088;node-1;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.14,source ip=10.0.0.19,source seqno=1386,payload size=345,offset size=345,src time stamp=13.717,hop time stamp=28.199,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-28.2167;node-6;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.18,source seqno=1825,payload size=345,offset size=345,src time stamp=17.894,hop time stamp=28.199,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-28.5005;node-19;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.20,source ip=10.0.0.2,source seqno=2496,payload size=345,offset size=345,src time stamp=24.282,hop time stamp=28.499,hop ip=10.0.0.16,bundle type=BundlePacket
#
# [time-28.5033;node-12;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.13,source ip=10.0.0.2,source seqno=669,payload size=345,offset size=345,src time stamp=6.646,hop time stamp=28.499,hop ip=10.0.0.12,bundle type=BundlePacket
#
# [time-28.5036;node-15;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.17,source ip=10.0.0.10,source seqno=2863,payload size=345,offset size=345,src time stamp=27.23,hop time stamp=28.499,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-28.5076;node-3;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.14,source ip=10.0.0.19,source seqno=1386,payload size=345,offset size=345,src time stamp=13.717,hop time stamp=28.499,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-28.5087;node-3;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.13,source ip=10.0.0.3,source seqno=2990,payload size=345,offset size=345,src time stamp=27.949,hop time stamp=28.499,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-28.8005;node-5;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.13,source ip=10.0.0.16,source seqno=2309,payload size=345,offset size=345,src time stamp=22.432,hop time stamp=28.799,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-28.8115;node-16;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.17,source ip=10.0.0.10,source seqno=2863,payload size=345,offset size=345,src time stamp=27.23,hop time stamp=28.799,hop ip=10.0.0.16,bundle type=BundlePacket
#
# [time-28.8484;node-16;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.7,source ip=10.0.0.17,source seqno=3157,payload size=345,offset size=345,src time stamp=28.848,hop time stamp=28.848,hop ip=10.0.0.17,bundle type=BundlePacket
#
# [time-28.9061;node-11;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.15,source seqno=2946,payload size=345,offset size=345,src time stamp=27.671,hop time stamp=27.899,hop ip=10.0.0.15,bundle type=BundlePacket
#
# [time-29.102;node-5;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.2,source ip=10.0.0.20,source seqno=1802,payload size=345,offset size=345,src time stamp=17.67,hop time stamp=29.099,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-29.1039;node-11;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.14,source ip=10.0.0.19,source seqno=1386,payload size=345,offset size=345,src time stamp=13.717,hop time stamp=29.099,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-29.1051;node-15;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.17,source seqno=3157,payload size=345,offset size=345,src time stamp=28.848,hop time stamp=29.099,hop ip=10.0.0.17,bundle type=BundlePacket
#
# [time-29.113;node-1;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.13,source ip=10.0.0.16,source seqno=2309,payload size=345,offset size=345,src time stamp=22.432,hop time stamp=29.099,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-29.2062;node-4;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.5,source ip=10.0.0.11,source seqno=2067,payload size=345,offset size=345,src time stamp=20.115,hop time stamp=28.199,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-29.3476;node-13;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.5,source ip=10.0.0.14,source seqno=3251,payload size=345,offset size=345,src time stamp=29.347,hop time stamp=29.347,hop ip=10.0.0.14,bundle type=BundlePacket
#
# [time-29.3715;node-15;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.1,source ip=10.0.0.16,source seqno=3255,payload size=345,offset size=345,src time stamp=29.371,hop time stamp=29.371,hop ip=10.0.0.16,bundle type=BundlePacket
#
# [time-29.4019;node-3;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.13,source ip=10.0.0.16,source seqno=2309,payload size=345,offset size=345,src time stamp=22.432,hop time stamp=29.399,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-29.403;node-3;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.15,source seqno=2946,payload size=345,offset size=345,src time stamp=27.671,hop time stamp=29.399,hop ip=10.0.0.12,bundle type=BundlePacket
#
# [time-29.404;node-11;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.13,source ip=10.0.0.3,source seqno=2990,payload size=345,offset size=345,src time stamp=27.949,hop time stamp=29.399,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-29.4106;node-1;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.2,source ip=10.0.0.20,source seqno=1802,payload size=345,offset size=345,src time stamp=17.67,hop time stamp=29.399,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-29.6803;node-16;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.4,source ip=10.0.0.17,source seqno=3303,payload size=345,offset size=345,src time stamp=29.68,hop time stamp=29.68,hop ip=10.0.0.17,bundle type=BundlePacket
#
# [time-29.7005;node-11;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.13,source ip=10.0.0.16,source seqno=2309,payload size=345,offset size=345,src time stamp=22.432,hop time stamp=29.699,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-29.7036;node-7;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.17,source seqno=3157,payload size=345,offset size=345,src time stamp=28.848,hop time stamp=29.699,hop ip=10.0.0.16,bundle type=BundlePacket
#
# [time-29.7104;node-13;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.14,source ip=10.0.0.19,source seqno=1386,payload size=345,offset size=345,src time stamp=13.717,hop time stamp=29.699,hop ip=10.0.0.12,bundle type=BundlePacket
#
# [time-29.7135;node-11;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.5,source ip=10.0.0.14,source seqno=3251,payload size=345,offset size=345,src time stamp=29.347,hop time stamp=29.699,hop ip=10.0.0.14,bundle type=BundlePacket
#
# [time-30.0005;node-6;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.17,source seqno=3157,payload size=345,offset size=345,src time stamp=28.848,hop time stamp=29.999,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-30.0027;node-12;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.13,source ip=10.0.0.3,source seqno=2990,payload size=345,offset size=345,src time stamp=27.949,hop time stamp=29.999,hop ip=10.0.0.12,bundle type=BundlePacket
#
# [time-30.0044;node-15;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.4,source ip=10.0.0.17,source seqno=3303,payload size=345,offset size=345,src time stamp=29.68,hop time stamp=29.999,hop ip=10.0.0.17,bundle type=BundlePacket
#
# [time-30.0046;node-1;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.15,source seqno=2946,payload size=345,offset size=345,src time stamp=27.671,hop time stamp=29.999,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-30.0074;node-7;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.1,source ip=10.0.0.16,source seqno=3255,payload size=345,offset size=345,src time stamp=29.371,hop time stamp=29.999,hop ip=10.0.0.16,bundle type=BundlePacket
#
# [time-30.3018;node-12;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.13,source ip=10.0.0.16,source seqno=2309,payload size=345,offset size=345,src time stamp=22.432,hop time stamp=30.299,hop ip=10.0.0.12,bundle type=BundlePacket
#
# [time-30.3029;node-7;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.4,source ip=10.0.0.17,source seqno=3303,payload size=345,offset size=345,src time stamp=29.68,hop time stamp=30.299,hop ip=10.0.0.16,bundle type=BundlePacket
#
# [time-30.3041;node-5;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.1,source ip=10.0.0.16,source seqno=3255,payload size=345,offset size=345,src time stamp=29.371,hop time stamp=30.299,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-30.3087;node-5;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.15,source seqno=2946,payload size=345,offset size=345,src time stamp=27.671,hop time stamp=30.299,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-30.6029;node-3;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.5,source ip=10.0.0.14,source seqno=3251,payload size=345,offset size=345,src time stamp=29.347,hop time stamp=30.599,hop ip=10.0.0.12,bundle type=BundlePacket
#
# [time-30.6046;node-5;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.4,source ip=10.0.0.17,source seqno=3303,payload size=345,offset size=345,src time stamp=29.68,hop time stamp=30.599,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-30.9023;node-4;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.5,source ip=10.0.0.14,source seqno=3251,payload size=345,offset size=345,src time stamp=29.347,hop time stamp=30.899,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-30.906;node-1;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.1,source ip=10.0.0.16,source seqno=3255,payload size=345,offset size=345,src time stamp=29.371,hop time stamp=30.899,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-31.2005;node-1;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.4,source ip=10.0.0.17,source seqno=3303,payload size=345,offset size=345,src time stamp=29.68,hop time stamp=31.199,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-31.2085;node-0;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.1,source ip=10.0.0.16,source seqno=3255,payload size=345,offset size=345,src time stamp=29.371,hop time stamp=31.199,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-31.5019;node-3;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.4,source ip=10.0.0.17,source seqno=3303,payload size=345,offset size=345,src time stamp=29.68,hop time stamp=31.499,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-31.8262;node-4;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.7,source ip=10.0.0.5,source seqno=3702,payload size=345,offset size=345,src time stamp=31.826,hop time stamp=31.826,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-32.1337;node-1;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.5,source seqno=3702,payload size=345,offset size=345,src time stamp=31.826,hop time stamp=32.099,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-32.8929;node-5;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.18,source ip=10.0.0.6,source seqno=3848,payload size=345,offset size=345,src time stamp=32.892,hop time stamp=32.892,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-33.3005;node-7;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.18,source ip=10.0.0.6,source seqno=3848,payload size=345,offset size=345,src time stamp=32.892,hop time stamp=33.299,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-33.5183;node-0;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.18,source ip=10.0.0.1,source seqno=3927,payload size=345,offset size=345,src time stamp=33.518,hop time stamp=33.518,hop ip=10.0.0.1,bundle type=BundlePacket
#
# [time-33.9005;node-15;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.18,source ip=10.0.0.6,source seqno=3848,payload size=345,offset size=345,src time stamp=32.892,hop time stamp=33.899,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-33.9005;node-1;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.18,source ip=10.0.0.1,source seqno=3927,payload size=345,offset size=345,src time stamp=33.518,hop time stamp=33.899,hop ip=10.0.0.1,bundle type=BundlePacket
#
# [time-34.2005;node-17;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.18,source ip=10.0.0.6,source seqno=3848,payload size=345,offset size=345,src time stamp=32.892,hop time stamp=34.199,hop ip=10.0.0.16,bundle type=BundlePacket
#
# [time-34.2731;node-14;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.6,source ip=10.0.0.15,source seqno=4016,payload size=345,offset size=345,src time stamp=34.273,hop time stamp=34.273,hop ip=10.0.0.15,bundle type=BundlePacket
#
# [time-34.8026;node-3;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.15,source seqno=4016,payload size=345,offset size=345,src time stamp=34.273,hop time stamp=34.799,hop ip=10.0.0.15,bundle type=BundlePacket
#
# [time-35.171;node-4;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.9,source ip=10.0.0.5,source seqno=4147,payload size=345,offset size=345,src time stamp=35.17,hop time stamp=35.17,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-35.4024;node-1;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.5,source seqno=4147,payload size=345,offset size=345,src time stamp=35.17,hop time stamp=35.399,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-35.4035;node-1;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.15,source seqno=4016,payload size=345,offset size=345,src time stamp=34.273,hop time stamp=35.399,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-36.0406;node-8;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.7,source ip=10.0.0.9,source seqno=4241,payload size=345,offset size=345,src time stamp=36.04,hop time stamp=36.04,hop ip=10.0.0.9,bundle type=BundlePacket
#
# [time-36.3113;node-6;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.9,source seqno=4241,payload size=345,offset size=345,src time stamp=36.04,hop time stamp=36.299,hop ip=10.0.0.9,bundle type=BundlePacket
#
# [time-37.6951;node-10;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.8,source ip=10.0.0.11,source seqno=4420,payload size=345,offset size=345,src time stamp=37.695,hop time stamp=37.695,hop ip=10.0.0.11,bundle type=BundlePacket
#
# [time-39.0112;node-1;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.11,source seqno=4420,payload size=345,offset size=345,src time stamp=37.695,hop time stamp=38.999,hop ip=10.0.0.11,bundle type=BundlePacket
#
# [time-39.5989;node-2;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.19,source ip=10.0.0.3,source seqno=4625,payload size=345,offset size=345,src time stamp=39.598,hop time stamp=39.598,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-39.8359;node-13;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.5,source ip=10.0.0.14,source seqno=4650,payload size=345,offset size=345,src time stamp=39.835,hop time stamp=39.835,hop ip=10.0.0.14,bundle type=BundlePacket
#
# [time-40.1384;node-3;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.12,source ip=10.0.0.4,source seqno=4681,payload size=345,offset size=345,src time stamp=40.138,hop time stamp=40.138,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-40.2118;node-3;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.5,source ip=10.0.0.14,source seqno=4650,payload size=345,offset size=345,src time stamp=39.835,hop time stamp=40.199,hop ip=10.0.0.14,bundle type=BundlePacket
#
# [time-40.5024;node-11;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.12,source ip=10.0.0.4,source seqno=4681,payload size=345,offset size=345,src time stamp=40.138,hop time stamp=40.499,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-40.8036;node-4;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.5,source ip=10.0.0.14,source seqno=4650,payload size=345,offset size=345,src time stamp=39.835,hop time stamp=40.799,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-44.3674;node-9;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.19,source ip=10.0.0.10,source seqno=5143,payload size=345,offset size=345,src time stamp=44.367,hop time stamp=44.367,hop ip=10.0.0.10,bundle type=BundlePacket
#
# [time-44.8273;node-18;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.9,source ip=10.0.0.19,source seqno=5190,payload size=345,offset size=345,src time stamp=44.827,hop time stamp=44.827,hop ip=10.0.0.19,bundle type=BundlePacket
#
# [time-45.0005;node-7;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.19,source ip=10.0.0.10,source seqno=5143,payload size=345,offset size=345,src time stamp=44.367,hop time stamp=44.999,hop ip=10.0.0.10,bundle type=BundlePacket
#
# [time-45.6005;node-15;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.19,source seqno=5190,payload size=345,offset size=345,src time stamp=44.827,hop time stamp=45.599,hop ip=10.0.0.19,bundle type=BundlePacket
#
# [time-47.0173;node-7;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.16,source ip=10.0.0.8,source seqno=5416,payload size=345,offset size=345,src time stamp=47.017,hop time stamp=47.017,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-48.6662;node-12;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.8,source ip=10.0.0.13,source seqno=5582,payload size=345,offset size=345,src time stamp=48.666,hop time stamp=48.666,hop ip=10.0.0.13,bundle type=BundlePacket
#
# [time-49.2029;node-11;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.13,source seqno=5582,payload size=345,offset size=345,src time stamp=48.666,hop time stamp=49.199,hop ip=10.0.0.13,bundle type=BundlePacket
#
# [time-51.2741;node-17;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.1,source ip=10.0.0.18,source seqno=5847,payload size=345,offset size=345,src time stamp=51.274,hop time stamp=51.274,hop ip=10.0.0.18,bundle type=BundlePacket
#
# [time-51.6005;node-15;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.1,source ip=10.0.0.18,source seqno=5847,payload size=345,offset size=345,src time stamp=51.274,hop time stamp=51.599,hop ip=10.0.0.18,bundle type=BundlePacket
#
# [time-53.3553;node-0;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.16,source ip=10.0.0.1,source seqno=6059,payload size=345,offset size=345,src time stamp=53.355,hop time stamp=53.355,hop ip=10.0.0.1,bundle type=BundlePacket
#
# [time-54.0005;node-1;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.16,source ip=10.0.0.1,source seqno=6059,payload size=345,offset size=345,src time stamp=53.355,hop time stamp=53.999,hop ip=10.0.0.1,bundle type=BundlePacket
#
# [time-54.6805;node-11;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.7,source ip=10.0.0.12,source seqno=6196,payload size=345,offset size=345,src time stamp=54.68,hop time stamp=54.68,hop ip=10.0.0.12,bundle type=BundlePacket
#
# [time-56.0436;node-6;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.12,source ip=10.0.0.7,source seqno=6333,payload size=345,offset size=345,src time stamp=56.043,hop time stamp=56.043,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-56.4005;node-5;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.12,source ip=10.0.0.7,source seqno=6333,payload size=345,offset size=345,src time stamp=56.043,hop time stamp=56.399,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-57.5549;node-19;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.14,source ip=10.0.0.20,source seqno=6488,payload size=345,offset size=345,src time stamp=57.554,hop time stamp=57.554,hop ip=10.0.0.20,bundle type=BundlePacket
#
# [time-57.565;node-8;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.2,source ip=10.0.0.9,source seqno=6490,payload size=345,offset size=345,src time stamp=57.564,hop time stamp=57.564,hop ip=10.0.0.9,bundle type=BundlePacket
#
# [time-58.2005;node-15;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.14,source ip=10.0.0.20,source seqno=6488,payload size=345,offset size=345,src time stamp=57.554,hop time stamp=58.199,hop ip=10.0.0.20,bundle type=BundlePacket
#
# [time-58.2017;node-1;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.12,source ip=10.0.0.7,source seqno=6333,payload size=345,offset size=345,src time stamp=56.043,hop time stamp=58.199,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-58.2033;node-5;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.5,source seqno=3702,payload size=345,offset size=345,src time stamp=31.826,hop time stamp=58.199,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-58.5005;node-6;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.5,source seqno=3702,payload size=345,offset size=345,src time stamp=31.826,hop time stamp=58.499,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-58.5028;node-5;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.18,source ip=10.0.0.1,source seqno=3927,payload size=345,offset size=345,src time stamp=33.518,hop time stamp=58.499,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-58.8023;node-7;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.18,source ip=10.0.0.1,source seqno=3927,payload size=345,offset size=345,src time stamp=33.518,hop time stamp=58.799,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-58.8136;node-8;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.5,source seqno=4147,payload size=345,offset size=345,src time stamp=35.17,hop time stamp=58.799,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-58.8162;node-1;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.2,source ip=10.0.0.9,source seqno=6490,payload size=345,offset size=345,src time stamp=57.564,hop time stamp=58.799,hop ip=10.0.0.9,bundle type=BundlePacket
#
# [time-59.1005;node-5;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.15,source seqno=4016,payload size=345,offset size=345,src time stamp=34.273,hop time stamp=59.099,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-59.403;node-5;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.11,source seqno=4420,payload size=345,offset size=345,src time stamp=37.695,hop time stamp=59.399,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-59.7005;node-7;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.11,source seqno=4420,payload size=345,offset size=345,src time stamp=37.695,hop time stamp=59.699,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-59.7021;node-3;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.12,source ip=10.0.0.7,source seqno=6333,payload size=345,offset size=345,src time stamp=56.043,hop time stamp=59.699,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-59.8059;node-5;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.19,source ip=10.0.0.3,source seqno=4625,payload size=345,offset size=345,src time stamp=39.598,hop time stamp=58.799,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-60.0005;node-7;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.19,source ip=10.0.0.3,source seqno=4625,payload size=345,offset size=345,src time stamp=39.598,hop time stamp=59.999,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-60.0024;node-5;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.16,source ip=10.0.0.1,source seqno=6059,payload size=345,offset size=345,src time stamp=53.355,hop time stamp=59.999,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-60.3016;node-7;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.16,source ip=10.0.0.1,source seqno=6059,payload size=345,offset size=345,src time stamp=53.355,hop time stamp=60.299,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-66.902;node-11;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.12,source ip=10.0.0.7,source seqno=6333,payload size=345,offset size=345,src time stamp=56.043,hop time stamp=66.899,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-66.9029;node-7;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.19,source seqno=5190,payload size=345,offset size=345,src time stamp=44.827,hop time stamp=66.899,hop ip=10.0.0.16,bundle type=BundlePacket
#
# [time-66.9033;node-3;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.13,source seqno=5582,payload size=345,offset size=345,src time stamp=48.666,hop time stamp=66.899,hop ip=10.0.0.12,bundle type=BundlePacket
#
# [time-67.2005;node-1;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.13,source seqno=5582,payload size=345,offset size=345,src time stamp=48.666,hop time stamp=67.199,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-67.2025;node-3;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.12,source seqno=6196,payload size=345,offset size=345,src time stamp=54.68,hop time stamp=67.199,hop ip=10.0.0.12,bundle type=BundlePacket
#
# [time-67.2029;node-15;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.19,source ip=10.0.0.10,source seqno=5143,payload size=345,offset size=345,src time stamp=44.367,hop time stamp=67.199,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-67.2048;node-7;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.1,source ip=10.0.0.18,source seqno=5847,payload size=345,offset size=345,src time stamp=51.274,hop time stamp=67.199,hop ip=10.0.0.16,bundle type=BundlePacket
#
# [time-67.5018;node-7;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.14,source ip=10.0.0.20,source seqno=6488,payload size=345,offset size=345,src time stamp=57.554,hop time stamp=67.499,hop ip=10.0.0.16,bundle type=BundlePacket
#
# [time-67.5029;node-1;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.12,source seqno=6196,payload size=345,offset size=345,src time stamp=54.68,hop time stamp=67.499,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-67.5034;node-15;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.16,source ip=10.0.0.8,source seqno=5416,payload size=345,offset size=345,src time stamp=47.017,hop time stamp=67.499,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-67.5062;node-5;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.13,source seqno=5582,payload size=345,offset size=345,src time stamp=48.666,hop time stamp=67.499,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-67.8005;node-18;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.19,source ip=10.0.0.10,source seqno=5143,payload size=345,offset size=345,src time stamp=44.367,hop time stamp=67.799,hop ip=10.0.0.16,bundle type=BundlePacket
#
# [time-67.8029;node-7;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.13,source seqno=5582,payload size=345,offset size=345,src time stamp=48.666,hop time stamp=67.799,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-67.804;node-15;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.18,source ip=10.0.0.1,source seqno=3927,payload size=345,offset size=345,src time stamp=33.518,hop time stamp=67.799,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-67.8098;node-5;line-640]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.12,source seqno=6196,payload size=345,offset size=345,src time stamp=54.68,hop time stamp=67.799,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-68.1005;node-17;line-632]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.18,source ip=10.0.0.1,source seqno=3927,payload size=345,offset size=345,src time stamp=33.518,hop time stamp=68.099,hop ip=10.0.0.16,bundle type=BundlePacket
#
# ...
# from time-6.91402 => time-27.299 in node-3
# from time-27.3026 => time-28.499 in node-11
# received by node-12 at time-28.5033 destination :)
# arrived destination
#
# schedule is: from node-1 to node-12 at time-6.646
# ==================
# pkt-seqno:1386, trace is:
# from time-13.717 => time-14.099 in node-18
# from time-14.1143 => time-27.299 in node-15
# from time-27.3005 => time-27.899 in node-7
# from time-27.9035 => time-28.199 in node-5
# from time-28.2088 => time-28.499 in node-1
# from time-28.5076 => time-29.099 in node-3
# from time-29.1039 => time-29.699 in node-11
# received by node-13 at time-29.7104 destination :)
# arrived destination
#
# schedule is: from node-18 to node-13 at time-13.717
# ==================
# pkt-seqno:1454, trace is:
# from time-14.292 => time-14.699 in node-12
# from time-14.7122 => time-27.299 in node-11
# from time-27.3018 => time-27.599 in node-3
# received by node-2 at time-27.6171 destination :)
# arrived destination
#
# schedule is: from node-12 to node-2 at time-14.292
# ==================
# pkt-seqno:1802, trace is:
# from time-17.67 => time-18.299 in node-19
# from time-18.317 => time-27.899 in node-15
# from time-27.9026 => time-29.099 in node-7
# from time-29.102 => time-29.399 in node-5
# received by node-1 at time-29.4106 destination :)
# arrived destination
#
# schedule is: from node-19 to node-1 at time-17.67
# ==================
# pkt-seqno:1825, trace is:
# from time-17.894 => time-18.299 in node-17
# from time-18.3095 => time-27.599 in node-15
# from time-27.602 => time-28.199 in node-7
# received by node-6 at time-28.2167 destination :)
# arrived destination
#
# schedule is: from node-17 to node-6 at time-17.894
# ==================
# pkt-seqno:1940, trace is:
# from time-18.857 => time-27.599 in node-11
# from time-27.6029 => time-27.899 in node-3
# from time-27.9086 => time-28.199 in node-1
# received by node-9 at time-28.2078 destination :)
# arrived destination
#
# schedule is: from node-11 to node-9 at time-18.857
# ==================
# pkt-seqno:2067, trace is:
# from time-20.115 => time-20.699 in node-10
# from time-20.713 => time-27.899 in node-11
# from time-27.9035 => time-28.199 in node-3
# received by node-4 at time-29.2062 destination :)
# arrived destination
#
# schedule is: from node-10 to node-4 at time-20.115
# ==================
# pkt-seqno:2309, trace is:
# from time-22.432 => time-28.199 in node-15
# from time-28.2049 => time-28.799 in node-7
# from time-28.8005 => time-29.099 in node-5
# from time-29.113 => time-29.399 in node-1
# from time-29.4019 => time-29.699 in node-3
# from time-29.7005 => time-30.299 in node-11
# received by node-12 at time-30.3018 destination :)
# arrived destination
#
# schedule is: from node-15 to node-12 at time-22.432
# ==================
# pkt-seqno:2451, trace is:
# from time-23.842 => time-24.299 in node-6
# from time-24.3082 => time-24.899 in node-5
# from time-24.9019 => time-25.499 in node-1
# from time-25.5021 => time-26.999 in node-3
# from time-27.009 => time-28.199 in node-11
# received by node-10 at time-28.2034 destination :)
# arrived destination
#
# schedule is: from node-6 to node-10 at time-23.842
# ==================
# pkt-seqno:2496, trace is:
# from time-24.282 => time-24.599 in node-1
# from time-24.609 => time-25.199 in node-5
# from time-25.2133 => time-26.999 in node-7
# from time-27.0146 => time-28.499 in node-15
# received by node-19 at time-28.5005 destination :)
# arrived destination
#
# schedule is: from node-1 to node-19 at time-24.282
# ==================
# pkt-seqno:2608, trace is:
# from time-25.18 => time-25.499 in node-3
# received by node-1 at time-25.5036 destination :)
# arrived destination
#
# schedule is: from node-3 to node-1 at time-25.18
# ==================
# pkt-seqno:2848, trace is:
# from time-27.096 => time-27.299 in node-5
# received by node-4 at time-27.3145 destination :)
# arrived destination
#
# schedule is: from node-5 to node-4 at time-27.096
# ==================
# pkt-seqno:2863, trace is:
# from time-27.23 => time-27.899 in node-9
# from time-27.9017 => time-28.499 in node-7
# from time-28.5036 => time-28.799 in node-15
# received by node-16 at time-28.8115 destination :)
# arrived destination
#
# schedule is: from node-9 to node-16 at time-27.23
# ==================
# pkt-seqno:2946, trace is:
# from time-27.671 => time-27.899 in node-14
# from time-28.9061 => time-29.399 in node-11
# from time-29.403 => time-29.999 in node-3
# from time-30.0046 => time-30.299 in node-1
# received by node-5 at time-30.3087 destination :)
# arrived destination
#
# schedule is: from node-14 to node-5 at time-27.671
# ==================
# pkt-seqno:2990, trace is:
# from time-27.949 => time-28.499 in node-2
# from time-28.5087 => time-29.399 in node-3
# from time-29.404 => time-29.999 in node-11
# received by node-12 at time-30.0027 destination :)
# arrived destination
#
# schedule is: from node-2 to node-12 at time-27.949
# ==================
# pkt-seqno:3157, trace is:
# from time-28.848 => time-29.099 in node-16
# from time-29.1051 => time-29.699 in node-15
# from time-29.7036 => time-29.999 in node-7
# received by node-6 at time-30.0005 destination :)
# arrived destination
#
# schedule is: from node-16 to node-6 at time-28.848
# ==================
# pkt-seqno:3251, trace is:
# from time-29.347 => time-29.699 in node-13
# from time-29.7135 => time-30.599 in node-11
# from time-30.6029 => time-30.899 in node-3
# received by node-4 at time-30.9023 destination :)
# arrived destination
#
# schedule is: from node-13 to node-4 at time-29.347
# ==================
# pkt-seqno:3255, trace is:
# from time-29.371 => time-29.999 in node-15
# from time-30.0074 => time-30.299 in node-7
# from time-30.3041 => time-30.899 in node-5
# from time-30.906 => time-31.199 in node-1
# received by node-0 at time-31.2085 destination :)
# arrived destination
#
# schedule is: from node-15 to node-0 at time-29.371
# ==================
# pkt-seqno:3303, trace is:
# from time-29.68 => time-29.999 in node-16
# from time-30.0044 => time-30.299 in node-15
# from time-30.3029 => time-30.599 in node-7
# from time-30.6046 => time-31.199 in node-5
# from time-31.2005 => time-31.499 in node-1
# received by node-3 at time-31.5019 destination :)
# arrived destination
#
# schedule is: from node-16 to node-3 at time-29.68
# ==================
# pkt-seqno:3702, trace is:
# from time-31.826 => time-32.099 in node-4
# from time-32.1337 => time-58.199 in node-1
# from time-58.2033 => time-58.499 in node-5
# received by node-6 at time-58.5005 destination :)
# arrived destination
#
# schedule is: from node-4 to node-6 at time-31.826
# ==================
# pkt-seqno:3848, trace is:
# from time-32.892 => time-33.299 in node-5
# from time-33.3005 => time-33.899 in node-7
# from time-33.9005 => time-34.199 in node-15
# received by node-17 at time-34.2005 destination :)
# arrived destination
#
# schedule is: from node-5 to node-17 at time-32.892
# ==================
# pkt-seqno:3927, trace is:
# from time-33.518 => time-33.899 in node-0
# from time-33.9005 => time-58.499 in node-1
# from time-58.5028 => time-58.799 in node-5
# from time-58.8023 => time-67.799 in node-7
# from time-67.804 => time-68.099 in node-15
# received by node-17 at time-68.1005 destination :)
# arrived destination
#
# schedule is: from node-0 to node-17 at time-33.518
# ==================
# pkt-seqno:4016, trace is:
# from time-34.273 => time-34.799 in node-14
# from time-34.8026 => time-35.399 in node-3
# from time-35.4035 => time-59.099 in node-1
# received by node-5 at time-59.1005 destination :)
# arrived destination
#
# schedule is: from node-14 to node-5 at time-34.273
# ==================
# pkt-seqno:4147, trace is:
# from time-35.17 => time-35.399 in node-4
# from time-35.4024 => time-58.799 in node-1
# received by node-8 at time-58.8136 destination :)
# arrived destination
#
# schedule is: from node-4 to node-8 at time-35.17
# ==================
# pkt-seqno:4241, trace is:
# from time-36.04 => time-36.299 in node-8
# received by node-6 at time-36.3113 destination :)
# arrived destination
#
# schedule is: from node-8 to node-6 at time-36.04
# ==================
# pkt-seqno:4420, trace is:
# from time-37.695 => time-38.999 in node-10
# from time-39.0112 => time-59.399 in node-1
# from time-59.403 => time-59.699 in node-5
# received by node-7 at time-59.7005 destination :)
# arrived destination
#
# schedule is: from node-10 to node-7 at time-37.695
# ==================
# pkt-seqno:4625, trace is:
# from time-39.598 => time-58.799 in node-2
# from time-59.8059 => time-59.999 in node-5
# from time-60.0005 => time-68.099 in node-7
# from time-68.1043 => time-68.399 in node-15
# received by node-18 at time-68.4035 destination :)
# arrived destination
#
# schedule is: from node-2 to node-18 at time-39.598
# ==================
# pkt-seqno:4650, trace is:
# from time-39.835 => time-40.199 in node-13
# from time-40.2118 => time-40.799 in node-3
# received by node-4 at time-40.8036 destination :)
# arrived destination
#
# schedule is: from node-13 to node-4 at time-39.835
# ==================
# pkt-seqno:4681, trace is:
# from time-40.138 => time-40.499 in node-3
# received by node-11 at time-40.5024 destination :)
# arrived destination
#
# schedule is: from node-3 to node-11 at time-40.138
# ==================
# pkt-seqno:5143, trace is:
# from time-44.367 => time-44.999 in node-9
# from time-45.0005 => time-67.199 in node-7
# from time-67.2029 => time-67.799 in node-15
# received by node-18 at time-67.8005 destination :)
# arrived destination
#
# schedule is: from node-9 to node-18 at time-44.367
# ==================
# pkt-seqno:5190, trace is:
# from time-44.827 => time-45.599 in node-18
# from time-45.6005 => time-66.899 in node-15
# from time-66.9029 => time-68.699 in node-7
# received by node-8 at time-68.707 destination :)
# arrived destination
#
# schedule is: from node-18 to node-8 at time-44.827
# ==================
# pkt-seqno:5416, trace is:
# from time-47.017 => time-67.499 in node-7
# received by node-15 at time-67.5034 destination :)
# arrived destination
#
# schedule is: from node-7 to node-15 at time-47.017
# ==================
# pkt-seqno:5582, trace is:
# from time-48.666 => time-49.199 in node-12
# from time-49.2029 => time-66.899 in node-11
# from time-66.9033 => time-67.199 in node-3
# from time-67.2005 => time-67.499 in node-1
# from time-67.5062 => time-67.799 in node-5
# received by node-7 at time-67.8029 destination :)
# arrived destination
#
# schedule is: from node-12 to node-7 at time-48.666
# ==================
# pkt-seqno:5847, trace is:
# from time-51.274 => time-51.599 in node-17
# from time-51.6005 => time-67.199 in node-15
# from time-67.2048 => time-68.999 in node-7
# from time-69.0061 => time-69.599 in node-5
# from time-69.6019 => time-69.899 in node-1
# received by node-0 at time-69.904 destination :)
# arrived destination
#
# schedule is: from node-17 to node-0 at time-51.274
# ==================
# pkt-seqno:6059, trace is:
# from time-53.355 => time-53.999 in node-0
# from time-54.0005 => time-59.999 in node-1
# from time-60.0024 => time-60.299 in node-5
# from time-60.3016 => time-68.399 in node-7
# received by node-15 at time-68.4068 destination :)
# arrived destination
#
# schedule is: from node-0 to node-15 at time-53.355
# ==================
# pkt-seqno:6196, trace is:
# from time-54.68 => time-67.199 in node-11
# from time-67.2025 => time-67.499 in node-3
# from time-67.5029 => time-67.799 in node-1
# from time-67.8098 => time-68.099 in node-5
# received by node-6 at time-68.1023 destination :)
# arrived destination
#
# schedule is: from node-11 to node-6 at time-54.68
# ==================
# pkt-seqno:6333, trace is:
# from time-56.043 => time-56.399 in node-6
# from time-56.4005 => time-58.199 in node-5
# from time-58.2017 => time-59.699 in node-1
# from time-59.7021 => time-66.899 in node-3
# received by node-11 at time-66.902 destination :)
# arrived destination
#
# schedule is: from node-6 to node-11 at time-56.043
# ==================
# pkt-seqno:6488, trace is:
# from time-57.554 => time-58.199 in node-19
# from time-58.2005 => time-67.499 in node-15
# from time-67.5018 => time-69.299 in node-7
# from time-69.3005 => time-69.899 in node-5
# from time-69.906 => time-70.199 in node-1
# from time-70.2032 => time-71.099 in node-0
# from time-71.1005 => time-71.699 in node-11
# received by node-13 at time-71.7005 destination :)
# arrived destination
#
# schedule is: from node-19 to node-13 at time-57.554
# ==================
# pkt-seqno:6490, trace is:
# from time-57.564 => time-58.799 in node-8
# received by node-1 at time-58.8162 destination :)
# arrived destination
#
# schedule is: from node-8 to node-1 at time-57.564
# {384: [3.93, 7, 4.499, 4.5153, 9, 802.0], 669: [6.646, 1, 6.899, 6.91402, 3, 27.299, 27.3026, 11, 28.499, 28.5033, 12, 802.0], 1386: [13.717, 18, 14.099, 14.1143, 15, 27.299, 27.3005, 7, 27.899, 27.9035, 5, 28.199, 28.2088, 1, 28.499, 28.5076, 3, 29.099, 29.1039, 11, 29.699, 29.7104, 13, 802.0], 1454: [14.292, 12, 14.699, 14.7122, 11, 27.299, 27.3018, 3, 27.599, 27.6171, 2, 802.0], 1802: [17.67, 19, 18.299, 18.317, 15, 27.899, 27.9026, 7, 29.099, 29.102, 5, 29.399, 29.4106, 1, 802.0], 1825: [17.894, 17, 18.299, 18.3095, 15, 27.599, 27.602, 7, 28.199, 28.2167, 6, 802.0], 1940: [18.857, 11, 27.599, 27.6029, 3, 27.899, 27.9086, 1, 28.199, 28.2078, 9, 802.0], 2067: [20.115, 10, 20.699, 20.713, 11, 27.899, 27.9035, 3, 28.199, 29.2062, 4, 802.0], 2309: [22.432, 15, 28.199, 28.2049, 7, 28.799, 28.8005, 5, 29.099, 29.113, 1, 29.399, 29.4019, 3, 29.699, 29.7005, 11, 30.299, 30.3018, 12, 802.0], 2451: [23.842, 6, 24.299, 24.3082, 5, 24.899, 24.9019, 1, 25.499, 25.5021, 3, 26.999, 27.009, 11, 28.199, 28.2034, 10, 802.0], 2496: [24.282, 1, 24.599, 24.609, 5, 25.199, 25.2133, 7, 26.999, 27.0146, 15, 28.499, 28.5005, 19, 802.0], 2608: [25.18, 3, 25.499, 25.5036, 1, 802.0], 2848: [27.096, 5, 27.299, 27.3145, 4, 802.0], 2863: [27.23, 9, 27.899, 27.9017, 7, 28.499, 28.5036, 15, 28.799, 28.8115, 16, 802.0], 2946: [27.671, 14, 27.899, 28.9061, 11, 29.399, 29.403, 3, 29.999, 30.0046, 1, 30.299, 30.3087, 5, 802.0], 2990: [27.949, 2, 28.499, 28.5087, 3, 29.399, 29.404, 11, 29.999, 30.0027, 12, 802.0], 3157: [28.848, 16, 29.099, 29.1051, 15, 29.699, 29.7036, 7, 29.999, 30.0005, 6, 802.0], 3251: [29.347, 13, 29.699, 29.7135, 11, 30.599, 30.6029, 3, 30.899, 30.9023, 4, 802.0], 3255: [29.371, 15, 29.999, 30.0074, 7, 30.299, 30.3041, 5, 30.899, 30.906, 1, 31.199, 31.2085, 0, 802.0], 3303: [29.68, 16, 29.999, 30.0044, 15, 30.299, 30.3029, 7, 30.599, 30.6046, 5, 31.199, 31.2005, 1, 31.499, 31.5019, 3, 802.0], 3702: [31.826, 4, 32.099, 32.1337, 1, 58.199, 58.2033, 5, 58.499, 58.5005, 6, 802.0], 3848: [32.892, 5, 33.299, 33.3005, 7, 33.899, 33.9005, 15, 34.199, 34.2005, 17, 802.0], 3927: [33.518, 0, 33.899, 33.9005, 1, 58.499, 58.5028, 5, 58.799, 58.8023, 7, 67.799, 67.804, 15, 68.099, 68.1005, 17, 802.0], 4016: [34.273, 14, 34.799, 34.8026, 3, 35.399, 35.4035, 1, 59.099, 59.1005, 5, 802.0], 4147: [35.17, 4, 35.399, 35.4024, 1, 58.799, 58.8136, 8, 802.0], 4241: [36.04, 8, 36.299, 36.3113, 6, 802.0], 4420: [37.695, 10, 38.999, 39.0112, 1, 59.399, 59.403, 5, 59.699, 59.7005, 7, 802.0], 4625: [39.598, 2, 58.799, 59.8059, 5, 59.999, 60.0005, 7, 68.099, 68.1043, 15, 68.399, 68.4035, 18, 802.0], 4650: [39.835, 13, 40.199, 40.2118, 3, 40.799, 40.8036, 4, 802.0], 4681: [40.138, 3, 40.499, 40.5024, 11, 802.0], 5143: [44.367, 9, 44.999, 45.0005, 7, 67.199, 67.2029, 15, 67.799, 67.8005, 18, 802.0], 5190: [44.827, 18, 45.599, 45.6005, 15, 66.899, 66.9029, 7, 68.699, 68.707, 8, 802.0], 5416: [47.017, 7, 67.499, 67.5034, 15, 802.0], 5582: [48.666, 12, 49.199, 49.2029, 11, 66.899, 66.9033, 3, 67.199, 67.2005, 1, 67.499, 67.5062, 5, 67.799, 67.8029, 7, 802.0], 5847: [51.274, 17, 51.599, 51.6005, 15, 67.199, 67.2048, 7, 68.999, 69.0061, 5, 69.599, 69.6019, 1, 69.899, 69.904, 0, 802.0], 6059: [53.355, 0, 53.999, 54.0005, 1, 59.999, 60.0024, 5, 60.299, 60.3016, 7, 68.399, 68.4068, 15, 802.0], 6196: [54.68, 11, 67.199, 67.2025, 3, 67.499, 67.5029, 1, 67.799, 67.8098, 5, 68.099, 68.1023, 6, 802.0], 6333: [56.043, 6, 56.399, 56.4005, 5, 58.199, 58.2017, 1, 59.699, 59.7021, 3, 66.899, 66.902, 11, 802.0], 6488: [57.554, 19, 58.199, 58.2005, 15, 67.499, 67.5018, 7, 69.299, 69.3005, 5, 69.899, 69.906, 1, 70.199, 70.2032, 0, 71.099, 71.1005, 11, 71.699, 71.7005, 13, 802.0], 6490: [57.564, 8, 58.799, 58.8162, 1, 802.0]}
# <img src="data:image/png;base64,..." width="640">
# colors count=40
# len of seqno_number_list=40
# range(0, 40)
