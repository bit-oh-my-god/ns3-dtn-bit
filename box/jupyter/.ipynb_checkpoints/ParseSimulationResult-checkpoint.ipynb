# %%
# %matplotlib notebook
import re
import sys
import inspect
from math import sqrt
import numpy as np
from scipy import integrate
from matplotlib import pyplot as plt
import matplotlib as mpl
from matplotlib import cm
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
import jsonpickle
from matplotlib.colors import cnames
from matplotlib import animation
#==================================
# This parse script won't parse sprayandwait for full footprints, just the longest one.
##################
# define handy func
def nums(s):
    try:
        return int(s)
    except ValueError:
        return float(s)
################
#====
# read the result file
simulation_result_file = open("../../box/dtn_simulation_result/dtnrunninglog.txt", "r")
lines = simulation_result_file.readlines();
simulation_result_file.close()
#====
x_is_one_delivery_route = False
x_jsonfile_name = '??random with Spray'
x_totoal_cgr_enter_count = 0
x_simulation_time = -1
x_nodes = -1
x_sch_n = -1
x_arrive_n = 0
#                                                                                    dstination
x_time_trace_map = {} # seqno -> [src_t, sr_id, hop_t, rec_t, rec_id, hop_t, ... , rec_t, rec_id, x_simulation_time]
x_tosend_list = [] # element is also a list [source, time, destination, seqno] this is used to substitude x_schedule_list
x_schedule_list = [] # element is also a list[source, time, destination, seqno]
x_pkt_trace_map = {} # seqno -> [one_hop_snap, one_hop_snap... destination_snap]
# hop_snap , destination_snap = 
#[receive_time, receive_id, dest_id, source_id, seqno, src_generate_time, hop_transmit_time, pkt_type, is_dst, hop_id]
############
# define
def snap_print(snap) :
    print('''seqno :{0}, pkt-type={4}, receive at time-{1} at node-{2}, transmit at time-{3} at node-{5}'''
          .format(snap[4], snap[0], snap[1], snap[6], snap[7], snap[9]))
def is_snap_des(snap) :
    return snap[8]
class B_Tree(object):
    def __init__(self, pos1, pos2, pos3, pos4, data):
        self.pos1 = pos1
        self.pos2 = pos2
        self.pos3 = pos3
        self.pos4 = pos4
        self.data = data
def create_tree_from_list(list):
    root = B_Tree(None, None, None, None, None)
    return root
#############
test_string = r'Here In DtnExampleInterface::ReportExBundleTrace:node_number_=5;simulation_duration_=802'
r11 = re.compile(r'BundleTrace:node_number_=(\d+\.*\d*);simulation_duration_=(\d+\.*\d*)', re.VERBOSE)
test_regx = r11.search(test_string)
if test_regx :
    print("good0")
else :
    print("bad0")
    sys.exit()
    
strss = "[time-5.40052;node-1;line-638]NOTE:BundleTrace:good! one bun\
dle recept, it's one hop! bp_header=,destination ip=10.0.0.3,sour\
ce ip=10.0.0.1,source seqno=139,payload size=345,offset size=345,src time sta\
mp=5,hop time stamp=5,bundle type=BundlePacket"
r22 = re.compile(r'\[time-(\d+\.*\d*);node-(\d+\.*\d*);line-(\d+\.*\d*)\]NOTE:BundleTr\
ace:good!\sone\sbundle\srecept,\sit\'s\sone\shop!\sbp_header=,destination\sip=10.0.0.(\d+\.*\d*),sou\
rce\sip=10.0.0.(\d+\.*\d*),source\sseqno=(\d+\.*\d*),payload\ssize=(\d+\.*\d*),offset\ssi\
ze=(\d+\.*\d*),src\stime\sstamp=(\d+\.*\d*),hop\stime\sstamp=(\d+\.*\d*),bundle\stype=([a-zA-Z]+)', re.VERBOSE)
hopt = r22.match(strss)
if hopt :
    print("good1")
else :
    print("bad1")
    sys.exit()
    
#================================================ dividing parse ========================================
# parse for x_ nodes and x_ simualtion_time
# parse for bundle trace and schedule
avoid_log_twice_bug = False
for line in lines :
    #In DtnExampleRunner
    r0 = re.compile(r'In\sDtnExampleRunner', re.VERBOSE)
    parse_begin = r0.search(line)
    if parse_begin :
        avoid_log_twice_bug = True
        continue
    elif avoid_log_twice_bug :
        # do nothing
        onenomeaning = 1
    else :
        continue
    
    #BundleTrace:node_number_=5;simulation_duration_=802
    r1 = re.compile(r'BundleTrace:node_number_=(\d+\.*\d*);simulation_duration_=(\d+\.*\d*)', re.VERBOSE)
    simulation_preview = r1.search(line)
    
    #[time-5.40052;node-1;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.3,source ip=10.0.0.1,source seqno=139,payload size=345,offset size=345,src time stamp=5,hop time stamp=5,bundle type=BundlePacket
    r2 = re.compile(r'''\[time\-(\d+\.*\d*);node\-(\d+\.*\d*);line\-(\d+\.*\d*)\]NOTE:BundleTrace:go
    od!\sone\sbundle\srecept\,\sit\'s\sone\shop!\sbp_header=\,destination\sip=10\.0\.0\.(\d+\.*\d*)\,sour
    ce\sip=10\.0\.0\.(\d+\.*\d*)\,source\sseqno=(\d+\.*\d*)\,payload\ssize=(\d+\.*\d*)\,offset\ssiz
    e=(\d+\.*\d*)\,src\stime\sstamp=(\d+\.*\d*)\,hop\stime\ssta
    mp=(\d+\.*\d*)\,hop\sip=10\.0\.0\.(\d+\.*\d*)\,bundle\stype=([a-zA-Z]+)''', re.VERBOSE)
    hop = r2.search(line)
    
    #[time-3.30744;node-1;line-630]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.2,source ip=10.0.0.1,source seqno=75,payload size=345,offset size=345,src time stamp=3,hop time stamp=3,bundle type=BundlePacket
    r3 = re.compile(r'''\[time\-(\d+\.*\d*);node\-(\d+\.*\d*);line\-(\d+\.*\d*)\]NOTE:BundleTrace:Great!\son
    e\sbundle\sarrive\sdestination!\sbp_header=\,destination\sip=10\.0\.0\.(\d+\.*\d*)\,so
    urce\sip=10\.0\.0\.(\d+\.*\d*)\,source\sseqno=(\d+\.*\d*)\,payload\ssize=(\d+\.*\d*)\,offset\ss
    ize=(\d+\.*\d*)\,src\stime\sstamp=(\d+\.*\d*)\,hop\stime\ssta
    mp=(\d+\.*\d*)\,hop\sip=10\.0\.0\.(\d+\.*\d*)\,bundle\stype=([a-zA-Z]+)''', re.VERBOSE)
    destination = r3.search(line)
    
    #[time-0;node-0;line-1553]enter ScheduleTx(), time-+3000000000.0ns,size=345, to node-1
    r4 = re.compile(r'''node\-(\d+\.*\d*);line\-(\d+\.*\d*)]enter\sScheduleTx\(\)\,\sti
    me\-\+(\d+\.*\d*)ns\,size=(\d+\.*\d*)\,\sto\snode\-(\d+\.*\d*)''', re.VERBOSE)
    schedule = r4.search(line)
    
    #BundleTrace:Itisonedeliverymethon
    r5 = re.compile(r'''BundleTrace:Itisonedeliverymethon''', re.VERBOSE)
    isonedelivery = r5.search(line)
    
    #ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.4,source ip=10.0.0.3,source seqno=47,payload size=345,offset size=345,src time stamp=0.562494,hop time stamp=0.562494,hop ip=10.0.0.3,bundle type=BundlePacket
    r6 = re.compile(r'''ScheduleTx\,inToSendBundle\(\)\,bp_header=\,destination\sip=10\.0\.0\.(\d+\.*\d*)\,so
    urce\sip=10\.0\.0\.(\d+\.*\d*)\,source\sseqno=(\d+\.*\d*)\,payload\ssize=(\d+\.*\d*)\,offset\ss
    ize=(\d+\.*\d*)\,src\stime\sstamp=(\d+\.*\d*)\,hop\stime\ssta
    mp=(\d+\.*\d*)\,hop\sip=10\.0\.0\.(\d+\.*\d*)\,bundle\stype=([a-zA-Z]+)''', re.VERBOSE)
    tosendbundle = r6.search(line)
    
    #BundleTrace:entertimes=1times
    r7 = re.compile(r'''BundleTrace:entertimes=(\d+\.*\d*)times''', re.VERBOSE)
    cgrcount = r7.search(line)
    
    if schedule :
        print(line)
        sche_source = int(nums(schedule.group(1)))
        sche_time = float(nums(schedule.group(3)) / 1000000000.0)
        sche_destination = int(nums(schedule.group(5)))
        tmp = [sche_source, sche_time, sche_destination, -1]
        x_schedule_list.append(tmp)
    elif cgrcount :
        print(line)
        x_totoal_cgr_enter_count += int(nums(cgrcount.group(1)))
    elif tosendbundle :
        print(line)
        tosend_source = int(nums(tosendbundle.group(2)) - int(1))
        tosend_time = float(nums(tosendbundle.group(6)))
        tosend_destination = int(nums(tosendbundle.group(1)) - int(1))
        tosend_seqno = int(nums(tosendbundle.group(3)))
        tmp = [tosend_source, tosend_time, tosend_destination, tosend_seqno]
        x_tosend_list.append(tmp)
    elif isonedelivery :
        print(line)
        x_is_one_delivery_route = True
    elif hop :
        print(line)
        hop_receive_time = float(nums(hop.group(1)))
        hop_receive_id = int(nums(hop.group(2)))
        hop_dest_id = int(nums(hop.group(4)) - int(1))
        hop_source_id = int(nums(hop.group(5)) - int(1))
        hop_seqno = int(nums(hop.group(6)))
        hop_src_generate_time = float(nums(hop.group(9))) # TODO
        hop_hop_transmit_time = float(nums(hop.group(10)))
        hop_hop_id = int(nums(hop.group(11)) - int(1))
        hop_pkt_type = hop.group(12)
        if (hop_hop_transmit_time > hop_receive_time) :
            print('receive time:{0} should < hop_transmit time{1}'.format(hop_receive_time, hop_hop_transmit_time))
            sys.exit()
        tmp = [hop_receive_time, hop_receive_id, hop_dest_id, hop_source_id, hop_seqno,
               hop_src_generate_time, hop_hop_transmit_time, hop_pkt_type, False, hop_hop_id]
        if hop_seqno in x_pkt_trace_map.keys():
            old_list = x_pkt_trace_map[hop_seqno]
            old_list.append(tmp)
            old_list.sort(key=lambda tup: tup[0])
            x_pkt_trace_map[hop_seqno] = old_list
        else:
            new_list = []
            new_list.append(tmp)
            x_pkt_trace_map[hop_seqno] = new_list
    elif simulation_preview :
        print(line)
        x_nodes = int(simulation_preview.group(1))
        x_simulation_time = float(simulation_preview.group(2))
    elif destination :
        print(line)
        dst_receive_time = float(nums(destination.group(1)))
        dst_receive_id = int(nums(destination.group(2)))
        dst_dst_id = int(nums(destination.group(4)) - int(1))
        dst_src_id = int(nums(destination.group(5)) - int(1))
        dst_seqno = int(nums(destination.group(6)))
        dst_src_generate_time = float(nums(destination.group(9)))
        dst_hop_transmit_time = float(nums(destination.group(10)))
        dst_hop_id = int(nums(destination.group(11)) - int(1))
        dst_pkt_type = destination.group(12)
        if (dst_hop_transmit_time > dst_receive_time) :
            print('receive time')
            sys.exit()
        tmp = [dst_receive_time, dst_receive_id, dst_dst_id, dst_src_id, dst_seqno,
               dst_src_generate_time, dst_hop_transmit_time, dst_pkt_type, True, dst_hop_id]
        if dst_seqno in x_pkt_trace_map.keys() :
            old_list = x_pkt_trace_map[dst_seqno]
            old_list.append(tmp)
            old_list.sort(key=lambda tup: tup[0])
            x_pkt_trace_map[dst_seqno] = old_list
        else :
            new_list = []
            new_list.append(tmp)
            x_pkt_trace_map[dst_seqno] = new_list
            
#========================================= end of parse ===================================================

print(r'============= dividing end of parse =============')
if (x_nodes == -1) or (x_simulation_time == -1) :
    print('error_04')
    sys.exit()
#================ now we have every thing we need, refine the data and prepare for visualization
#===== refine x_schedule_list
for sch in x_schedule_list :
    sk = [sch[0], sch[1], sch[2]] # s, t, d
    sn = sch[3]
    if sn != -1 :
        print('error_03')
        sys.exit()
    for key, value in x_pkt_trace_map.items() : #
        #print('value len={0}'.format(len(value)))
        #print(value)
        tk = [value[0][3], value[0][5], value[0][2]]
        seqno = value[0][4]
        if (tk[0] == sk[0] and tk[2] == sk[2] and tk[1] - sk[1] < 0.1) :
            sn = seqno
            break
    if (sn != -1) :
        sch[3] = sn
    else :
        print('warn_05:this may happen when one pkt scheduled but not successfully hoped')

print('============= \n === print your schedule')
print(x_schedule_list)
print('============= \n === print your tosendbundle')
print(x_tosend_list)
#===================================== get graph needed list
#
x_sch_n = len(x_tosend_list)
print('==============\n print your x_pkt_trace_map')
print(x_pkt_trace_map)
#######################################
####################
#definition
def get_x_time_trace_map_detail(p_x_time_trace_map, p_x_tosend_list, p_x_pkt_trace_map, ref_x_arrive_n) :
    ref_x_arrive_n = 0
    for sch in p_x_tosend_list :
            src_t = sch[1]
            seqno = sch[3]
            if seqno == -1 :
                print('error_01')
                sys.exit()
            sr_id = sch[0]
            tmp = []
            tmp.extend([src_t, sr_id])
            if seqno in p_x_pkt_trace_map :
                print('key exist')
                for trace in p_x_pkt_trace_map[seqno] :
                    if trace[4] != seqno :
                        print('error_02')
                        sys.exit()
                    is_dst = bool(trace[8])
                    hop_t = trace[6]
                    rec_t = trace[0]
                    rec_id = trace[1]
                    tmp.extend([hop_t, rec_t, rec_id])
                    if is_dst :
                        tmp.append(x_simulation_time)
                if len(tmp) % 3 == 0 :
                    ref_x_arrive_n += 1
                    p_x_time_trace_map[seqno] = tmp 
                else :
                    print('there is one pkt don\'t arrive destination')
                    p_x_time_trace_map[seqno] = tmp
            else :
                print('key not exist-{0}'.format(seqno))
                p_x_time_trace_map[seqno] = tmp
    return ref_x_arrive_n
def get_x_time_trace_map(p_x_time_trace_map, p_x_tosend_list, p_x_pkt_trace_map, ref_x_arrive_n) :
    ref_x_arrive_n = 0
    if x_is_one_delivery_route :
        ref_x_arrive_n = get_x_time_trace_map_detail(p_x_time_trace_map,p_x_tosend_list, p_x_pkt_trace_map, ref_x_arrive_n)
    else :
        print('if not one delivery route, this would cause one seqno -> multiply path, it\'s hard to parse, would\
        differ against normal one delivery parse')
        print('============ print all hop snap ==============')
        for key, snaps in p_x_pkt_trace_map.items() :
            for snap in snaps :
                snap_print(snap)
        print('================ then we would try to find destination delivery in p_x_pkt_trace_map =========')
        for key, snaps in p_x_pkt_trace_map.items() :
            #treeob = get_B_Tree_from_key_snaps(key, snaps, p_x_tosend_list)
            pkt_uni_list = get_list_of_pkt_trace(key, snaps, p_x_tosend_list)
            reversed_uni_list = []
            for v in reversed(pkt_uni_list) :
                reversed_uni_list.append(v)
            p_x_pkt_trace_map[key] = reversed_uni_list
        print('================ debug  p_x_pkt_trace_map 1=========')
        print(p_x_pkt_trace_map)
        print('================ debug  p_x_pkt_trace_map 1=========')
        ref_x_arrive_n = get_x_time_trace_map_detail(p_x_time_trace_map,p_x_tosend_list, p_x_pkt_trace_map, ref_x_arrive_n)
    return ref_x_arrive_n
def get_list_of_pkt_trace(key, snaps, p_x_tosend_list) :
    snaps_count = len(snaps)
    source_id = None
    for y_tosend in p_x_tosend_list :
        if key == y_tosend[3] :
            source_id = y_tosend[0]
    dest_snap = None
    for snap in snaps :
        if is_snap_des(snap) :
            dest_snap = snap
    if dest_snap == None :
        dest_snap = snaps[snaps_count - 1]
    return_list = []
    if dest_snap == None :
        return return_list
    cur_snap = dest_snap
    return_list.append(cur_snap)
    loop_count = 0
    if dest_snap[3] != source_id :
        print('source ={0}-{1}'.format(source_id, dest_snap[3]))
        print("error_09")
        sys.exit()
    while cur_snap[9] != source_id and loop_count <= 40 :
        loop_count += 1
        for snap in snaps :
            print("key is {2}, cur_snap from-{0}, snap is{1}".format(cur_snap[9], snap[1], key))
            if cur_snap[9] == snap[1] and snap[6] < cur_snap[0] :
                cur_snap = snap
                return_list.append(cur_snap)
                break
    if loop_count > 40 :
        print("error_08")
        sys.exit()
    return return_list
def get_B_Tree_from_key_snaps(key, snaps, pp_x_tosend_list) :
    r = 1
    #unreached_count = len(snaps)
    #have_dest = False
    #dest_snap = None
    #longest_snap_chain = None
    #for snap in snaps :
    #    if is_snap_des(snap) :
    #        dest_snap = snap
    #source_id = None
    #tree_root = None
    #for y_tosend in pp_x_tosend_list :
    #    if key == y_tosend[3] :
    #        source_id = y_tosend[0]
    #if source_id == None :
    #    print("error_07")
    #    sys.exit()
    #else :
    #    tree_root = B_Tree(None, None, None, None, source_id)
    #cur_trans_id = source_id
    #while unreached_count > 0 :
    #    tree_child = [None, None, None, None]
     #    child_index = 0
    #    for snap in snaps :
    #        if snap[9] == cur_trans_id ##
    #       tree_childe[child_index] = snap
    #        child_index += 1
    #        unreached_count -= 1
    #--- Not implement yet
    #return tree_root
def handy_print_2(seqno, p_x_tosend_list) :
    for xs in p_x_tosend_list :
        if xs[3] == seqno :
            print('schedule is: from node-{0} to node-{1} at time-{2}'.format(xs[0], xs[2], xs[1]))
            break
def handy_print_0(st, et, nid) :
    print('from time-{0} => time-{1} in node-{2}'.format(st, et, nid))
def handy_print_1(key, value, p_x_tosend_list) :
    print('==================\npkt-seqno:{0}, trace is: '.format(key))
    n_v = int(len(value) / 3)
    is_arrived_traffic = False
    if (n_v * 3 == len(value)) :
        is_arrived_traffic = True
    if (is_arrived_traffic) :
        for cur in range(0, n_v, 1) :
            if cur == n_v - 1 :
                print('received by node-{1} at time-{0} destination :)'.format(value[cur * 3], value[cur * 3 + 1]))
            else :
                handy_print_0(value[cur * 3], value[cur * 3 + 2], value[cur * 3 + 1])
        print('arrived destination\n')
    else :
        for cur in range(0, n_v + 1, 1) :
            if cur == n_v :
                print('received by node-{1} at time-{0}, not destination :('.format(value[cur * 3], value[cur * 3 + 1]))
                if cur == 0 :
                    print('this bundle may not be transmit out from source')
            else :
                handy_print_0(value[cur * 3], value[cur * 3 + 2], value[cur * 3 + 1])
        print('not arrived destination\n')
    handy_print_2(key, p_x_tosend_list)
def handy_draw_0(ax0, st, et, nid, seqnoindex, c) :
    dx = et - st
    ax0.bar3d(st, seqnoindex, nid, dx + 1.0, 0.2, 0.2, alpha=0.1, color=c, linewidth=0) # alpha = abs(dz[i]/max(dz))
class JSONOB(object):
    def __init__(self, name, tosend_list_ob, time_trace_map_ob):
        self.name = name
        self.tosend_list_ob = tosend_list_ob
        self.time_trace_map_ob = time_trace_map_ob
    def get_map(self) :
        return self.time_trace_map_ob
    def get_list(self) :
        return self.tosend_list_ob
def save_this_jsonob_as(filename, jsonob_to) :
    fullpathname = './stuff folder/' + filename
    serialized_json = jsonpickle.encode(jsonob_to)
    with open(fullpathname, "w") as text_file:
        print(serialized_json, file=text_file)
def draw_it(p_x_tosend_list, p_x_time_trace_map, p_x_simulation_time) :
    fig = plt.figure()
    ax = fig.gca(projection='3d')
    colors = plt.cm.jet(np.linspace(0, 1, len(p_x_tosend_list)))
    seqno_number_list = []
    for xsele in p_x_tosend_list :
        seqno_number_list.append(xsele[3])  
    print('colors count={0}'.format(len(colors)))
    print('len of seqno_number_list={0}'.format(len(seqno_number_list)))
    print(range(0, len(seqno_number_list), 1))
    for c, zseqnoindex in zip(colors, range(0, len(seqno_number_list), 1)):
        this_seqno_no = seqno_number_list[zseqnoindex]
        trace_list_of_seqno = p_x_time_trace_map[this_seqno_no]
        rt_count = int(len(trace_list_of_seqno) / 3)
        is_arrived_traffic_0 = False
        if (rt_count * 3 == len(trace_list_of_seqno)) :
            is_arrived_traffic_0 = True
            
        if is_arrived_traffic_0 :
            for cur in range(0, rt_count, 1) :
                if cur == rt_count - 1 :
                    handy_draw_0(ax, trace_list_of_seqno[cur * 3], trace_list_of_seqno[cur * 3 + 2], \
                                 trace_list_of_seqno[cur * 3 + 1], zseqnoindex, c)
                    ax.text(p_x_simulation_time, zseqnoindex, 0\
                            , 'arrived! seqno={0}'.format(seqno_number_list[zseqnoindex]), 'x')
                else :
                    handy_draw_0(ax, trace_list_of_seqno[cur * 3], trace_list_of_seqno[cur * 3 + 2], \
                                 trace_list_of_seqno[cur * 3 + 1], zseqnoindex, c)
        else :
            for cur in range(0, rt_count + 1, 1) :
                if cur == rt_count :
                    handy_draw_0(ax, trace_list_of_seqno[cur * 3], trace_list_of_seqno[cur * 3] + 1, \
                                 trace_list_of_seqno[cur * 3 + 1], zseqnoindex, c)
                    ax.text(p_x_simulation_time, zseqnoindex, 0\
                            , 'missed! seqno={0}'.format(seqno_number_list[zseqnoindex]), 'x')
                else :
                    handy_draw_0(ax, trace_list_of_seqno[cur * 3], trace_list_of_seqno[cur * 3 + 2], \
                                 trace_list_of_seqno[cur * 3 + 1], zseqnoindex, c)

    ax.set_xlabel('time')
    ax.set_ylabel('seqno')
    ax.set_zlabel('node')
    plt.show()
#end of definition
#################################
###################################
print('===================================================================================================\
\n===================== report parse result ================')
x_arrive_n = get_x_time_trace_map(x_time_trace_map, x_tosend_list, x_pkt_trace_map, x_arrive_n)
title_str = '{0} / {1} arrived'.format(x_arrive_n, x_sch_n)
print(title_str)
print('====================== serialize to json format =====================')
name = '{4}-nodeN-{0}-timeT-{1}-arriveN-{2}-scheduleN-{3}'.\
                    format(x_nodes, x_simulation_time, x_arrive_n, x_sch_n, x_jsonfile_name)
jsonob_this = JSONOB(name, x_tosend_list, x_time_trace_map)
save_this_jsonob_as(name, jsonob_this)

print('====================== print result in plain text =====================')
for key, value in x_time_trace_map.items() :
    handy_print_1(key, value, x_tosend_list)
print(x_time_trace_map)

print('================================= dividing ========================')
draw_it(x_tosend_list, x_time_trace_map, x_simulation_time)

if x_totoal_cgr_enter_count > 0 :
    print('totoal cgr enter count = {0}'.format(x_totoal_cgr_enter_count))
# Out:
# good0
# good1
# Here In DtnExampleInterface::ReportExBundleTrace:node_number_=10;simulation_duration_=802
#
# [time-0;node-0;line-1604]enter ScheduleTx(), time-+12021325669.0ns,size=345, to node-2
#
# [time-0;node-0;line-1604]enter ScheduleTx(), time-+117981550363.0ns,size=345, to node-9
#
# [time-0;node-1;line-1604]enter ScheduleTx(), time-+13820478268.0ns,size=345, to node-3
#
# [time-0;node-1;line-1604]enter ScheduleTx(), time-+40906334457.0ns,size=345, to node-5
#
# [time-0;node-2;line-1604]enter ScheduleTx(), time-+10576573125.0ns,size=345, to node-7
#
# [time-0;node-2;line-1604]enter ScheduleTx(), time-+111853278406.0ns,size=345, to node-1
#
# [time-0;node-3;line-1604]enter ScheduleTx(), time-+44976664340.0ns,size=345, to node-0
#
# [time-0;node-3;line-1604]enter ScheduleTx(), time-+96841738290.0ns,size=345, to node-0
#
# [time-0;node-4;line-1604]enter ScheduleTx(), time-+59974493344.0ns,size=345, to node-7
#
# [time-0;node-4;line-1604]enter ScheduleTx(), time-+58811808883.0ns,size=345, to node-2
#
# [time-0;node-5;line-1604]enter ScheduleTx(), time-+45792076630.0ns,size=345, to node-6
#
# [time-0;node-5;line-1604]enter ScheduleTx(), time-+93212644665.0ns,size=345, to node-8
#
# [time-0;node-6;line-1604]enter ScheduleTx(), time-+49717128001.0ns,size=345, to node-8
#
# [time-0;node-6;line-1604]enter ScheduleTx(), time-+105528534177.0ns,size=345, to node-4
#
# [time-0;node-7;line-1604]enter ScheduleTx(), time-+68712840599.0ns,size=345, to node-5
#
# [time-0;node-7;line-1604]enter ScheduleTx(), time-+99989950898.0ns,size=345, to node-8
#
# [time-0;node-8;line-1604]enter ScheduleTx(), time-+65532323034.0ns,size=345, to node-5
#
# [time-0;node-8;line-1604]enter ScheduleTx(), time-+81878003716.0ns,size=345, to node-3
#
# [time-0;node-9;line-1604]enter ScheduleTx(), time-+48118018161.0ns,size=345, to node-8
#
# [time-0;node-9;line-1604]enter ScheduleTx(), time-+69282537905.0ns,size=345, to node-8
#
# [time-10.5766;node-2;line-367]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.8,source ip=10.0.0.3,source seqno=528,payload size=345,offset size=345,src time stamp=10.576,hop time stamp=10.576,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-12.0213;node-0;line-367]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.3,source ip=10.0.0.1,source seqno=601,payload size=345,offset size=345,src time stamp=12.021,hop time stamp=12.021,hop ip=10.0.0.1,bundle type=BundlePacket
#
# [time-13.8205;node-1;line-367]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.4,source ip=10.0.0.2,source seqno=692,payload size=345,offset size=345,src time stamp=13.82,hop time stamp=13.82,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-36.306;node-2;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.4,source ip=10.0.0.2,source seqno=692,payload size=345,offset size=345,src time stamp=13.82,hop time stamp=36.299,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-36.3849;node-1;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.3,source seqno=528,payload size=345,offset size=345,src time stamp=10.576,hop time stamp=36.299,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-40.9063;node-1;line-367]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.6,source ip=10.0.0.2,source seqno=2092,payload size=345,offset size=345,src time stamp=40.906,hop time stamp=40.906,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-41.4039;node-2;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.2,source seqno=2092,payload size=345,offset size=345,src time stamp=40.906,hop time stamp=41.399,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-44.9767;node-3;line-367]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.1,source ip=10.0.0.4,source seqno=2303,payload size=345,offset size=345,src time stamp=44.976,hop time stamp=44.976,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-45.3122;node-6;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.1,source ip=10.0.0.4,source seqno=2303,payload size=345,offset size=345,src time stamp=44.976,hop time stamp=45.299,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-45.7921;node-5;line-367]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.7,source ip=10.0.0.6,source seqno=2355,payload size=345,offset size=345,src time stamp=45.792,hop time stamp=45.792,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-46.5138;node-7;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.6,source seqno=2355,payload size=345,offset size=345,src time stamp=45.792,hop time stamp=46.499,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-48.118;node-9;line-367]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.9,source ip=10.0.0.10,source seqno=2477,payload size=345,offset size=345,src time stamp=48.118,hop time stamp=48.118,hop ip=10.0.0.10,bundle type=BundlePacket
#
# [time-48.9104;node-8;line-630]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.10,source seqno=2477,payload size=345,offset size=345,src time stamp=48.118,hop time stamp=48.899,hop ip=10.0.0.10,bundle type=BundlePacket
#
# [time-49.7171;node-6;line-367]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.9,source ip=10.0.0.7,source seqno=2571,payload size=345,offset size=345,src time stamp=49.717,hop time stamp=49.717,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-50.1005;node-3;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.7,source seqno=2571,payload size=345,offset size=345,src time stamp=49.717,hop time stamp=50.099,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-58.8118;node-4;line-367]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.3,source ip=10.0.0.5,source seqno=3033,payload size=345,offset size=345,src time stamp=58.811,hop time stamp=58.811,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-59.9745;node-4;line-367]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.8,source ip=10.0.0.5,source seqno=3092,payload size=345,offset size=345,src time stamp=59.974,hop time stamp=59.974,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-65.5323;node-8;line-367]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.6,source ip=10.0.0.9,source seqno=3369,payload size=345,offset size=345,src time stamp=65.532,hop time stamp=65.532,hop ip=10.0.0.9,bundle type=BundlePacket
#
# [time-66.3005;node-9;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.9,source seqno=3369,payload size=345,offset size=345,src time stamp=65.532,hop time stamp=66.299,hop ip=10.0.0.9,bundle type=BundlePacket
#
# [time-68.7128;node-7;line-367]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.6,source ip=10.0.0.8,source seqno=3531,payload size=345,offset size=345,src time stamp=68.712,hop time stamp=68.712,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-69.2825;node-9;line-367]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.9,source ip=10.0.0.10,source seqno=3560,payload size=345,offset size=345,src time stamp=69.282,hop time stamp=69.282,hop ip=10.0.0.10,bundle type=BundlePacket
#
# [time-69.3005;node-5;line-630]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.8,source seqno=3531,payload size=345,offset size=345,src time stamp=68.712,hop time stamp=69.299,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-69.6005;node-8;line-630]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.10,source seqno=3560,payload size=345,offset size=345,src time stamp=69.282,hop time stamp=69.599,hop ip=10.0.0.10,bundle type=BundlePacket
#
# [time-81.878;node-8;line-367]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.4,source ip=10.0.0.9,source seqno=4205,payload size=345,offset size=345,src time stamp=81.878,hop time stamp=81.878,hop ip=10.0.0.9,bundle type=BundlePacket
#
# [time-82.2005;node-9;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.4,source ip=10.0.0.9,source seqno=4205,payload size=345,offset size=345,src time stamp=81.878,hop time stamp=82.199,hop ip=10.0.0.9,bundle type=BundlePacket
#
# [time-93.2126;node-5;line-367]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.9,source ip=10.0.0.6,source seqno=4779,payload size=345,offset size=345,src time stamp=93.212,hop time stamp=93.212,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-96.8417;node-3;line-367]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.1,source ip=10.0.0.4,source seqno=4960,payload size=345,offset size=345,src time stamp=96.841,hop time stamp=96.841,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-99.99;node-7;line-367]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.9,source ip=10.0.0.8,source seqno=5120,payload size=345,offset size=345,src time stamp=99.989,hop time stamp=99.989,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-105.529;node-6;line-367]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.5,source ip=10.0.0.7,source seqno=5395,payload size=345,offset size=345,src time stamp=105.528,hop time stamp=105.528,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-111.853;node-2;line-367]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.2,source ip=10.0.0.3,source seqno=5713,payload size=345,offset size=345,src time stamp=111.853,hop time stamp=111.853,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-112.201;node-1;line-630]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.2,source ip=10.0.0.3,source seqno=5713,payload size=345,offset size=345,src time stamp=111.853,hop time stamp=112.199,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-117.982;node-0;line-367]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.10,source ip=10.0.0.1,source seqno=6030,payload size=345,offset size=345,src time stamp=117.981,hop time stamp=117.981,hop ip=10.0.0.1,bundle type=BundlePacket
#
# [time-163.514;node-2;line-630]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.3,source ip=10.0.0.5,source seqno=3033,payload size=345,offset size=345,src time stamp=58.811,hop time stamp=163.499,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-163.587;node-4;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.3,source seqno=528,payload size=345,offset size=345,src time stamp=10.576,hop time stamp=163.499,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-163.809;node-4;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.4,source ip=10.0.0.2,source seqno=692,payload size=345,offset size=345,src time stamp=13.82,hop time stamp=163.799,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-163.813;node-2;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.5,source seqno=3092,payload size=345,offset size=345,src time stamp=59.974,hop time stamp=163.799,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-164.109;node-4;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.2,source seqno=2092,payload size=345,offset size=345,src time stamp=40.906,hop time stamp=164.099,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-206.711;node-6;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.3,source ip=10.0.0.1,source seqno=601,payload size=345,offset size=345,src time stamp=12.021,hop time stamp=206.699,hop ip=10.0.0.1,bundle type=BundlePacket
#
# [time-207.009;node-0;line-630]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.1,source ip=10.0.0.4,source seqno=2303,payload size=345,offset size=345,src time stamp=44.976,hop time stamp=206.999,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-207.013;node-6;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.10,source ip=10.0.0.1,source seqno=6030,payload size=345,offset size=345,src time stamp=117.981,hop time stamp=206.999,hop ip=10.0.0.1,bundle type=BundlePacket
#
# [time-207.308;node-0;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.7,source seqno=2571,payload size=345,offset size=345,src time stamp=49.717,hop time stamp=207.299,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-207.612;node-0;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.5,source ip=10.0.0.7,source seqno=5395,payload size=345,offset size=345,src time stamp=105.528,hop time stamp=207.599,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-243.008;node-4;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.6,source seqno=2355,payload size=345,offset size=345,src time stamp=45.792,hop time stamp=242.999,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-243.309;node-4;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.6,source seqno=4779,payload size=345,offset size=345,src time stamp=93.212,hop time stamp=243.299,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-243.313;node-5;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.3,source seqno=528,payload size=345,offset size=345,src time stamp=10.576,hop time stamp=243.299,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-243.608;node-5;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.5,source seqno=3092,payload size=345,offset size=345,src time stamp=59.974,hop time stamp=243.599,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-243.904;node-5;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.4,source ip=10.0.0.2,source seqno=692,payload size=345,offset size=345,src time stamp=13.82,hop time stamp=243.899,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-244.203;node-5;line-630]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.2,source seqno=2092,payload size=345,offset size=345,src time stamp=40.906,hop time stamp=244.199,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-314.409;node-2;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.6,source seqno=2355,payload size=345,offset size=345,src time stamp=45.792,hop time stamp=314.399,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-315.003;node-2;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.6,source seqno=4779,payload size=345,offset size=345,src time stamp=93.212,hop time stamp=314.999,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-414.013;node-9;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.6,source seqno=2355,payload size=345,offset size=345,src time stamp=45.792,hop time stamp=413.999,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-414.308;node-7;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.9,source seqno=3369,payload size=345,offset size=345,src time stamp=65.532,hop time stamp=414.299,hop ip=10.0.0.10,bundle type=BundlePacket
#
# [time-414.313;node-9;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.8,source seqno=5120,payload size=345,offset size=345,src time stamp=99.989,hop time stamp=414.299,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-414.613;node-7;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.4,source ip=10.0.0.9,source seqno=4205,payload size=345,offset size=345,src time stamp=81.878,hop time stamp=414.599,hop ip=10.0.0.10,bundle type=BundlePacket
#
# [time-462.612;node-6;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.6,source seqno=4779,payload size=345,offset size=345,src time stamp=93.212,hop time stamp=462.599,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-462.909;node-6;line-630]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.6,source seqno=2355,payload size=345,offset size=345,src time stamp=45.792,hop time stamp=462.899,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-462.913;node-2;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.10,source ip=10.0.0.1,source seqno=6030,payload size=345,offset size=345,src time stamp=117.981,hop time stamp=462.899,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-463.202;node-6;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.4,source ip=10.0.0.2,source seqno=692,payload size=345,offset size=345,src time stamp=13.82,hop time stamp=463.199,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-463.203;node-2;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.7,source seqno=2571,payload size=345,offset size=345,src time stamp=49.717,hop time stamp=463.199,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-463.502;node-6;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.5,source seqno=3092,payload size=345,offset size=345,src time stamp=59.974,hop time stamp=463.499,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-463.503;node-2;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.5,source ip=10.0.0.7,source seqno=5395,payload size=345,offset size=345,src time stamp=105.528,hop time stamp=463.499,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-463.802;node-2;line-630]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.3,source ip=10.0.0.1,source seqno=601,payload size=345,offset size=345,src time stamp=12.021,hop time stamp=463.799,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-489.901;node-5;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.10,source ip=10.0.0.1,source seqno=6030,payload size=345,offset size=345,src time stamp=117.981,hop time stamp=489.899,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-490.201;node-5;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.7,source seqno=2571,payload size=345,offset size=345,src time stamp=49.717,hop time stamp=490.199,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-490.501;node-5;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.5,source ip=10.0.0.7,source seqno=5395,payload size=345,offset size=345,src time stamp=105.528,hop time stamp=490.499,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-501.909;node-6;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.3,source seqno=528,payload size=345,offset size=345,src time stamp=10.576,hop time stamp=501.899,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-522.31;node-3;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.6,source seqno=2355,payload size=345,offset size=345,src time stamp=45.792,hop time stamp=522.299,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-522.608;node-4;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.1,source ip=10.0.0.4,source seqno=2303,payload size=345,offset size=345,src time stamp=44.976,hop time stamp=522.599,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-522.613;node-3;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.3,source seqno=528,payload size=345,offset size=345,src time stamp=10.576,hop time stamp=522.599,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-522.909;node-4;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.7,source seqno=2571,payload size=345,offset size=345,src time stamp=49.717,hop time stamp=522.899,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-522.913;node-3;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.6,source seqno=4779,payload size=345,offset size=345,src time stamp=93.212,hop time stamp=522.899,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-523.208;node-3;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.5,source seqno=3092,payload size=345,offset size=345,src time stamp=59.974,hop time stamp=523.199,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-523.213;node-4;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.1,source ip=10.0.0.4,source seqno=4960,payload size=345,offset size=345,src time stamp=96.841,hop time stamp=523.199,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-523.513;node-3;line-630]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.4,source ip=10.0.0.2,source seqno=692,payload size=345,offset size=345,src time stamp=13.82,hop time stamp=523.499,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-545.108;node-8;line-630]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.6,source seqno=4779,payload size=345,offset size=345,src time stamp=93.212,hop time stamp=545.099,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-545.113;node-6;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.9,source seqno=3369,payload size=345,offset size=345,src time stamp=65.532,hop time stamp=545.099,hop ip=10.0.0.9,bundle type=BundlePacket
#
# [time-545.409;node-6;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.4,source ip=10.0.0.9,source seqno=4205,payload size=345,offset size=345,src time stamp=81.878,hop time stamp=545.399,hop ip=10.0.0.9,bundle type=BundlePacket
#
# [time-545.414;node-8;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.10,source ip=10.0.0.1,source seqno=6030,payload size=345,offset size=345,src time stamp=117.981,hop time stamp=545.399,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-545.709;node-8;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.3,source seqno=528,payload size=345,offset size=345,src time stamp=10.576,hop time stamp=545.699,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-546.013;node-8;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.4,source ip=10.0.0.2,source seqno=692,payload size=345,offset size=345,src time stamp=13.82,hop time stamp=545.999,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-546.309;node-8;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.5,source seqno=3092,payload size=345,offset size=345,src time stamp=59.974,hop time stamp=546.299,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-622.209;node-5;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.1,source ip=10.0.0.4,source seqno=4960,payload size=345,offset size=345,src time stamp=96.841,hop time stamp=622.199,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-622.283;node-3;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.10,source ip=10.0.0.1,source seqno=6030,payload size=345,offset size=345,src time stamp=117.981,hop time stamp=622.199,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-622.801;node-4;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.10,source ip=10.0.0.1,source seqno=6030,payload size=345,offset size=345,src time stamp=117.981,hop time stamp=622.799,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-622.81;node-3;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.5,source ip=10.0.0.7,source seqno=5395,payload size=345,offset size=345,src time stamp=105.528,hop time stamp=622.799,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-623.113;node-5;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.1,source ip=10.0.0.4,source seqno=2303,payload size=345,offset size=345,src time stamp=44.976,hop time stamp=623.099,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-623.401;node-4;line-630]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.5,source ip=10.0.0.7,source seqno=5395,payload size=345,offset size=345,src time stamp=105.528,hop time stamp=623.399,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-705.607;node-0;line-630]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.1,source ip=10.0.0.4,source seqno=4960,payload size=345,offset size=345,src time stamp=96.841,hop time stamp=705.599,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-706.208;node-5;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.5,source ip=10.0.0.7,source seqno=5395,payload size=345,offset size=345,src time stamp=105.528,hop time stamp=706.199,hop ip=10.0.0.1,bundle type=BundlePacket
#
# [time-706.509;node-0;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.5,source ip=10.0.0.7,source seqno=5395,payload size=345,offset size=345,src time stamp=105.528,hop time stamp=706.499,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-746.108;node-9;line-630]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.10,source ip=10.0.0.1,source seqno=6030,payload size=345,offset size=345,src time stamp=117.981,hop time stamp=746.099,hop ip=10.0.0.1,bundle type=BundlePacket
#
# [time-746.408;node-0;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.8,source seqno=5120,payload size=345,offset size=345,src time stamp=99.989,hop time stamp=746.399,hop ip=10.0.0.10,bundle type=BundlePacket
#
# [time-746.413;node-9;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.5,source ip=10.0.0.7,source seqno=5395,payload size=345,offset size=345,src time stamp=105.528,hop time stamp=746.399,hop ip=10.0.0.1,bundle type=BundlePacket
#
# [time-746.701;node-5;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.8,source seqno=5120,payload size=345,offset size=345,src time stamp=99.989,hop time stamp=746.699,hop ip=10.0.0.1,bundle type=BundlePacket
#
# ============= dividing end of parse =============
# =============
#  === print your schedule
# [[0, 12.021325669, 2, 601], [0, 117.981550363, 9, 6030], [1, 13.820478268, 3, 692], [1, 40.906334457, 5, 2092], [2, 10.576573125, 7, 528], [2, 111.853278406, 1, 5713], [3, 44.97666434, 0, 2303], [3, 96.84173829, 0, 2303], [4, 59.974493344, 7, 3092], [4, 58.811808883, 2, 3033], [5, 45.79207663, 6, 2355], [5, 93.212644665, 8, 4779], [6, 49.717128001, 8, 2571], [6, 105.528534177, 4, 5395], [7, 68.712840599, 5, 3531], [7, 99.989950898, 8, 5120], [8, 65.532323034, 5, 3369], [8, 81.878003716, 3, 4205], [9, 48.118018161, 8, 2477], [9, 69.282537905, 8, 2477]]
# =============
#  === print your tosendbundle
# [[2, 10.576, 7, 528], [0, 12.021, 2, 601], [1, 13.82, 3, 692], [1, 40.906, 5, 2092], [3, 44.976, 0, 2303], [5, 45.792, 6, 2355], [9, 48.118, 8, 2477], [6, 49.717, 8, 2571], [4, 58.811, 2, 3033], [4, 59.974, 7, 3092], [8, 65.532, 5, 3369], [7, 68.712, 5, 3531], [9, 69.282, 8, 3560], [8, 81.878, 3, 4205], [5, 93.212, 8, 4779], [3, 96.841, 0, 4960], [7, 99.989, 8, 5120], [6, 105.528, 4, 5395], [2, 111.853, 1, 5713], [0, 117.981, 9, 6030]]
# ==============
#  print your x_pkt_trace_map
# {692: [[36.306, 2, 3, 1, 692, 13.82, 36.299, 'BundlePacket', False, 1], [163.809, 4, 3, 1, 692, 13.82, 163.799, 'BundlePacket', False, 2], [243.904, 5, 3, 1, 692, 13.82, 243.899, 'BundlePacket', False, 4], [463.202, 6, 3, 1, 692, 13.82, 463.199, 'BundlePacket', False, 2], [523.513, 3, 3, 1, 692, 13.82, 523.499, 'BundlePacket', True, 4], [546.013, 8, 3, 1, 692, 13.82, 545.999, 'BundlePacket', False, 6]], 528: [[36.3849, 1, 7, 2, 528, 10.576, 36.299, 'BundlePacket', False, 2], [163.587, 4, 7, 2, 528, 10.576, 163.499, 'BundlePacket', False, 2], [243.313, 5, 7, 2, 528, 10.576, 243.299, 'BundlePacket', False, 4], [501.909, 6, 7, 2, 528, 10.576, 501.899, 'BundlePacket', False, 5], [522.613, 3, 7, 2, 528, 10.576, 522.599, 'BundlePacket', False, 4], [545.709, 8, 7, 2, 528, 10.576, 545.699, 'BundlePacket', False, 6]], 2092: [[41.4039, 2, 5, 1, 2092, 40.906, 41.399, 'BundlePacket', False, 1], [164.109, 4, 5, 1, 2092, 40.906, 164.099, 'BundlePacket', False, 2], [244.203, 5, 5, 1, 2092, 40.906, 244.199, 'BundlePacket', True, 4]], 2303: [[45.3122, 6, 0, 3, 2303, 44.976, 45.299, 'BundlePacket', False, 3], [207.009, 0, 0, 3, 2303, 44.976, 206.999, 'BundlePacket', True, 6], [522.608, 4, 0, 3, 2303, 44.976, 522.599, 'BundlePacket', False, 3], [623.113, 5, 0, 3, 2303, 44.976, 623.099, 'BundlePacket', False, 3]], 2355: [[46.5138, 7, 6, 5, 2355, 45.792, 46.499, 'BundlePacket', False, 5], [243.008, 4, 6, 5, 2355, 45.792, 242.999, 'BundlePacket', False, 5], [314.409, 2, 6, 5, 2355, 45.792, 314.399, 'BundlePacket', False, 5], [414.013, 9, 6, 5, 2355, 45.792, 413.999, 'BundlePacket', False, 7], [462.909, 6, 6, 5, 2355, 45.792, 462.899, 'BundlePacket', True, 2], [522.31, 3, 6, 5, 2355, 45.792, 522.299, 'BundlePacket', False, 4]], 2477: [[48.9104, 8, 8, 9, 2477, 48.118, 48.899, 'BundlePacket', True, 9]], 2571: [[50.1005, 3, 8, 6, 2571, 49.717, 50.099, 'BundlePacket', False, 6], [207.308, 0, 8, 6, 2571, 49.717, 207.299, 'BundlePacket', False, 6], [463.203, 2, 8, 6, 2571, 49.717, 463.199, 'BundlePacket', False, 6], [490.201, 5, 8, 6, 2571, 49.717, 490.199, 'BundlePacket', False, 2], [522.909, 4, 8, 6, 2571, 49.717, 522.899, 'BundlePacket', False, 3]], 3369: [[66.3005, 9, 5, 8, 3369, 65.532, 66.299, 'BundlePacket', False, 8], [414.308, 7, 5, 8, 3369, 65.532, 414.299, 'BundlePacket', False, 9], [545.113, 6, 5, 8, 3369, 65.532, 545.099, 'BundlePacket', False, 8]], 3531: [[69.3005, 5, 5, 7, 3531, 68.712, 69.299, 'BundlePacket', True, 7]], 3560: [[69.6005, 8, 8, 9, 3560, 69.282, 69.599, 'BundlePacket', True, 9]], 4205: [[82.2005, 9, 3, 8, 4205, 81.878, 82.199, 'BundlePacket', False, 8], [414.613, 7, 3, 8, 4205, 81.878, 414.599, 'BundlePacket', False, 9], [545.409, 6, 3, 8, 4205, 81.878, 545.399, 'BundlePacket', False, 8]], 5713: [[112.201, 1, 1, 2, 5713, 111.853, 112.199, 'BundlePacket', True, 2]], 3033: [[163.514, 2, 2, 4, 3033, 58.811, 163.499, 'BundlePacket', True, 4]], 3092: [[163.813, 2, 7, 4, 3092, 59.974, 163.799, 'BundlePacket', False, 4], [243.608, 5, 7, 4, 3092, 59.974, 243.599, 'BundlePacket', False, 4], [463.502, 6, 7, 4, 3092, 59.974, 463.499, 'BundlePacket', False, 2], [523.208, 3, 7, 4, 3092, 59.974, 523.199, 'BundlePacket', False, 4], [546.309, 8, 7, 4, 3092, 59.974, 546.299, 'BundlePacket', False, 6]], 601: [[206.711, 6, 2, 0, 601, 12.021, 206.699, 'BundlePacket', False, 0], [463.802, 2, 2, 0, 601, 12.021, 463.799, 'BundlePacket', True, 6]], 6030: [[207.013, 6, 9, 0, 6030, 117.981, 206.999, 'BundlePacket', False, 0], [462.913, 2, 9, 0, 6030, 117.981, 462.899, 'BundlePacket', False, 6], [489.901, 5, 9, 0, 6030, 117.981, 489.899, 'BundlePacket', False, 2], [545.414, 8, 9, 0, 6030, 117.981, 545.399, 'BundlePacket', False, 6], [622.283, 3, 9, 0, 6030, 117.981, 622.199, 'BundlePacket', False, 5], [622.801, 4, 9, 0, 6030, 117.981, 622.799, 'BundlePacket', False, 3], [746.108, 9, 9, 0, 6030, 117.981, 746.099, 'BundlePacket', True, 0]], 5395: [[207.612, 0, 4, 6, 5395, 105.528, 207.599, 'BundlePacket', False, 6], [463.503, 2, 4, 6, 5395, 105.528, 463. ...
# ===================================================================================================
# ===================== report parse result ================
# if not one delivery route, this would cause one seqno -> multiply path, it's hard to parse, would        differ against normal one delivery parse
# ============ print all hop snap ==============
# seqno :692, pkt-type=BundlePacket, receive at time-36.306 at node-2, transmit at time-36.299 at node-1
# seqno :692, pkt-type=BundlePacket, receive at time-163.809 at node-4, transmit at time-163.799 at node-2
# seqno :692, pkt-type=BundlePacket, receive at time-243.904 at node-5, transmit at time-243.899 at node-4
# seqno :692, pkt-type=BundlePacket, receive at time-463.202 at node-6, transmit at time-463.199 at node-2
# seqno :692, pkt-type=BundlePacket, receive at time-523.513 at node-3, transmit at time-523.499 at node-4
# seqno :692, pkt-type=BundlePacket, receive at time-546.013 at node-8, transmit at time-545.999 at node-6
# seqno :528, pkt-type=BundlePacket, receive at time-36.3849 at node-1, transmit at time-36.299 at node-2
# seqno :528, pkt-type=BundlePacket, receive at time-163.587 at node-4, transmit at time-163.499 at node-2
# seqno :528, pkt-type=BundlePacket, receive at time-243.313 at node-5, transmit at time-243.299 at node-4
# seqno :528, pkt-type=BundlePacket, receive at time-501.909 at node-6, transmit at time-501.899 at node-5
# seqno :528, pkt-type=BundlePacket, receive at time-522.613 at node-3, transmit at time-522.599 at node-4
# seqno :528, pkt-type=BundlePacket, receive at time-545.709 at node-8, transmit at time-545.699 at node-6
# seqno :2092, pkt-type=BundlePacket, receive at time-41.4039 at node-2, transmit at time-41.399 at node-1
# seqno :2092, pkt-type=BundlePacket, receive at time-164.109 at node-4, transmit at time-164.099 at node-2
# seqno :2092, pkt-type=BundlePacket, receive at time-244.203 at node-5, transmit at time-244.199 at node-4
# seqno :2303, pkt-type=BundlePacket, receive at time-45.3122 at node-6, transmit at time-45.299 at node-3
# seqno :2303, pkt-type=BundlePacket, receive at time-207.009 at node-0, transmit at time-206.999 at node-6
# seqno :2303, pkt-type=BundlePacket, receive at time-522.608 at node-4, transmit at time-522.599 at node-3
# seqno :2303, pkt-type=BundlePacket, receive at time-623.113 at node-5, transmit at time-623.099 at node-3
# seqno :2355, pkt-type=BundlePacket, receive at time-46.5138 at node-7, transmit at time-46.499 at node-5
# seqno :2355, pkt-type=BundlePacket, receive at time-243.008 at node-4, transmit at time-242.999 at node-5
# seqno :2355, pkt-type=BundlePacket, receive at time-314.409 at node-2, transmit at time-314.399 at node-5
# seqno :2355, pkt-type=BundlePacket, receive at time-414.013 at node-9, transmit at time-413.999 at node-7
# seqno :2355, pkt-type=BundlePacket, receive at time-462.909 at node-6, transmit at time-462.899 at node-2
# seqno :2355, pkt-type=BundlePacket, receive at time-522.31 at node-3, transmit at time-522.299 at node-4
# seqno :2477, pkt-type=BundlePacket, receive at time-48.9104 at node-8, transmit at time-48.899 at node-9
# seqno :2571, pkt-type=BundlePacket, receive at time-50.1005 at node-3, transmit at time-50.099 at node-6
# seqno :2571, pkt-type=BundlePacket, receive at time-207.308 at node-0, transmit at time-207.299 at node-6
# seqno :2571, pkt-type=BundlePacket, receive at time-463.203 at node-2, transmit at time-463.199 at node-6
# seqno :2571, pkt-type=BundlePacket, receive at time-490.201 at node-5, transmit at time-490.199 at node-2
# seqno :2571, pkt-type=BundlePacket, receive at time-522.909 at node-4, transmit at time-522.899 at node-3
# seqno :3369, pkt-type=BundlePacket, receive at time-66.3005 at node-9, transmit at time-66.299 at node-8
# seqno :3369, pkt-type=BundlePacket, receive at time-414.308 at node-7, transmit at time-414.299 at node-9
# seqno :3369, pkt-type=BundlePacket, receive at time-545.113 at node-6, transmit at time-545.099 at node-8
# seqno :3531, pkt-type=BundlePacket, receive at time-69.3005 at node-5, transmit at time-69.299 at node-7
# seqno :3560, pkt-type=BundlePacket, receive at time-69.6005 at node-8, transmit at time-69.599 at node-9
# seqno :4205, pkt-type=BundlePacket, receive at time-82.2005 at node-9, transmit at time-82.199 at node-8
# seqno :4205, pkt-type=BundlePacket, receive at time-414.613 at node-7, transmit at time-414.599 at node-9
# seqno :4205, pkt-type=BundlePacket, receive at time-545.409 at node-6, transmit at time-545.399 at node-8
# seqno :5713, pkt-type=BundlePacket, receive at time-112.201 at node-1, transmit at time-112.199 at node-2
# seqno :3033, pkt-type=BundlePacket, receive at time-163.514 at node-2, transmit at time-163.499 at node-4
# seqno :3092, pkt-type=BundlePacket, receive at time-163.813 at node-2, transmit at time-163.799 at node-4
# seqno :3092, pkt-type=BundlePacket, receive at time-243.608 at node-5, transmit at time-243.599 at node-4
# seqno :3092, pkt-type=BundlePacket, receive at time-463.502 at node-6, transmit at time-463.499 at node-2
# seqno :3092, pkt-type=BundlePacket, receive at time-523.208 at node-3, transmit at time-523.199 at node-4
# seqno :3092, pkt-type=BundlePacket, receive at time-546.309 at node-8, transmit at time-546.299 at node-6
# seqno :601, pkt-type=BundlePacket, receive at time-206.711 at node-6, transmit at time-206.699 at node-0
# seqno :601, pkt-type=BundlePacket, receive at time-463.802 at node-2, transmit at time-463.799 at node-6
# seqno :6030, pkt-type=BundlePacket, receive at time-207.013 at node-6, transmit at time-206.999 at node-0
# seqno :6030, pkt-type=BundlePacket, receive at time-462.913 at node-2, transmit at time-462.899 at node-6
# seqno :6030, pkt-type=BundlePacket, receive at time-489.901 at node-5, transmit at time-489.899 at node-2
# seqno :6030, pkt-type=BundlePacket, receive at time-545.414 at node-8, transmit at time-545.399 at node-6
# seqno :6030, pkt-type=BundlePacket, receive at time-622.283 at node-3, transmit at time-622.199 at node-5
# seqno :6030, pkt-type=BundlePacket, receive at time-622.801 at node-4, transmit at time-622.799 at node-3
# seqno :6030, pkt-type=BundlePacket, receive at time-746.108 at node-9, transmit at time-746.099 at node-0
# seqno :5395, pkt-type=BundlePacket, receive at time-207.612 at node-0, transmit at time-207.599 at node-6
# seqno :5395, pkt-type=BundlePacket, receive at time-463.503 at node-2, transmit at time-463.499 at node-6
# seqno :5395, pkt-type=BundlePacket, receive at time-490.501 at node-5, transmit at time-490.499 at node-2
# seqno :5395, pkt-type=BundlePacket, receive at time-622.81 at node-3, transmit at time-622.799 at node-5
# seqno :5395, pkt-type=BundlePacket, receive at time-623.401 at node-4, transmit at time-623.399 at node-3
# seqno :5395, pkt-type=BundlePacket, receive at time-706.208 at node-5, transmit at time-706.199 at node-0
# seqno :5395, pkt-type=BundlePacket, receive at time-706.509 at node-0, transmit at time-706.499 at node-5
# seqno :5395, pkt-type=BundlePacket, receive at time-746.413 at node-9, transmit at time-746.399 at node-0
# seqno :4779, pkt-type=BundlePacket, receive at time-243.309 at node-4, transmit at time-243.299 at node-5
# seqno :4779, pkt-type=BundlePacket, receive at time-315.003 at node-2, transmit at time-314.999 at node-5
# seqno :4779, pkt-type=BundlePacket, receive at time-462.612 at node-6, transmit at time-462.599 at node-2
# seqno :4779, pkt-type=BundlePacket, receive at time-522.913 at node-3, transmit at time-522.899 at node-4
# seqno :4779, pkt-type=BundlePacket, receive at time-545.108 at node-8, transmit at time-545.099 at node-6
# seqno :5120, pkt-type=BundlePacket, receive at time-414.313 at node-9, transmit at time-414.299 at node-7
# seqno :5120, pkt-type=BundlePacket, receive at time-746.408 at node-0, transmit at time-746.399 at node-9
# seqno :5120, pkt-type=BundlePacket, receive at time-746.701 at node-5, transmit at time-746.699 at node-0
# seqno :4960, pkt-type=BundlePacket, receive at time-523.213 at node-4, transmit at time-523.199 at node-3
# seqno :4960, pkt-type=BundlePacket, receive at time-622.209 at node-5, transmit at time-622.199 at node-3
# seqno :4960, pkt-type=BundlePacket, receive at time-705.607 at node-0, transmit at time-705.599 at node-5
# ================ then we would try to find destination delivery in p_x_pkt_trace_map =========
# key is 692, cur_snap from-4, snap is2
# key is 692, cur_snap from-4, snap is4
# key is 692, cur_snap from-2, snap is2
# key is 528, cur_snap from-6, snap is1
# key is 528, cur_snap from-6, snap is4
# key is 528, cur_snap from-6, snap is5
# key is 528, cur_snap from-6, snap is6
# key is 528, cur_snap from-5, snap is1
# key is 528, cur_snap from-5, snap is4
# key is 528, cur_snap from-5, snap is5
# key is 528, cur_snap from-4, snap is1
# key is 528, cur_snap from-4, snap is4
# key is 2092, cur_snap from-4, snap is2
# key is 2092, cur_snap from-4, snap is4
# key is 2092, cur_snap from-2, snap is2
# key is 2303, cur_snap from-6, snap is6
# key is 2355, cur_snap from-2, snap is7
# key is 2355, cur_snap from-2, snap is4
# key is 2355, cur_snap from-2, snap is2
# key is 2571, cur_snap from-3, snap is3
# key is 3092, cur_snap from-6, snap is2
# key is 3092, cur_snap from-6, snap is5
# key is 3092, cur_snap from-6, snap is6
# key is 3092, cur_snap from-2, snap is2
# key is 601, cur_snap from-6, snap is6
# key is 5395, cur_snap from-3, snap is0
# key is 5395, cur_snap from-3, snap is2
# key is 5395, cur_snap from-3, snap is5
# key is 5395, cur_snap from-3, snap is3
# key is 5395, cur_snap from-5, snap is0
# key is 5395, cur_snap from-5, snap is2
# key is 5395, cur_snap from-5, snap is5
# key is 5395, cur_snap from-2, snap is0
# key is 5395, cur_snap from-2, snap is2
# key is 4779, cur_snap from-6, snap is4
# key is 4779, cur_snap from-6, snap is2
# key is 4779, cur_snap from-6, snap is6
# key is 4779, cur_snap from-2, snap is4
# key is 4779, cur_snap from-2, snap is2
# key is 5120, cur_snap from-0, snap is9
# key is 5120, cur_snap from-0, snap is0
# key is 5120, cur_snap from-9, snap is9
# key is 4960, cur_snap from-5, snap is4
# key is 4960, cur_snap from-5, snap is5
# ================ debug  p_x_pkt_trace_map 1=========
# {692: [[36.306, 2, 3, 1, 692, 13.82, 36.299, 'BundlePacket', False, 1], [163.809, 4, 3, 1, 692, 13.82, 163.799, 'BundlePacket', False, 2], [523.513, 3, 3, 1, 692, 13.82, 523.499, 'BundlePacket', True, 4]], 528: [[163.587, 4, 7, 2, 528, 10.576, 163.499, 'BundlePacket', False, 2], [243.313, 5, 7, 2, 528, 10.576, 243.299, 'BundlePacket', False, 4], [501.909, 6, 7, 2, 528, 10.576, 501.899, 'BundlePacket', False, 5], [545.709, 8, 7, 2, 528, 10.576, 545.699, 'BundlePacket', False, 6]], 2092: [[41.4039, 2, 5, 1, 2092, 40.906, 41.399, 'BundlePacket', False, 1], [164.109, 4, 5, 1, 2092, 40.906, 164.099, 'BundlePacket', False, 2], [244.203, 5, 5, 1, 2092, 40.906, 244.199, 'BundlePacket', True, 4]], 2303: [[45.3122, 6, 0, 3, 2303, 44.976, 45.299, 'BundlePacket', False, 3], [207.009, 0, 0, 3, 2303, 44.976, 206.999, 'BundlePacket', True, 6]], 2355: [[314.409, 2, 6, 5, 2355, 45.792, 314.399, 'BundlePacket', False, 5], [462.909, 6, 6, 5, 2355, 45.792, 462.899, 'BundlePacket', True, 2]], 2477: [[48.9104, 8, 8, 9, 2477, 48.118, 48.899, 'BundlePacket', True, 9]], 2571: [[50.1005, 3, 8, 6, 2571, 49.717, 50.099, 'BundlePacket', False, 6], [522.909, 4, 8, 6, 2571, 49.717, 522.899, 'BundlePacket', False, 3]], 3369: [[545.113, 6, 5, 8, 3369, 65.532, 545.099, 'BundlePacket', False, 8]], 3531: [[69.3005, 5, 5, 7, 3531, 68.712, 69.299, 'BundlePacket', True, 7]], 3560: [[69.6005, 8, 8, 9, 3560, 69.282, 69.599, 'BundlePacket', True, 9]], 4205: [[545.409, 6, 3, 8, 4205, 81.878, 545.399, 'BundlePacket', False, 8]], 5713: [[112.201, 1, 1, 2, 5713, 111.853, 112.199, 'BundlePacket', True, 2]], 3033: [[163.514, 2, 2, 4, 3033, 58.811, 163.499, 'BundlePacket', True, 4]], 3092: [[163.813, 2, 7, 4, 3092, 59.974, 163.799, 'BundlePacket', False, 4], [463.502, 6, 7, 4, 3092, 59.974, 463.499, 'BundlePacket', False, 2], [546.309, 8, 7, 4, 3092, 59.974, 546.299, 'BundlePacket', False, 6]], 601: [[206.711, 6, 2, 0, 601, 12.021, 206.699, 'BundlePacket', False, 0], [463.802, 2, 2, 0, 601, 12.021, 463.799, 'BundlePacket', True, 6]], 6030: [[746.108, 9, 9, 0, 6030, 117.981, 746.099, 'BundlePacket', True, 0]], 5395: [[463.503, 2, 4, 6, 5395, 105.528, 463.499, 'BundlePacket', False, 6], [490.501, 5, 4, 6, 5395, 105.528, 490.499, 'BundlePacket', False, 2], [622.81, 3, 4, 6, 5395, 105.528, 622.799, 'BundlePacket', False, 5], [623.401, 4, 4, 6, 5395, 105.528, 623.399, 'BundlePacket', True, 3]], 4779: [[315.003, 2, 8, 5, 4779, 93.212, 314.999, 'BundlePacket', False, 5], [462.612, 6, 8, 5, 4779, 93.212, 462.599, 'BundlePacket', False, 2], [545.108, 8, 8, 5, 4779, 93.212, 545.099, 'BundlePacket', True, 6]], 5120: [[414.313, 9, 8, 7, 5120, 99.989, 414.299, 'BundlePacket', False, 7], [746.408, 0, 8, 7, 5120, 99.989, 746.399, 'BundlePacket', False, 9], [746.701, 5, 8, 7, 5120, 99.989, 746.699, 'BundlePacket', False, 0]], 4960: [[622.209, 5, 0, 3, 4960, 96.841, 622.199, 'BundlePacket', False, 3], [705.607, 0, 0, 3, 4960, 96.841, 705.599, 'BundlePacket', True, 5]]}
# ================ debug  p_x_pkt_trace_map 1=========
# key exist
# there is one pkt don't arrive destination
# key exist
# key exist
# key exist
# key exist
# key exist
# key exist
# key exist
# there is one pkt don't arrive destination
# key exist
# key exist
# there is one pkt don't arrive destination
# key exist
# there is one pkt don't arrive destination
# key exist
# key exist
# key exist
# there is one pkt don't arrive destination
# key exist
# key exist
# key exist
# there is one pkt don't arrive destination
# key exist
# key exist
# key exist
# 14 / 20 arrived
# ====================== serialize to json format =====================
# ====================== print result in plain text =====================
# ==================
# pkt-seqno:528, trace is:
# from time-10.576 => time-163.499 in node-2
# from time-163.587 => time-243.299 in node-4
# from time-243.313 => time-501.899 in node-5
# from time-501.909 => time-545.699 in node-6
# received by node-8 at time-545.709, not destination :(
# not arrived destination
#
# schedule is: from node-2 to node-7 at time-10.576
# ==================
# pkt-seqno:601, trace is:
# from time-12.021 => time-206.699 in node-0
# from time-206.711 => time-463.799 in node-6
# received by node-2 at time-463.802 destination :)
# arrived destination
#
# schedule is: from node-0 to node-2 at time-12.021
# ==================
# pkt-seqno:692, trace is:
# from time-13.82 => time-36.299 in node-1
# from time-36.306 => time-163.799 in node-2
# from time-163.809 => time-523.499 in node-4
# received by node-3 at time-523.513 destination :)
# arrived destination
#
# schedule is: from node-1 to node-3 at time-13.82
# ==================
# pkt-seqno:2092, trace is:
# from time-40.906 => time-41.399 in node-1
# from time-41.4039 => time-164.099 in node-2
# from time-164.109 => time-244.199 in node-4
# received by node-5 at time-244.203 destination :)
# arrived destination
#
# schedule is: from node-1 to node-5 at time-40.906
# ==================
# pkt-seqno:2303, trace is:
# from time-44.976 => time-45.299 in node-3
# from time-45.3122 => time-206.999 in node-6
# received by node-0 at time-207.009 destination :)
# arrived destination
#
# schedule is: from node-3 to node-0 at time-44.976
# ==================
# pkt-seqno:2355, trace is:
# from time-45.792 => time-314.399 in node-5
# from time-314.409 => time-462.899 in node-2
# received by node-6 at time-462.909 destination :)
# arrived destination
#
# schedule is: from node-5 to node-6 at time-45.792
# ==================
# pkt-seqno:2477, trace is:
# from time-48.118 => time-48.899 in node-9
# received by node-8 at time-48.9104 destination :)
# arrived destination
#
# schedule is: from node-9 to node-8 at time-48.118
# ==================
# pkt-seqno:2571, trace is:
# from time-49.717 => time-50.099 in node-6
# from time-50.1005 => time-522.899 in node-3
# received by node-4 at time-522.909, not destination :(
# not arrived destination
#
# schedule is: from node-6 to node-8 at time-49.717
# ==================
# pkt-seqno:3033, trace is:
# from time-58.811 => time-163.499 in node-4
# received by node-2 at time-163.514 destination :)
# arrived destination
#
# schedule is: from node-4 to node-2 at time-58.811
# ==================
# pkt-seqno:3092, trace is:
# from time-59.974 => time-163.799 in node-4
# from time-163.813 => time-463.499 in node-2
# from time-463.502 => time-546.299 in node-6
# received by node-8 at time-546.309, not destination :(
# not arrived destination
#
# schedule is: from node-4 to node-7 at time-59.974
# ==================
# pkt-seqno:3369, trace is:
# from time-65.532 => time-545.099 in node-8
# received by node-6 at time-545.113, not destination :(
# not arrived destination
#
# schedule is: from node-8 to node-5 at time-65.532
# ==================
# pkt-seqno:3531, trace is:
# from time-68.712 => time-69.299 in node-7
# received by node-5 at time-69.3005 destination :)
# arrived destination
#
# schedule is: from node-7 to node-5 at time-68.712
# ==================
# pkt-seqno:3560, trace is:
# from time-69.282 => time-69.599 in node-9
# received by node-8 at time-69.6005 destination :)
# arrived destination
#
# schedule is: from node-9 to node-8 at time-69.282
# ==================
# pkt-seqno:4205, trace is:
# from time-81.878 => time-545.399 in node-8
# received by node-6 at time-545.409, not destination :(
# not arrived destination
#
# schedule is: from node-8 to node-3 at time-81.878
# ==================
# pkt-seqno:4779, trace is:
# from time-93.212 => time-314.999 in node-5
# from time-315.003 => time-462.599 in node-2
# from time-462.612 => time-545.099 in node-6
# received by node-8 at time-545.108 destination :)
# arrived destination
#
# schedule is: from node-5 to node-8 at time-93.212
# ==================
# pkt-seqno:4960, trace is:
# from time-96.841 => time-622.199 in node-3
# from time-622.209 => time-705.599 in node-5
# received by node-0 at time-705.607 destination :)
# arrived destination
#
# schedule is: from node-3 to node-0 at time-96.841
# ==================
# pkt-seqno:5120, trace is:
# from time-99.989 => time-414.299 in node-7
# from time-414.313 => time-746.399 in node-9
# from time-746.408 => time-746.699 in node-0
# received by node-5 at time-746.701, not destination :(
# not arrived destination
#
# schedule is: from node-7 to node-8 at time-99.989
# ==================
# pkt-seqno:5395, trace is:
# from time-105.528 => time-463.499 in node-6
# from time-463.503 => time-490.499 in node-2
# from time-490.501 => time-622.799 in node-5
# from time-622.81 => time-623.399 in node-3
# received by node-4 at time-623.401 destination :)
# arrived destination
#
# schedule is: from node-6 to node-4 at time-105.528
# ==================
# pkt-seqno:5713, trace is:
# from time-111.853 => time-112.199 in node-2
# received by node-1 at time-112.201 destination :)
# arrived destination
#
# schedule is: from node-2 to node-1 at time-111.853
# ==================
# pkt-seqno:6030, trace is:
# from time-117.981 => time-746.099 in node-0
# received by node-9 at time-746.108 destination :)
# arrived destination
#
# schedule is: from node-0 to node-9 at time-117.981
# {528: [10.576, 2, 163.499, 163.587, 4, 243.299, 243.313, 5, 501.899, 501.909, 6, 545.699, 545.709, 8], 601: [12.021, 0, 206.699, 206.711, 6, 463.799, 463.802, 2, 802.0], 692: [13.82, 1, 36.299, 36.306, 2, 163.799, 163.809, 4, 523.499, 523.513, 3, 802.0], 2092: [40.906, 1, 41.399, 41.4039, 2, 164.099, 164.109, 4, 244.199, 244.203, 5, 802.0], 2303: [44.976, 3, 45.299, 45.3122, 6, 206.999, 207.009, 0, 802.0], 2355: [45.792, 5, 314.399, 314.409, 2, 462.899, 462.909, 6, 802.0], 2477: [48.118, 9, 48.899, 48.9104, 8, 802.0], 2571: [49.717, 6, 50.099, 50.1005, 3, 522.899, 522.909, 4], 3033: [58.811, 4, 163.499, 163.514, 2, 802.0], 3092: [59.974, 4, 163.799, 163.813, 2, 463.499, 463.502, 6, 546.299, 546.309, 8], 3369: [65.532, 8, 545.099, 545.113, 6], 3531: [68.712, 7, 69.299, 69.3005, 5, 802.0], 3560: [69.282, 9, 69.599, 69.6005, 8, 802.0], 4205: [81.878, 8, 545.399, 545.409, 6], 4779: [93.212, 5, 314.999, 315.003, 2, 462.599, 462.612, 6, 545.099, 545.108, 8, 802.0], 4960: [96.841, 3, 622.199, 622.209, 5, 705.599, 705.607, 0, 802.0], 5120: [99.989, 7, 414.299, 414.313, 9, 746.399, 746.408, 0, 746.699, 746.701, 5], 5395: [105.528, 6, 463.499, 463.503, 2, 490.499, 490.501, 5, 622.799, 622.81, 3, 623.399, 623.401, 4, 802.0], 5713: [111.853, 2, 112.199, 112.201, 1, 802.0], 6030: [117.981, 0, 746.099, 746.108, 9, 802.0]}
# ================================= dividing ========================
# <img src="data:image/png;base64,..." width="640">
# colors count=20
# len of seqno_number_list=20
# range(0, 20)
