# %%
# %matplotlib notebook
import re
import sys
import inspect
from math import sqrt
import numpy as np
from scipy import integrate
from matplotlib import pyplot as plt
import matplotlib as mpl
from matplotlib import cm
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import cnames
from matplotlib import animation
#==================================
# This parse script won't parse sprayandwait yet, would cause mass
##################
# define handy func
def nums(s):
    try:
        return int(s)
    except ValueError:
        return float(s)
################
#====
# read the result file
simulation_result_file = open("../../box/dtn_simulation_result/dtnrunninglog.txt", "r")
lines = simulation_result_file.readlines();
simulation_result_file.close()
#====
x_is_one_delivery_route = False
x_simulation_time = -1
x_nodes = -1
x_sch_n = -1
x_arrive_n = 0
x_schedule_list = [] # element is also a list[source, time, destination, seqno]
x_pkt_trace_map = {} # seqno -> [one_hop_snap, one_hop_snap... destination_snap]
# hop_snap , destination_snap = 
#[receive_time, receive_id, dest_id, source_id, seqno, src_generate_time, hop_transmit_time, pkt_type, is_dst, hop_id]
############
# define
def snap_print(snap) :
    print('''seqno :{0}, pkt-type={4}, receive at time-{1} at node-{2}, transmit at time-{3} at node-{5}'''
          .format(snap[4], snap[0], snap[1], snap[6], snap[7], snap[9]))
#############
test_string = r'Here In DtnExampleInterface::ReportExBundleTrace:node_number_=5;simulation_duration_=802'
r11 = re.compile(r'BundleTrace:node_number_=(\d+\.*\d*);simulation_duration_=(\d+\.*\d*)', re.VERBOSE)
test_regx = r11.search(test_string)
if test_regx :
    print("good0")
else :
    print("bad0")
    sys.exit()
    
strss = "[time-5.40052;node-1;line-638]NOTE:BundleTrace:good! one bun\
dle recept, it's one hop! bp_header=,destination ip=10.0.0.3,sour\
ce ip=10.0.0.1,source seqno=139,payload size=345,offset size=345,src time sta\
mp=5,hop time stamp=5,bundle type=BundlePacket"
r22 = re.compile(r'\[time-(\d+\.*\d*);node-(\d+\.*\d*);line-(\d+\.*\d*)\]NOTE:BundleTr\
ace:good!\sone\sbundle\srecept,\sit\'s\sone\shop!\sbp_header=,destination\sip=10.0.0.(\d+\.*\d*),sou\
rce\sip=10.0.0.(\d+\.*\d*),source\sseqno=(\d+\.*\d*),payload\ssize=(\d+\.*\d*),offset\ssi\
ze=(\d+\.*\d*),src\stime\sstamp=(\d+\.*\d*),hop\stime\sstamp=(\d+\.*\d*),bundle\stype=([a-zA-Z]+)', re.VERBOSE)
hopt = r22.match(strss)
if hopt :
    print("good1")
else :
    print("bad1")
    sys.exit()
    
#================================================ dividing parse ========================================
# parse for x_ nodes and x_ simualtion_time
# parse for bundle trace and schedule
avoid_log_twice_bug = False
for line in lines :
    #In DtnExampleRunner
    r0 = re.compile(r'In\sDtnExampleRunner', re.VERBOSE)
    parse_begin = r0.search(line)
    if parse_begin :
        avoid_log_twice_bug = True
        continue
    elif avoid_log_twice_bug :
        # do nothing
        onenomeaning = 1
    else :
        continue
    
    #BundleTrace:node_number_=5;simulation_duration_=802
    r1 = re.compile(r'BundleTrace:node_number_=(\d+\.*\d*);simulation_duration_=(\d+\.*\d*)', re.VERBOSE)
    simulation_preview = r1.search(line)
    
    #[time-5.40052;node-1;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.3,source ip=10.0.0.1,source seqno=139,payload size=345,offset size=345,src time stamp=5,hop time stamp=5,bundle type=BundlePacket
    r2 = re.compile(r'''\[time\-(\d+\.*\d*);node\-(\d+\.*\d*);line\-(\d+\.*\d*)\]NOTE:BundleTrace:go
    od!\sone\sbundle\srecept\,\sit\'s\sone\shop!\sbp_header=\,destination\sip=10\.0\.0\.(\d+\.*\d*)\,sour
    ce\sip=10\.0\.0\.(\d+\.*\d*)\,source\sseqno=(\d+\.*\d*)\,payload\ssize=(\d+\.*\d*)\,offset\ssiz
    e=(\d+\.*\d*)\,src\stime\sstamp=(\d+\.*\d*)\,hop\stime\ssta
    mp=(\d+\.*\d*)\,hop\sip=10\.0\.0\.(\d+\.*\d*)\,bundle\stype=([a-zA-Z]+)''', re.VERBOSE)
    hop = r2.search(line)
    
    #[time-3.30744;node-1;line-630]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.2,source ip=10.0.0.1,source seqno=75,payload size=345,offset size=345,src time stamp=3,hop time stamp=3,bundle type=BundlePacket
    r3 = re.compile(r'''\[time\-(\d+\.*\d*);node\-(\d+\.*\d*);line\-(\d+\.*\d*)\]NOTE:BundleTrace:Great!\son
    e\sbundle\sarrive\sdestination!\sbp_header=\,destination\sip=10\.0\.0\.(\d+\.*\d*)\,so
    urce\sip=10\.0\.0\.(\d+\.*\d*)\,source\sseqno=(\d+\.*\d*)\,payload\ssize=(\d+\.*\d*)\,offset\ss
    ize=(\d+\.*\d*)\,src\stime\sstamp=(\d+\.*\d*)\,hop\stime\ssta
    mp=(\d+\.*\d*),hop\sip=10\.0\.0\.(\d+\.*\d*)\,bundle\stype=([a-zA-Z]+)''', re.VERBOSE)
    destination = r3.search(line)
    
    #[time-0;node-0;line-1553]enter ScheduleTx(), time-+3000000000.0ns,size=345, to node-1
    r4 = re.compile(r'''node\-(\d+\.*\d*);line\-(\d+\.*\d*)]enter\sScheduleTx\(\)\,\sti
    me\-\+(\d+\.*\d*)ns\,size=(\d+\.*\d*)\,\sto\snode\-(\d+\.*\d*)''', re.VERBOSE)
    schedule = r4.search(line)
    
    #BundleTrace:Itisonedeliverymethon
    r5 = re.compile(r'''BundleTrace:Itisonedeliverymethon''', re.VERBOSE)
    isonedelivery = r5.search(line)
    
    if schedule :
        print(line)
        sche_source = int(nums(schedule.group(1)))
        sche_time = float(nums(schedule.group(3)) / 1000000000.0)
        sche_destination = int(nums(schedule.group(5)))
        tmp = [sche_source, sche_time, sche_destination, -1]
        x_schedule_list.append(tmp)
    elif isonedelivery :
        x_is_one_delivery_route = True
    elif hop :
        print(line)
        hop_receive_time = float(nums(hop.group(1)))
        hop_receive_id = int(nums(hop.group(2)))
        hop_dest_id = int(nums(hop.group(4)) - int(1))
        hop_source_id = int(nums(hop.group(5)) - int(1))
        hop_seqno = int(nums(hop.group(6)))
        hop_src_generate_time = float(nums(hop.group(9))) # TODO
        hop_hop_transmit_time = float(nums(hop.group(10)))
        hop_hop_id = int(nums(hop.group(11)) - int(1))
        hop_pkt_type = hop.group(12)
        if (hop_hop_transmit_time > hop_receive_time) :
            print('receive time:{0} should < hop_transmit time{1}'.format(hop_receive_time, hop_hop_transmit_time))
            sys.exit()
        tmp = [hop_receive_time, hop_receive_id, hop_dest_id, hop_source_id, hop_seqno,
               hop_src_generate_time, hop_hop_transmit_time, hop_pkt_type, False, hop_hop_id]
        if hop_seqno in x_pkt_trace_map.keys():
            old_list = x_pkt_trace_map[hop_seqno]
            old_list.append(tmp)
            old_list.sort(key=lambda tup: tup[0])
            x_pkt_trace_map[hop_seqno] = old_list
        else:
            new_list = []
            new_list.append(tmp)
            x_pkt_trace_map[hop_seqno] = new_list
    elif simulation_preview :
        print(line)
        x_nodes = int(simulation_preview.group(1))
        x_simulation_time = float(simulation_preview.group(2))
    elif destination :
        print(line)
        dst_receive_time = float(nums(destination.group(1)))
        dst_receive_id = int(nums(destination.group(2)))
        dst_dst_id = int(nums(destination.group(4)) - int(1))
        dst_src_id = int(nums(destination.group(5)) - int(1))
        dst_seqno = int(nums(destination.group(6)))
        dst_src_generate_time = float(nums(destination.group(9)))
        dst_hop_transmit_time = float(nums(destination.group(10)))
        dst_hop_id = int(nums(destination.group(11)) - int(1))
        dst_pkt_type = destination.group(12)
        if (dst_hop_transmit_time > dst_receive_time) :
            print('receive time')
            sys.exit()
        tmp = [dst_receive_time, dst_receive_id, dst_dst_id, dst_src_id, dst_seqno,
               dst_src_generate_time, dst_hop_transmit_time, dst_pkt_type, True, dst_hop_id]
        if dst_seqno in x_pkt_trace_map.keys() :
            old_list = x_pkt_trace_map[dst_seqno]
            old_list.append(tmp)
            old_list.sort(key=lambda tup: tup[0])
            x_pkt_trace_map[dst_seqno] = old_list
        else :
            new_list = []
            new_list.append(tmp)
            x_pkt_trace_map[dst_seqno] = new_list
            
#========================================= end of parse ===================================================

print(r'============= dividing end of parse =============')
if (x_nodes == -1) or (x_simulation_time == -1) :
    print('error_04')
    sys.exit()
#================ now we have every thing we need, refine the data and prepare for visualization
#===== refine x_schedule_list
for sch in x_schedule_list :
    sk = [sch[0], sch[1], sch[2]] # s, t, d
    sn = sch[3]
    if sn != -1 :
        print('error_03')
        sys.exit()
    for key, value in x_pkt_trace_map.items() : #
        #print('value len={0}'.format(len(value)))
        #print(value)
        tk = [value[0][3], value[0][5], value[0][2]]
        seqno = value[0][4]
        if (tk[0] == sk[0] and tk[2] == sk[2] and tk[1] - sk[1] < 0.01) :
            sn = seqno
            break
    if (sn != -1) :
        sch[3] = sn
    else :
        print('error_05')
        sys.exit()
x_sch_n = len(x_schedule_list)

print('============= \n === print your schedule')
print(x_schedule_list)
#===================================== get graph needed list
#
#                                                                                    dstination
x_time_trace_map = {} # seqno -> [src_t, sr_id, hop_t, rec_t, rec_id, hop_t, ... , rec_t, rec_id, x_simulation_time]
####################
#definition
def get_x_time_trace_map(p_x_time_trace_map, p_x_schedule_list, p_x_pkt_trace_map, ref_x_arrive_n) :
    ref_x_arrive_n = 0
    if x_is_one_delivery_route :
        for sch in p_x_schedule_list :
            src_t = sch[1]
            seqno = sch[3]
            if seqno == -1 :
                print('error_01')
                sys.exit()
            sr_id = sch[0]
            tmp = []
            tmp.extend([src_t, sr_id])
            for trace in p_x_pkt_trace_map[seqno] :
                if trace[4] != seqno :
                    print('error_02')
                    sys.exit()
                is_dst = bool(trace[8])
                hop_t = trace[6]
                rec_t = trace[0]
                rec_id = trace[1]
                tmp.extend([hop_t, rec_t, rec_id])
                if is_dst :
                    tmp.append(x_simulation_time)
            if len(tmp) % 3 == 0 :
                ref_x_arrive_n += 1
                p_x_time_trace_map[seqno] = tmp 
            else :
                print('there is one pkt don\'t arrive destination')
                p_x_time_trace_map[seqno] = tmp
    else :
        print('if not one delivery route, this would cause one seqno -> multiply path, it\'s hard to parse, would\
        do this latter')
        print('============ print all hop snap and end ==============')
        for key, snaps in p_x_pkt_trace_map.items() :
            for snap in snaps :
                snap_print(snap)
        print('normal exit')
        sys.exit()
    return ref_x_arrive_n
#end of definition
#################################
x_arrive_n = get_x_time_trace_map(x_time_trace_map, x_schedule_list, x_pkt_trace_map, x_arrive_n)
#===== gonna to make graph|
print('===================================================================================================\
\n===================== report parse result ================')
title_str = '{0} / {1} arrived'.format(x_arrive_n, x_sch_n)
#print(x_time_trace_map)
print(title_str)
###############
# define
def handy_print_2(seqno) :
    for xs in x_schedule_list :
        if xs[3] == seqno :
            print('schedule is: from node-{0} to node-{1} at time-{2}'.format(xs[0], xs[2], xs[1]))
            break
def handy_print_0(st, et, nid) :
    print('from time-{0} => time-{1} in node-{2}'.format(st, et, nid))
def handy_print_1(key, value) :
    print('==================\npkt-seqno:{0}, trace is: '.format(key))
    n_v = int(len(value) / 3)
    is_arrived_traffic = False
    if (n_v * 3 == len(value)) :
        is_arrived_traffic = True
    if (is_arrived_traffic) :
        for cur in range(0, n_v, 1) :
            if cur == n_v - 1 :
                print('received by node-{1} at time-{0} destination :)'.format(value[cur * 3], value[cur * 3 + 1]))
            else :
                handy_print_0(value[cur * 3], value[cur * 3 + 2], value[cur * 3 + 1])
        print('arrived destination\n')
    else :
        for cur in range(0, n_v + 1, 1) :
            if cur == n_v :
                print('received by node-{1} at time-{0}, not destination :('.format(value[cur * 3], value[cur * 3 + 1]))
            else :
                handy_print_0(value[cur * 3], value[cur * 3 + 2], value[cur * 3 + 1])
        print('not arrived destination\n')
    handy_print_2(key)
def handy_draw_0(ax0, st, et, nid, seqnoindex, c) :
    dx = et - st
    ax0.bar3d(st, seqnoindex, nid, dx, 0.2, 0.2, alpha=0.1, color=c, linewidth=0) # alpha = abs(dz[i]/max(dz))
###################################

for key, value in x_time_trace_map.items() :
    handy_print_1(key, value)
print(x_time_trace_map)
#===============
fig = plt.figure()
ax = fig.gca(projection='3d')
colors = plt.cm.jet(np.linspace(0, 1, len(x_schedule_list)))
seqno_number_list = []
for xsele in x_schedule_list :
    seqno_number_list.append(xsele[3])

#=======    
print('colors count={0}'.format(len(colors)))
print('len of seqno_number_list={0}'.format(len(seqno_number_list)))
print(range(0, len(seqno_number_list), 1))

for c, zseqnoindex in zip(colors, range(0, len(seqno_number_list), 1)):
    this_seqno_no = seqno_number_list[zseqnoindex]
    trace_list_of_seqno = x_time_trace_map[this_seqno_no]
    rt_count = int(len(trace_list_of_seqno) / 3)
    is_arrived_traffic_0 = False
    if (rt_count * 3 == len(trace_list_of_seqno)) :
        is_arrived_traffic_0 = True
        
    if is_arrived_traffic_0 :
        for cur in range(0, rt_count, 1) :
            if cur == rt_count - 1 :
                handy_draw_0(ax, trace_list_of_seqno[cur * 3], trace_list_of_seqno[cur * 3 + 2], \
                             trace_list_of_seqno[cur * 3 + 1], zseqnoindex, c)
                ax.text(x_simulation_time, zseqnoindex, 0\
                        , 'arrived! seqno={0}'.format(seqno_number_list[zseqnoindex]), 'x')
            else :
                handy_draw_0(ax, trace_list_of_seqno[cur * 3], trace_list_of_seqno[cur * 3 + 2], \
                             trace_list_of_seqno[cur * 3 + 1], zseqnoindex, c)
    else :
        for cur in range(0, rt_count + 1, 1) :
            if cur == rt_count :
                handy_draw_0(ax, trace_list_of_seqno[cur * 3], trace_list_of_seqno[cur * 3] + 1, \
                             trace_list_of_seqno[cur * 3 + 1], zseqnoindex, c)
                ax.text(x_simulation_time, zseqnoindex, 0\
                        , 'missed! seqno={0}'.format(seqno_number_list[zseqnoindex]), 'x')
            else :
                handy_draw_0(ax, trace_list_of_seqno[cur * 3], trace_list_of_seqno[cur * 3 + 2], \
                             trace_list_of_seqno[cur * 3 + 1], zseqnoindex, c)
#======
ax.set_xlabel('time')
#ax.set_ylabel('')
ax.set_zlabel('node')
plt.show()
#==================
# Out:
# good0
# good1
# Here In DtnExampleInterface::ReportExBundleTrace:node_number_=10;simulation_duration_=802
#
# [time-0;node-0;line-1560]enter ScheduleTx(), time-+12021325669.0ns,size=345, to node-2
#
# [time-0;node-0;line-1560]enter ScheduleTx(), time-+117981550363.0ns,size=345, to node-9
#
# [time-0;node-0;line-1560]enter ScheduleTx(), time-+94020478268.0ns,size=345, to node-3
#
# [time-0;node-1;line-1560]enter ScheduleTx(), time-+806334457.0ns,size=345, to node-5
#
# [time-0;node-1;line-1560]enter ScheduleTx(), time-+50676573125.0ns,size=345, to node-7
#
# [time-0;node-1;line-1560]enter ScheduleTx(), time-+85401015942.0ns,size=345, to node-8
#
# [time-0;node-2;line-1560]enter ScheduleTx(), time-+3409505929.0ns,size=345, to node-5
#
# [time-0;node-2;line-1560]enter ScheduleTx(), time-+96930379408.0ns,size=345, to node-7
#
# [time-0;node-2;line-1560]enter ScheduleTx(), time-+100785055403.0ns,size=345, to node-7
#
# [time-0;node-3;line-1560]enter ScheduleTx(), time-+55296858285.0ns,size=345, to node-2
#
# [time-0;node-3;line-1560]enter ScheduleTx(), time-+107558250247.0ns,size=345, to node-5
#
# [time-0;node-3;line-1560]enter ScheduleTx(), time-+147199292754.0ns,size=345, to node-6
#
# [time-0;node-4;line-1560]enter ScheduleTx(), time-+49408970033.0ns,size=345, to node-6
#
# [time-0;node-4;line-1560]enter ScheduleTx(), time-+73305762111.0ns,size=345, to node-6
#
# [time-0;node-4;line-1560]enter ScheduleTx(), time-+125951311731.0ns,size=345, to node-8
#
# [time-0;node-5;line-1560]enter ScheduleTx(), time-+66392541120.0ns,size=345, to node-8
#
# [time-0;node-5;line-1560]enter ScheduleTx(), time-+86198989425.0ns,size=345, to node-7
#
# [time-0;node-5;line-1560]enter ScheduleTx(), time-+107952914708.0ns,size=345, to node-8
#
# [time-0;node-6;line-1560]enter ScheduleTx(), time-+67355142078.0ns,size=345, to node-5
#
# [time-0;node-6;line-1560]enter ScheduleTx(), time-+112228687082.0ns,size=345, to node-5
#
# [time-0;node-6;line-1560]enter ScheduleTx(), time-+88662378134.0ns,size=345, to node-3
#
# [time-0;node-7;line-1560]enter ScheduleTx(), time-+35567730150.0ns,size=345, to node-5
#
# [time-0;node-7;line-1560]enter ScheduleTx(), time-+48239575273.0ns,size=345, to node-1
#
# [time-0;node-7;line-1560]enter ScheduleTx(), time-+151540515515.0ns,size=345, to node-0
#
# [time-0;node-8;line-1560]enter ScheduleTx(), time-+66928350315.0ns,size=345, to node-9
#
# [time-0;node-8;line-1560]enter ScheduleTx(), time-+80856541053.0ns,size=345, to node-5
#
# [time-0;node-8;line-1560]enter ScheduleTx(), time-+149828988053.0ns,size=345, to node-4
#
# [time-0;node-9;line-1560]enter ScheduleTx(), time-+67409707327.0ns,size=345, to node-1
#
# [time-0;node-9;line-1560]enter ScheduleTx(), time-+71512551808.0ns,size=345, to node-7
#
# [time-0;node-9;line-1560]enter ScheduleTx(), time-+151043038945.0ns,size=345, to node-8
#
# [time-1.50609;node-7;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.2,source seqno=40,payload size=345,offset size=345,src time stamp=0.806334,hop time stamp=1.5,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-2.11369;node-5;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.2,source seqno=40,payload size=345,offset size=345,src time stamp=0.806334,hop time stamp=2.1,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-3.91378;node-3;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.3,source seqno=196,payload size=345,offset size=345,src time stamp=3.40951,hop time stamp=3.9,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-4.50813;node-9;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.3,source seqno=196,payload size=345,offset size=345,src time stamp=3.40951,hop time stamp=0.205033,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-5.11094;node-5;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.3,source seqno=196,payload size=345,offset size=345,src time stamp=3.40951,hop time stamp=0.805033,hop ip=10.0.0.10,bundle type=BundlePacket
#
# [time-36.0005;node-5;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.8,source seqno=1878,payload size=345,offset size=345,src time stamp=1.20799,hop time stamp=1.64026,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-48.3005;node-1;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.2,source ip=10.0.0.8,source seqno=2519,payload size=345,offset size=345,src time stamp=0.994935,hop time stamp=1.05536,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-51.0005;node-7;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.2,source seqno=2648,payload size=345,offset size=345,src time stamp=3.43193,hop time stamp=3.75536,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-55.8005;node-2;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.3,source ip=10.0.0.4,source seqno=2886,payload size=345,offset size=345,src time stamp=3.75725,hop time stamp=4.26039,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-57.3112;node-5;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.3,source ip=10.0.0.1,source seqno=700,payload size=345,offset size=345,src time stamp=3.43139,hop time stamp=1.46542,hop ip=10.0.0.1,bundle type=BundlePacket
#
# [time-57.91;node-4;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.3,source ip=10.0.0.1,source seqno=700,payload size=345,offset size=345,src time stamp=3.43139,hop time stamp=2.06542,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-66.6005;node-4;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.6,source seqno=3496,payload size=345,offset size=345,src time stamp=1.96803,hop time stamp=2.17549,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-67.5108;node-2;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.7,source seqno=3547,payload size=345,offset size=345,src time stamp=2.93063,hop time stamp=3.07549,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-67.806;node-1;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.7,source seqno=3547,payload size=345,offset size=345,src time stamp=2.93063,hop time stamp=3.37549,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-82.5072;node-1;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.10,source ip=10.0.0.9,source seqno=3523,payload size=345,offset size=345,src time stamp=2.50384,hop time stamp=0.895621,hop ip=10.0.0.9,bundle type=BundlePacket
#
# [time-82.8039;node-1;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.9,source seqno=4243,payload size=345,offset size=345,src time stamp=3.54713,hop time stamp=1.19562,hop ip=10.0.0.9,bundle type=BundlePacket
#
# [time-83.1005;node-2;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.10,source ip=10.0.0.9,source seqno=3523,payload size=345,offset size=345,src time stamp=2.50384,hop time stamp=1.49562,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-83.7005;node-6;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.10,source ip=10.0.0.9,source seqno=3523,payload size=345,offset size=345,src time stamp=2.50384,hop time stamp=2.09562,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-84.0142;node-3;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.10,source ip=10.0.0.9,source seqno=3523,payload size=345,offset size=345,src time stamp=2.50384,hop time stamp=2.39562,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-85.8039;node-8;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.2,source seqno=4536,payload size=345,offset size=345,src time stamp=3.79664,hop time stamp=4.19562,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-86.7005;node-4;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.6,source seqno=4581,payload size=345,offset size=345,src time stamp=0.299644,hop time stamp=0.800654,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-89.1005;node-3;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.4,source ip=10.0.0.7,source seqno=4709,payload size=345,offset size=345,src time stamp=2.76303,hop time stamp=3.20065,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-94.2082;node-4;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.4,source ip=10.0.0.1,source seqno=4987,payload size=345,offset size=345,src time stamp=3.82617,hop time stamp=4.00569,hop ip=10.0.0.1,bundle type=BundlePacket
#
# [time-94.8039;node-3;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.2,source ip=10.0.0.10,source seqno=3552,payload size=345,offset size=345,src time stamp=2.9852,hop time stamp=0.310719,hop ip=10.0.0.10,bundle type=BundlePacket
#
# [time-95.1082;node-3;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.10,source seqno=3773,payload size=345,offset size=345,src time stamp=2.79308,hop time stamp=0.610719,hop ip=10.0.0.10,bundle type=BundlePacket
#
# [time-95.1131;node-9;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.10,source ip=10.0.0.9,source seqno=3523,payload size=345,offset size=345,src time stamp=2.50384,hop time stamp=0.610719,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-95.4005;node-6;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.2,source ip=10.0.0.10,source seqno=3552,payload size=345,offset size=345,src time stamp=2.9852,hop time stamp=0.910719,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-95.7005;node-6;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.10,source seqno=3773,payload size=345,offset size=345,src time stamp=2.79308,hop time stamp=1.21072,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-96.0005;node-2;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.2,source ip=10.0.0.10,source seqno=3552,payload size=345,offset size=345,src time stamp=2.9852,hop time stamp=1.51072,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-96.3103;node-1;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.5,source seqno=2587,payload size=345,offset size=345,src time stamp=2.16433,hop time stamp=1.81072,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-96.3153;node-7;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.10,source seqno=3773,payload size=345,offset size=345,src time stamp=2.79308,hop time stamp=1.81072,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-96.3861;node-4;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.9,source seqno=4243,payload size=345,offset size=345,src time stamp=3.54713,hop time stamp=1.81072,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-96.6083;node-4;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.7,source seqno=3547,payload size=345,offset size=345,src time stamp=2.93063,hop time stamp=2.11072,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-96.6191;node-1;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.2,source ip=10.0.0.10,source seqno=3552,payload size=345,offset size=345,src time stamp=2.9852,hop time stamp=2.11072,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-96.6239;node-1;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.3,source ip=10.0.0.1,source seqno=700,payload size=345,offset size=345,src time stamp=3.43139,hop time stamp=2.11072,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-96.9047;node-2;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.5,source seqno=2587,payload size=345,offset size=345,src time stamp=2.16433,hop time stamp=2.41072,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-96.909;node-1;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.6,source seqno=3496,payload size=345,offset size=345,src time stamp=1.96803,hop time stamp=2.41072,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-97.2052;node-2;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.3,source ip=10.0.0.1,source seqno=700,payload size=345,offset size=345,src time stamp=3.43139,hop time stamp=2.71072,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-97.2097;node-1;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.5,source seqno=3863,payload size=345,offset size=345,src time stamp=0.291318,hop time stamp=2.71072,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-97.5005;node-8;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.6,source seqno=3496,payload size=345,offset size=345,src time stamp=1.96803,hop time stamp=3.01072,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-97.5026;node-6;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.5,source seqno=2587,payload size=345,offset size=345,src time stamp=2.16433,hop time stamp=3.01072,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-97.5104;node-1;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.6,source seqno=4581,payload size=345,offset size=345,src time stamp=0.299644,hop time stamp=3.01072,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-97.8005;node-2;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.5,source seqno=3863,payload size=345,offset size=345,src time stamp=0.291318,hop time stamp=3.31072,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-97.809;node-1;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.4,source ip=10.0.0.1,source seqno=4987,payload size=345,offset size=345,src time stamp=3.82617,hop time stamp=3.31072,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-97.8224;node-7;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.3,source seqno=5311,payload size=345,offset size=345,src time stamp=2.4411,hop time stamp=3.31072,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-98.1027;node-6;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.5,source seqno=3863,payload size=345,offset size=345,src time stamp=0.291318,hop time stamp=3.61072,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-98.1035;node-2;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.6,source seqno=4581,payload size=345,offset size=345,src time stamp=0.299644,hop time stamp=3.61072,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-98.1064;node-0;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.9,source seqno=4243,payload size=345,offset size=345,src time stamp=3.54713,hop time stamp=3.61072,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-98.4005;node-7;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.6,source seqno=4581,payload size=345,offset size=345,src time stamp=0.299644,hop time stamp=3.91072,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-98.4005;node-0;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.7,source seqno=3547,payload size=345,offset size=345,src time stamp=2.93063,hop time stamp=3.91072,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-98.4043;node-2;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.4,source ip=10.0.0.1,source seqno=4987,payload size=345,offset size=345,src time stamp=3.82617,hop time stamp=3.91072,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-98.702;node-6;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.4,source ip=10.0.0.1,source seqno=4987,payload size=345,offset size=345,src time stamp=3.82617,hop time stamp=4.21072,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-98.7039;node-5;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.9,source seqno=4243,payload size=345,offset size=345,src time stamp=3.54713,hop time stamp=4.21072,hop ip=10.0.0.1,bundle type=BundlePacket
#
# [time-99.0005;node-5;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.7,source seqno=3547,payload size=345,offset size=345,src time stamp=2.93063,hop time stamp=0.215752,hop ip=10.0.0.1,bundle type=BundlePacket
#
# [time-99.0005;node-3;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.4,source ip=10.0.0.1,source seqno=4987,payload size=345,offset size=345,src time stamp=3.82617,hop time stamp=0.215752,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-100.801;node-7;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.3,source seqno=5698,payload size=345,offset size=345,src time stamp=2.00081,hop time stamp=2.01575,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-112.501;node-3;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.7,source seqno=6405,payload size=345,offset size=345,src time stamp=0.559537,hop time stamp=0.83085,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-120.908;node-9;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.10,source ip=10.0.0.1,source seqno=6698,payload size=345,offset size=345,src time stamp=2.01743,hop time stamp=0.640915,hop ip=10.0.0.1,bundle type=BundlePacket
#
# [time-147.601;node-6;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.7,source ip=10.0.0.4,source seqno=8209,payload size=345,offset size=345,src time stamp=1.1704,hop time stamp=1.57111,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-150.301;node-1;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.5,source ip=10.0.0.9,source seqno=8347,payload size=345,offset size=345,src time stamp=3.8001,hop time stamp=4.27111,hop ip=10.0.0.9,bundle type=BundlePacket
#
# [time-151.201;node-3;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.10,source seqno=8411,payload size=345,offset size=345,src time stamp=0.719184,hop time stamp=0.876144,hop ip=10.0.0.10,bundle type=BundlePacket
#
# [time-197.709;node-2;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.5,source seqno=7144,payload size=345,offset size=345,src time stamp=1.39726,hop time stamp=0.131504,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-198.302;node-6;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.5,source seqno=7144,payload size=345,offset size=345,src time stamp=1.39726,hop time stamp=0.731504,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-215.11;node-5;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.4,source seqno=6169,payload size=345,offset size=345,src time stamp=0.184068,hop time stamp=0.351634,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-215.404;node-5;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.6,source ip=10.0.0.7,source seqno=6405,payload size=345,offset size=345,src time stamp=0.559537,hop time stamp=0.651634,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-215.708;node-5;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.10,source seqno=8411,payload size=345,offset size=345,src time stamp=0.719184,hop time stamp=0.951634,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-226.204;node-5;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.5,source seqno=7144,payload size=345,offset size=345,src time stamp=1.39726,hop time stamp=2.8617,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-326.112;node-0;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.5,source ip=10.0.0.9,source seqno=8347,payload size=345,offset size=345,src time stamp=3.8001,hop time stamp=3.97745,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-326.406;node-2;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.5,source ip=10.0.0.9,source seqno=8347,payload size=345,offset size=345,src time stamp=3.8001,hop time stamp=4.27745,hop ip=10.0.0.1,bundle type=BundlePacket
#
# [time-326.408;node-1;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.1,source ip=10.0.0.8,source seqno=8440,payload size=345,offset size=345,src time stamp=1.21666,hop time stamp=4.27745,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-327.004;node-0;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.1,source ip=10.0.0.8,source seqno=8440,payload size=345,offset size=345,src time stamp=1.21666,hop time stamp=0.582484,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-347.404;node-4;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.5,source ip=10.0.0.9,source seqno=8347,payload size=345,offset size=345,src time stamp=3.8001,hop time stamp=3.80262,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-357.616;node-1;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.6,source seqno=6190,payload size=345,offset size=345,src time stamp=0.578732,hop time stamp=1.11771,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-357.901;node-8;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.6,source seqno=6190,payload size=345,offset size=345,src time stamp=0.578732,hop time stamp=1.41771,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-357.908;node-1;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.10,source seqno=8411,payload size=345,offset size=345,src time stamp=0.719184,hop time stamp=1.41771,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-358.201;node-8;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.10,source seqno=8411,payload size=345,offset size=345,src time stamp=0.719184,hop time stamp=1.71771,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-358.209;node-1;line-641]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.5,source seqno=7144,payload size=345,offset size=345,src time stamp=1.39726,hop time stamp=1.71771,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-358.502;node-8;line-633]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.9,source ip=10.0.0.5,source seqno=7144,payload size=345,offset size=345,src time stamp=1.39726,hop time stamp=2.01771,hop ip=10.0.0.2,bundle type=BundlePacket
#
# ============= dividing end of parse =============
# =============
#  === print your schedule
# [[0, 12.021325669, 2, 700], [0, 117.981550363, 9, 6698], [0, 94.020478268, 3, 4987], [1, 0.806334457, 5, 40], [1, 50.676573125, 7, 2648], [1, 85.401015942, 8, 4536], [2, 3.409505929, 5, 196], [2, 96.930379408, 7, 5311], [2, 100.785055403, 7, 5311], [3, 55.296858285, 2, 2886], [3, 107.558250247, 5, 6169], [3, 147.199292754, 6, 8209], [4, 49.408970033, 6, 2587], [4, 73.305762111, 6, 2587], [4, 125.951311731, 8, 7144], [5, 66.39254112, 8, 3496], [5, 86.198989425, 7, 4581], [5, 107.952914708, 8, 3496], [6, 67.355142078, 5, 3547], [6, 112.228687082, 5, 3547], [6, 88.662378134, 3, 4709], [7, 35.56773015, 5, 1878], [7, 48.239575273, 1, 2519], [7, 151.540515515, 0, 8440], [8, 66.928350315, 9, 3523], [8, 80.856541053, 5, 4243], [8, 149.828988053, 4, 8347], [9, 67.409707327, 1, 3552], [9, 71.512551808, 7, 3773], [9, 151.043038945, 8, 8411]]
# ===================================================================================================
# ===================== report parse result ================
# 30 / 30 arrived
# ==================
# pkt-seqno:700, trace is:
# from time-12.021325669 => time-1.46542 in node-0
# from time-57.3112 => time-2.06542 in node-5
# from time-57.91 => time-2.11072 in node-4
# from time-96.6239 => time-2.71072 in node-1
# received by node-2 at time-97.2052 destination :)
# arrived destination
#
# schedule is: from node-0 to node-2 at time-12.021325669
# ==================
# pkt-seqno:6698, trace is:
# from time-117.981550363 => time-0.640915 in node-0
# received by node-9 at time-120.908 destination :)
# arrived destination
#
# schedule is: from node-0 to node-9 at time-117.981550363
# ==================
# pkt-seqno:4987, trace is:
# from time-94.020478268 => time-4.00569 in node-0
# from time-94.2082 => time-3.31072 in node-4
# from time-97.809 => time-3.91072 in node-1
# from time-98.4043 => time-4.21072 in node-2
# from time-98.702 => time-0.215752 in node-6
# received by node-3 at time-99.0005 destination :)
# arrived destination
#
# schedule is: from node-0 to node-3 at time-94.020478268
# ==================
# pkt-seqno:40, trace is:
# from time-0.806334457 => time-1.5 in node-1
# from time-1.50609 => time-2.1 in node-7
# received by node-5 at time-2.11369 destination :)
# arrived destination
#
# schedule is: from node-1 to node-5 at time-0.806334457
# ==================
# pkt-seqno:2648, trace is:
# from time-50.676573125 => time-3.75536 in node-1
# received by node-7 at time-51.0005 destination :)
# arrived destination
#
# schedule is: from node-1 to node-7 at time-50.676573125
# ==================
# pkt-seqno:4536, trace is:
# from time-85.401015942 => time-4.19562 in node-1
# received by node-8 at time-85.8039 destination :)
# arrived destination
#
# schedule is: from node-1 to node-8 at time-85.401015942
# ==================
# pkt-seqno:196, trace is:
# from time-3.409505929 => time-3.9 in node-2
# from time-3.91378 => time-0.205033 in node-3
# from time-4.50813 => time-0.805033 in node-9
# received by node-5 at time-5.11094 destination :)
# arrived destination
#
# schedule is: from node-2 to node-5 at time-3.409505929
# ==================
# pkt-seqno:5311, trace is:
# from time-100.785055403 => time-3.31072 in node-2
# received by node-7 at time-97.8224 destination :)
# arrived destination
#
# schedule is: from node-2 to node-7 at time-96.930379408
# ==================
# pkt-seqno:2886, trace is:
# from time-55.296858285 => time-4.26039 in node-3
# received by node-2 at time-55.8005 destination :)
# arrived destination
#
# schedule is: from node-3 to node-2 at time-55.296858285
# ==================
# pkt-seqno:6169, trace is:
# from time-107.558250247 => time-0.351634 in node-3
# received by node-5 at time-215.11 destination :)
# arrived destination
#
# schedule is: from node-3 to node-5 at time-107.558250247
# ==================
# pkt-seqno:8209, trace is:
# from time-147.199292754 => time-1.57111 in node-3
# received by node-6 at time-147.601 destination :)
# arrived destination
#
# schedule is: from node-3 to node-6 at time-147.199292754
# ==================
# pkt-seqno:2587, trace is:
# from time-73.305762111 => time-1.81072 in node-4
# from time-96.3103 => time-2.41072 in node-1
# from time-96.9047 => time-3.01072 in node-2
# received by node-6 at time-97.5026 destination :)
# arrived destination
#
# schedule is: from node-4 to node-6 at time-49.408970033
# ==================
# pkt-seqno:7144, trace is:
# from time-125.951311731 => time-0.131504 in node-4
# from time-197.709 => time-0.731504 in node-2
# from time-198.302 => time-2.8617 in node-6
# from time-226.204 => time-1.71771 in node-5
# from time-358.209 => time-2.01771 in node-1
# received by node-8 at time-358.502 destination :)
# arrived destination
#
# schedule is: from node-4 to node-8 at time-125.951311731
# ==================
# pkt-seqno:3496, trace is:
# from time-107.952914708 => time-2.17549 in node-5
# from time-66.6005 => time-2.41072 in node-4
# from time-96.909 => time-3.01072 in node-1
# received by node-8 at time-97.5005 destination :)
# arrived destination
#
# schedule is: from node-5 to node-8 at time-66.39254112
# ==================
# pkt-seqno:4581, trace is:
# from time-86.198989425 => time-0.800654 in node-5
# from time-86.7005 => time-3.01072 in node-4
# from time-97.5104 => time-3.61072 in node-1
# from time-98.1035 => time-3.91072 in node-2
# received by node-7 at time-98.4005 destination :)
# arrived destination
#
# schedule is: from node-5 to node-7 at time-86.198989425
# ==================
# pkt-seqno:3547, trace is:
# from time-112.228687082 => time-3.07549 in node-6
# from time-67.5108 => time-3.37549 in node-2
# from time-67.806 => time-2.11072 in node-1
# from time-96.6083 => time-3.91072 in node-4
# from time-98.4005 => time-0.215752 in node-0
# received by node-5 at time-99.0005 destination :)
# arrived destination
#
# schedule is: from node-6 to node-5 at time-67.355142078
# ==================
# pkt-seqno:4709, trace is:
# from time-88.662378134 => time-3.20065 in node-6
# received by node-3 at time-89.1005 destination :)
# arrived destination
#
# schedule is: from node-6 to node-3 at time-88.662378134
# ==================
# pkt-seqno:1878, trace is:
# from time-35.56773015 => time-1.64026 in node-7
# received by node-5 at time-36.0005 destination :)
# arrived destination
#
# schedule is: from node-7 to node-5 at time-35.56773015
# ==================
# pkt-seqno:2519, trace is:
# from time-48.239575273 => time-1.05536 in node-7
# received by node-1 at time-48.3005 destination :)
# arrived destination
#
# schedule is: from node-7 to node-1 at time-48.239575273
# ==================
# pkt-seqno:8440, trace is:
# from time-151.540515515 => time-4.27745 in node-7
# from time-326.408 => time-0.582484 in node-1
# received by node-0 at time-327.004 destination :)
# arrived destination
#
# schedule is: from node-7 to node-0 at time-151.540515515
# ==================
# pkt-seqno:3523, trace is:
# from time-66.928350315 => time-0.895621 in node-8
# from time-82.5072 => time-1.49562 in node-1
# from time-83.1005 => time-2.09562 in node-2
# from time-83.7005 => time-2.39562 in node-6
# from time-84.0142 => time-0.610719 in node-3
# received by node-9 at time-95.1131 destination :)
# arrived destination
#
# schedule is: from node-8 to node-9 at time-66.928350315
# ==================
# pkt-seqno:4243, trace is:
# from time-80.856541053 => time-1.19562 in node-8
# from time-82.8039 => time-1.81072 in node-1
# from time-96.3861 => time-3.61072 in node-4
# from time-98.1064 => time-4.21072 in node-0
# received by node-5 at time-98.7039 destination :)
# arrived destination
#
# schedule is: from node-8 to node-5 at time-80.856541053
# ==================
# pkt-seqno:8347, trace is:
# from time-149.828988053 => time-4.27111 in node-8
# from time-150.301 => time-3.97745 in node-1
# from time-326.112 => time-4.27745 in node-0
# from time-326.406 => time-3.80262 in node-2
# received by node-4 at time-347.404 destination :)
# arrived destination
#
# schedule is: from node-8 to node-4 at time-149.828988053
# ==================
# pkt-seqno:3552, trace is:
# from time-67.409707327 => time-0.310719 in node-9
# from time-94.8039 => time-0.910719 in node-3
# from time-95.4005 => time-1.51072 in node-6
# from time-96.0005 => time-2.11072 in node-2
# received by node-1 at time-96.6191 destination :)
# arrived destination
#
# schedule is: from node-9 to node-1 at time-67.409707327
# ==================
# pkt-seqno:3773, trace is:
# from time-71.512551808 => time-0.610719 in node-9
# from time-95.1082 => time-1.21072 in node-3
# from time-95.7005 => time-1.81072 in node-6
# received by node-7 at time-96.3153 destination :)
# arrived destination
#
# schedule is: from node-9 to node-7 at time-71.512551808
# ==================
# pkt-seqno:8411, trace is:
# from time-151.043038945 => time-0.876144 in node-9
# from time-151.201 => time-0.951634 in node-3
# from time-215.708 => time-1.41771 in node-5
# from time-357.908 => time-1.71771 in node-1
# received by node-8 at time-358.201 destination :)
# arrived destination
#
# schedule is: from node-9 to node-8 at time-151.043038945
# {700: [12.021325669, 0, 1.46542, 57.3112, 5, 2.06542, 57.91, 4, 2.11072, 96.6239, 1, 2.71072, 97.2052, 2, 802.0], 6698: [117.981550363, 0, 0.640915, 120.908, 9, 802.0], 4987: [94.020478268, 0, 4.00569, 94.2082, 4, 3.31072, 97.809, 1, 3.91072, 98.4043, 2, 4.21072, 98.702, 6, 0.215752, 99.0005, 3, 802.0], 40: [0.806334457, 1, 1.5, 1.50609, 7, 2.1, 2.11369, 5, 802.0], 2648: [50.676573125, 1, 3.75536, 51.0005, 7, 802.0], 4536: [85.401015942, 1, 4.19562, 85.8039, 8, 802.0], 196: [3.409505929, 2, 3.9, 3.91378, 3, 0.205033, 4.50813, 9, 0.805033, 5.11094, 5, 802.0], 5311: [100.785055403, 2, 3.31072, 97.8224, 7, 802.0], 2886: [55.296858285, 3, 4.26039, 55.8005, 2, 802.0], 6169: [107.558250247, 3, 0.351634, 215.11, 5, 802.0], 8209: [147.199292754, 3, 1.57111, 147.601, 6, 802.0], 2587: [73.305762111, 4, 1.81072, 96.3103, 1, 2.41072, 96.9047, 2, 3.01072, 97.5026, 6, 802.0], 7144: [125.951311731, 4, 0.131504, 197.709, 2, 0.731504, 198.302, 6, 2.8617, 226.204, 5, 1.71771, 358.209, 1, 2.01771, 358.502, 8, 802.0], 3496: [107.952914708, 5, 2.17549, 66.6005, 4, 2.41072, 96.909, 1, 3.01072, 97.5005, 8, 802.0], 4581: [86.198989425, 5, 0.800654, 86.7005, 4, 3.01072, 97.5104, 1, 3.61072, 98.1035, 2, 3.91072, 98.4005, 7, 802.0], 3547: [112.228687082, 6, 3.07549, 67.5108, 2, 3.37549, 67.806, 1, 2.11072, 96.6083, 4, 3.91072, 98.4005, 0, 0.215752, 99.0005, 5, 802.0], 4709: [88.662378134, 6, 3.20065, 89.1005, 3, 802.0], 1878: [35.56773015, 7, 1.64026, 36.0005, 5, 802.0], 2519: [48.239575273, 7, 1.05536, 48.3005, 1, 802.0], 8440: [151.540515515, 7, 4.27745, 326.408, 1, 0.582484, 327.004, 0, 802.0], 3523: [66.928350315, 8, 0.895621, 82.5072, 1, 1.49562, 83.1005, 2, 2.09562, 83.7005, 6, 2.39562, 84.0142, 3, 0.610719, 95.1131, 9, 802.0], 4243: [80.856541053, 8, 1.19562, 82.8039, 1, 1.81072, 96.3861, 4, 3.61072, 98.1064, 0, 4.21072, 98.7039, 5, 802.0], 8347: [149.828988053, 8, 4.27111, 150.301, 1, 3.97745, 326.112, 0, 4.27745, 326.406, 2, 3.80262, 347.404, 4, 802.0], 3552: [67.409707327, 9, 0.310719, 94.8039, 3, 0.910719, 95.4005, 6, 1.51072, 96.0005, 2, 2.11072, 96.6191, 1, 802.0], 3773: [71.512551808, 9, 0.610719, 95.1082, 3, 1.21072, 95.7005, 6, 1.81072, 96.3153, 7, 802.0], 8411: [151.043038945, 9, 0.876144, 151.201, 3, 0.951634, 215.708, 5, 1.41771, 357.908, 1, 1.71771, 358.201, 8, 802.0]}
# <img src="data:image/png;base64,..." width="640">
# colors count=30
# len of seqno_number_list=30
# range(0, 30)
