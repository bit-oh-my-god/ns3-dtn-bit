# %%
# %matplotlib notebook
import re
import sys
import inspect
from math import sqrt
import numpy as np
from scipy import integrate
from matplotlib import pyplot as plt
import matplotlib as mpl
from matplotlib import cm
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import cnames
from matplotlib import animation
#==================================
# This parse script won't parse sprayandwait yet, would cause mass
##################
# define handy func
def nums(s):
    try:
        return int(s)
    except ValueError:
        return float(s)
################
#====
# read the result file
simulation_result_file = open("../../box/dtn_simulation_result/dtnrunninglog.txt", "r")
lines = simulation_result_file.readlines();
simulation_result_file.close()
#====
x_is_one_delivery_route = False
x_simulation_time = -1
x_nodes = -1
x_sch_n = -1
x_arrive_n = 0
x_tosend_list = [] # element is also a list [source, time, destination, seqno] this is used to substitude x_schedule_list
x_schedule_list = [] # element is also a list[source, time, destination, seqno]
x_pkt_trace_map = {} # seqno -> [one_hop_snap, one_hop_snap... destination_snap]
# hop_snap , destination_snap = 
#[receive_time, receive_id, dest_id, source_id, seqno, src_generate_time, hop_transmit_time, pkt_type, is_dst, hop_id]
############
# define
def snap_print(snap) :
    print('''seqno :{0}, pkt-type={4}, receive at time-{1} at node-{2}, transmit at time-{3} at node-{5}'''
          .format(snap[4], snap[0], snap[1], snap[6], snap[7], snap[9]))
#############
test_string = r'Here In DtnExampleInterface::ReportExBundleTrace:node_number_=5;simulation_duration_=802'
r11 = re.compile(r'BundleTrace:node_number_=(\d+\.*\d*);simulation_duration_=(\d+\.*\d*)', re.VERBOSE)
test_regx = r11.search(test_string)
if test_regx :
    print("good0")
else :
    print("bad0")
    sys.exit()
    
strss = "[time-5.40052;node-1;line-638]NOTE:BundleTrace:good! one bun\
dle recept, it's one hop! bp_header=,destination ip=10.0.0.3,sour\
ce ip=10.0.0.1,source seqno=139,payload size=345,offset size=345,src time sta\
mp=5,hop time stamp=5,bundle type=BundlePacket"
r22 = re.compile(r'\[time-(\d+\.*\d*);node-(\d+\.*\d*);line-(\d+\.*\d*)\]NOTE:BundleTr\
ace:good!\sone\sbundle\srecept,\sit\'s\sone\shop!\sbp_header=,destination\sip=10.0.0.(\d+\.*\d*),sou\
rce\sip=10.0.0.(\d+\.*\d*),source\sseqno=(\d+\.*\d*),payload\ssize=(\d+\.*\d*),offset\ssi\
ze=(\d+\.*\d*),src\stime\sstamp=(\d+\.*\d*),hop\stime\sstamp=(\d+\.*\d*),bundle\stype=([a-zA-Z]+)', re.VERBOSE)
hopt = r22.match(strss)
if hopt :
    print("good1")
else :
    print("bad1")
    sys.exit()
    
#================================================ dividing parse ========================================
# parse for x_ nodes and x_ simualtion_time
# parse for bundle trace and schedule
avoid_log_twice_bug = False
for line in lines :
    #In DtnExampleRunner
    r0 = re.compile(r'In\sDtnExampleRunner', re.VERBOSE)
    parse_begin = r0.search(line)
    if parse_begin :
        avoid_log_twice_bug = True
        continue
    elif avoid_log_twice_bug :
        # do nothing
        onenomeaning = 1
    else :
        continue
    
    #BundleTrace:node_number_=5;simulation_duration_=802
    r1 = re.compile(r'BundleTrace:node_number_=(\d+\.*\d*);simulation_duration_=(\d+\.*\d*)', re.VERBOSE)
    simulation_preview = r1.search(line)
    
    #[time-5.40052;node-1;line-638]NOTE:BundleTrace:good! one bundle recept, it's one hop! bp_header=,destination ip=10.0.0.3,source ip=10.0.0.1,source seqno=139,payload size=345,offset size=345,src time stamp=5,hop time stamp=5,bundle type=BundlePacket
    r2 = re.compile(r'''\[time\-(\d+\.*\d*);node\-(\d+\.*\d*);line\-(\d+\.*\d*)\]NOTE:BundleTrace:go
    od!\sone\sbundle\srecept\,\sit\'s\sone\shop!\sbp_header=\,destination\sip=10\.0\.0\.(\d+\.*\d*)\,sour
    ce\sip=10\.0\.0\.(\d+\.*\d*)\,source\sseqno=(\d+\.*\d*)\,payload\ssize=(\d+\.*\d*)\,offset\ssiz
    e=(\d+\.*\d*)\,src\stime\sstamp=(\d+\.*\d*)\,hop\stime\ssta
    mp=(\d+\.*\d*)\,hop\sip=10\.0\.0\.(\d+\.*\d*)\,bundle\stype=([a-zA-Z]+)''', re.VERBOSE)
    hop = r2.search(line)
    
    #[time-3.30744;node-1;line-630]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.2,source ip=10.0.0.1,source seqno=75,payload size=345,offset size=345,src time stamp=3,hop time stamp=3,bundle type=BundlePacket
    r3 = re.compile(r'''\[time\-(\d+\.*\d*);node\-(\d+\.*\d*);line\-(\d+\.*\d*)\]NOTE:BundleTrace:Great!\son
    e\sbundle\sarrive\sdestination!\sbp_header=\,destination\sip=10\.0\.0\.(\d+\.*\d*)\,so
    urce\sip=10\.0\.0\.(\d+\.*\d*)\,source\sseqno=(\d+\.*\d*)\,payload\ssize=(\d+\.*\d*)\,offset\ss
    ize=(\d+\.*\d*)\,src\stime\sstamp=(\d+\.*\d*)\,hop\stime\ssta
    mp=(\d+\.*\d*)\,hop\sip=10\.0\.0\.(\d+\.*\d*)\,bundle\stype=([a-zA-Z]+)''', re.VERBOSE)
    destination = r3.search(line)
    
    #[time-0;node-0;line-1553]enter ScheduleTx(), time-+3000000000.0ns,size=345, to node-1
    r4 = re.compile(r'''node\-(\d+\.*\d*);line\-(\d+\.*\d*)]enter\sScheduleTx\(\)\,\sti
    me\-\+(\d+\.*\d*)ns\,size=(\d+\.*\d*)\,\sto\snode\-(\d+\.*\d*)''', re.VERBOSE)
    schedule = r4.search(line)
    
    #BundleTrace:Itisonedeliverymethon
    r5 = re.compile(r'''BundleTrace:Itisonedeliverymethon''', re.VERBOSE)
    isonedelivery = r5.search(line)
    
    #ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.4,source ip=10.0.0.3,source seqno=47,payload size=345,offset size=345,src time stamp=0.562494,hop time stamp=0.562494,hop ip=10.0.0.3,bundle type=BundlePacket
    r6 = re.compile(r'''ScheduleTx\,inToSendBundle\(\)\,bp_header=\,destination\sip=10\.0\.0\.(\d+\.*\d*)\,so
    urce\sip=10\.0\.0\.(\d+\.*\d*)\,source\sseqno=(\d+\.*\d*)\,payload\ssize=(\d+\.*\d*)\,offset\ss
    ize=(\d+\.*\d*)\,src\stime\sstamp=(\d+\.*\d*)\,hop\stime\ssta
    mp=(\d+\.*\d*)\,hop\sip=10\.0\.0\.(\d+\.*\d*)\,bundle\stype=([a-zA-Z]+)''', re.VERBOSE)
    tosendbundle = r6.search(line)
    
    if schedule :
        print(line)
        sche_source = int(nums(schedule.group(1)))
        sche_time = float(nums(schedule.group(3)) / 1000000000.0)
        sche_destination = int(nums(schedule.group(5)))
        tmp = [sche_source, sche_time, sche_destination, -1]
        x_schedule_list.append(tmp)
    elif tosendbundle :
        print(line)
        tosend_source = int(nums(tosendbundle.group(2)) - int(1))
        tosend_time = float(nums(tosendbundle.group(6)))
        tosend_destination = int(nums(tosendbundle.group(1)) - int(1))
        tosend_seqno = int(nums(tosendbundle.group(3)))
        tmp = [tosend_source, tosend_time, tosend_destination, tosend_seqno]
        x_tosend_list.append(tmp)
    elif isonedelivery :
        print(line)
        x_is_one_delivery_route = True
    elif hop :
        print(line)
        hop_receive_time = float(nums(hop.group(1)))
        hop_receive_id = int(nums(hop.group(2)))
        hop_dest_id = int(nums(hop.group(4)) - int(1))
        hop_source_id = int(nums(hop.group(5)) - int(1))
        hop_seqno = int(nums(hop.group(6)))
        hop_src_generate_time = float(nums(hop.group(9))) # TODO
        hop_hop_transmit_time = float(nums(hop.group(10)))
        hop_hop_id = int(nums(hop.group(11)) - int(1))
        hop_pkt_type = hop.group(12)
        if (hop_hop_transmit_time > hop_receive_time) :
            print('receive time:{0} should < hop_transmit time{1}'.format(hop_receive_time, hop_hop_transmit_time))
            sys.exit()
        tmp = [hop_receive_time, hop_receive_id, hop_dest_id, hop_source_id, hop_seqno,
               hop_src_generate_time, hop_hop_transmit_time, hop_pkt_type, False, hop_hop_id]
        if hop_seqno in x_pkt_trace_map.keys():
            old_list = x_pkt_trace_map[hop_seqno]
            old_list.append(tmp)
            old_list.sort(key=lambda tup: tup[0])
            x_pkt_trace_map[hop_seqno] = old_list
        else:
            new_list = []
            new_list.append(tmp)
            x_pkt_trace_map[hop_seqno] = new_list
    elif simulation_preview :
        print(line)
        x_nodes = int(simulation_preview.group(1))
        x_simulation_time = float(simulation_preview.group(2))
    elif destination :
        print(line)
        dst_receive_time = float(nums(destination.group(1)))
        dst_receive_id = int(nums(destination.group(2)))
        dst_dst_id = int(nums(destination.group(4)) - int(1))
        dst_src_id = int(nums(destination.group(5)) - int(1))
        dst_seqno = int(nums(destination.group(6)))
        dst_src_generate_time = float(nums(destination.group(9)))
        dst_hop_transmit_time = float(nums(destination.group(10)))
        dst_hop_id = int(nums(destination.group(11)) - int(1))
        dst_pkt_type = destination.group(12)
        if (dst_hop_transmit_time > dst_receive_time) :
            print('receive time')
            sys.exit()
        tmp = [dst_receive_time, dst_receive_id, dst_dst_id, dst_src_id, dst_seqno,
               dst_src_generate_time, dst_hop_transmit_time, dst_pkt_type, True, dst_hop_id]
        if dst_seqno in x_pkt_trace_map.keys() :
            old_list = x_pkt_trace_map[dst_seqno]
            old_list.append(tmp)
            old_list.sort(key=lambda tup: tup[0])
            x_pkt_trace_map[dst_seqno] = old_list
        else :
            new_list = []
            new_list.append(tmp)
            x_pkt_trace_map[dst_seqno] = new_list
            
#========================================= end of parse ===================================================

print(r'============= dividing end of parse =============')
if (x_nodes == -1) or (x_simulation_time == -1) :
    print('error_04')
    sys.exit()
#================ now we have every thing we need, refine the data and prepare for visualization
#===== refine x_schedule_list
for sch in x_schedule_list :
    sk = [sch[0], sch[1], sch[2]] # s, t, d
    sn = sch[3]
    if sn != -1 :
        print('error_03')
        sys.exit()
    for key, value in x_pkt_trace_map.items() : #
        #print('value len={0}'.format(len(value)))
        #print(value)
        tk = [value[0][3], value[0][5], value[0][2]]
        seqno = value[0][4]
        if (tk[0] == sk[0] and tk[2] == sk[2] and tk[1] - sk[1] < 0.1) :
            sn = seqno
            break
    if (sn != -1) :
        sch[3] = sn
    else :
        print('warn_05:this may happen when one pkt scheduled but not successfully hoped')

print('============= \n === print your schedule')
print(x_schedule_list)
print('============= \n === print your tosendbundle')
print(x_tosend_list)
#===================================== get graph needed list
#
#                                                                                    dstination
x_time_trace_map = {} # seqno -> [src_t, sr_id, hop_t, rec_t, rec_id, hop_t, ... , rec_t, rec_id, x_simulation_time]
x_sch_n = len(x_tosend_list)
print('==============\n print your x_pkt_trace_map')
print(x_pkt_trace_map)
####################
#definition
def get_x_time_trace_map(p_x_time_trace_map, p_x_tosend_list, p_x_pkt_trace_map, ref_x_arrive_n) :
    ref_x_arrive_n = 0
    if x_is_one_delivery_route :
        for sch in p_x_tosend_list :
            src_t = sch[1]
            seqno = sch[3]
            if seqno == -1 :
                print('error_01')
                sys.exit()
            sr_id = sch[0]
            tmp = []
            tmp.extend([src_t, sr_id])
            if seqno in p_x_pkt_trace_map :
                print('key exist')
                for trace in p_x_pkt_trace_map[seqno] :
                    if trace[4] != seqno :
                        print('error_02')
                        sys.exit()
                    is_dst = bool(trace[8])
                    hop_t = trace[6]
                    rec_t = trace[0]
                    rec_id = trace[1]
                    tmp.extend([hop_t, rec_t, rec_id])
                    if is_dst :
                        tmp.append(x_simulation_time)
                if len(tmp) % 3 == 0 :
                    ref_x_arrive_n += 1
                    p_x_time_trace_map[seqno] = tmp 
                else :
                    print('there is one pkt don\'t arrive destination')
                    p_x_time_trace_map[seqno] = tmp
            else :
                print('key not exist-{0}'.format(seqno))
                p_x_time_trace_map[seqno] = tmp
    else :
        print('if not one delivery route, this would cause one seqno -> multiply path, it\'s hard to parse, would\
        do this latter')
        print('============ print all hop snap and end ==============')
        for key, snaps in p_x_pkt_trace_map.items() :
            for snap in snaps :
                snap_print(snap)
        print('normal exit')
        sys.exit()
    return ref_x_arrive_n
#end of definition
#################################
x_arrive_n = get_x_time_trace_map(x_time_trace_map, x_tosend_list, x_pkt_trace_map, x_arrive_n)
#===== gonna to make graph|
print('===================================================================================================\
\n===================== report parse result ================')
title_str = '{0} / {1} arrived'.format(x_arrive_n, x_sch_n)
#print(x_time_trace_map)
print(title_str)
###############
# define
def handy_print_2(seqno) :
    for xs in x_tosend_list :
        if xs[3] == seqno :
            print('schedule is: from node-{0} to node-{1} at time-{2}'.format(xs[0], xs[2], xs[1]))
            break
def handy_print_0(st, et, nid) :
    print('from time-{0} => time-{1} in node-{2}'.format(st, et, nid))
def handy_print_1(key, value) :
    print('==================\npkt-seqno:{0}, trace is: '.format(key))
    n_v = int(len(value) / 3)
    is_arrived_traffic = False
    if (n_v * 3 == len(value)) :
        is_arrived_traffic = True
    if (is_arrived_traffic) :
        for cur in range(0, n_v, 1) :
            if cur == n_v - 1 :
                print('received by node-{1} at time-{0} destination :)'.format(value[cur * 3], value[cur * 3 + 1]))
            else :
                handy_print_0(value[cur * 3], value[cur * 3 + 2], value[cur * 3 + 1])
        print('arrived destination\n')
    else :
        for cur in range(0, n_v + 1, 1) :
            if cur == n_v :
                print('received by node-{1} at time-{0}, not destination :('.format(value[cur * 3], value[cur * 3 + 1]))
                if cur == 0 :
                    print('this bundle may not be transmit out from source')
            else :
                handy_print_0(value[cur * 3], value[cur * 3 + 2], value[cur * 3 + 1])
        print('not arrived destination\n')
    handy_print_2(key)
def handy_draw_0(ax0, st, et, nid, seqnoindex, c) :
    dx = et - st
    ax0.bar3d(st, seqnoindex, nid, dx, 0.2, 0.2, alpha=0.1, color=c, linewidth=0) # alpha = abs(dz[i]/max(dz))
###################################

for key, value in x_time_trace_map.items() :
    handy_print_1(key, value)
print(x_time_trace_map)
#===============
fig = plt.figure()
ax = fig.gca(projection='3d')
colors = plt.cm.jet(np.linspace(0, 1, len(x_tosend_list)))
seqno_number_list = []
for xsele in x_tosend_list :
    seqno_number_list.append(xsele[3])

#=======    
print('colors count={0}'.format(len(colors)))
print('len of seqno_number_list={0}'.format(len(seqno_number_list)))
print(range(0, len(seqno_number_list), 1))

for c, zseqnoindex in zip(colors, range(0, len(seqno_number_list), 1)):
    this_seqno_no = seqno_number_list[zseqnoindex]
    trace_list_of_seqno = x_time_trace_map[this_seqno_no]
    rt_count = int(len(trace_list_of_seqno) / 3)
    is_arrived_traffic_0 = False
    if (rt_count * 3 == len(trace_list_of_seqno)) :
        is_arrived_traffic_0 = True
        
    if is_arrived_traffic_0 :
        for cur in range(0, rt_count, 1) :
            if cur == rt_count - 1 :
                handy_draw_0(ax, trace_list_of_seqno[cur * 3], trace_list_of_seqno[cur * 3 + 2], \
                             trace_list_of_seqno[cur * 3 + 1], zseqnoindex, c)
                ax.text(x_simulation_time, zseqnoindex, 0\
                        , 'arrived! seqno={0}'.format(seqno_number_list[zseqnoindex]), 'x')
            else :
                handy_draw_0(ax, trace_list_of_seqno[cur * 3], trace_list_of_seqno[cur * 3 + 2], \
                             trace_list_of_seqno[cur * 3 + 1], zseqnoindex, c)
    else :
        for cur in range(0, rt_count + 1, 1) :
            if cur == rt_count :
                handy_draw_0(ax, trace_list_of_seqno[cur * 3], trace_list_of_seqno[cur * 3] + 1, \
                             trace_list_of_seqno[cur * 3 + 1], zseqnoindex, c)
                ax.text(x_simulation_time, zseqnoindex, 0\
                        , 'missed! seqno={0}'.format(seqno_number_list[zseqnoindex]), 'x')
            else :
                handy_draw_0(ax, trace_list_of_seqno[cur * 3], trace_list_of_seqno[cur * 3 + 2], \
                             trace_list_of_seqno[cur * 3 + 1], zseqnoindex, c)
#======
ax.set_xlabel('time')
#ax.set_ylabel('')
ax.set_zlabel('node')
plt.show()
#==================
# Out:
# good0
# good1
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# BundleTrace:Itisonedeliverymethon
#
# Here In DtnExampleInterface::ReportExBundleTrace:node_number_=10;simulation_duration_=802
#
# [time-0;node-0;line-1558]enter ScheduleTx(), time-+12021325669.0ns,size=345, to node-2
#
# [time-0;node-0;line-1558]enter ScheduleTx(), time-+117981550363.0ns,size=345, to node-9
#
# [time-0;node-0;line-1558]enter ScheduleTx(), time-+94020478268.0ns,size=345, to node-3
#
# [time-0;node-1;line-1558]enter ScheduleTx(), time-+806334457.0ns,size=345, to node-5
#
# [time-0;node-1;line-1558]enter ScheduleTx(), time-+50676573125.0ns,size=345, to node-7
#
# [time-0;node-1;line-1558]enter ScheduleTx(), time-+85401015942.0ns,size=345, to node-8
#
# [time-0;node-2;line-1558]enter ScheduleTx(), time-+3409505929.0ns,size=345, to node-5
#
# [time-0;node-2;line-1558]enter ScheduleTx(), time-+96930379408.0ns,size=345, to node-7
#
# [time-0;node-2;line-1558]enter ScheduleTx(), time-+100785055403.0ns,size=345, to node-7
#
# [time-0;node-3;line-1558]enter ScheduleTx(), time-+55296858285.0ns,size=345, to node-2
#
# [time-0;node-3;line-1558]enter ScheduleTx(), time-+107558250247.0ns,size=345, to node-5
#
# [time-0;node-3;line-1558]enter ScheduleTx(), time-+147199292754.0ns,size=345, to node-6
#
# [time-0;node-4;line-1558]enter ScheduleTx(), time-+49408970033.0ns,size=345, to node-6
#
# [time-0;node-4;line-1558]enter ScheduleTx(), time-+73305762111.0ns,size=345, to node-6
#
# [time-0;node-4;line-1558]enter ScheduleTx(), time-+125951311731.0ns,size=345, to node-8
#
# [time-0;node-5;line-1558]enter ScheduleTx(), time-+66392541120.0ns,size=345, to node-8
#
# [time-0;node-5;line-1558]enter ScheduleTx(), time-+86198989425.0ns,size=345, to node-7
#
# [time-0;node-5;line-1558]enter ScheduleTx(), time-+107952914708.0ns,size=345, to node-8
#
# [time-0;node-6;line-1558]enter ScheduleTx(), time-+67355142078.0ns,size=345, to node-5
#
# [time-0;node-6;line-1558]enter ScheduleTx(), time-+112228687082.0ns,size=345, to node-5
#
# [time-0;node-6;line-1558]enter ScheduleTx(), time-+88662378134.0ns,size=345, to node-3
#
# [time-0;node-7;line-1558]enter ScheduleTx(), time-+35567730150.0ns,size=345, to node-5
#
# [time-0;node-7;line-1558]enter ScheduleTx(), time-+48239575273.0ns,size=345, to node-1
#
# [time-0;node-7;line-1558]enter ScheduleTx(), time-+151540515515.0ns,size=345, to node-0
#
# [time-0;node-8;line-1558]enter ScheduleTx(), time-+66928350315.0ns,size=345, to node-9
#
# [time-0;node-8;line-1558]enter ScheduleTx(), time-+80856541053.0ns,size=345, to node-5
#
# [time-0;node-8;line-1558]enter ScheduleTx(), time-+149828988053.0ns,size=345, to node-4
#
# [time-0;node-9;line-1558]enter ScheduleTx(), time-+67409707327.0ns,size=345, to node-1
#
# [time-0;node-9;line-1558]enter ScheduleTx(), time-+71512551808.0ns,size=345, to node-7
#
# [time-0;node-9;line-1558]enter ScheduleTx(), time-+151043038945.0ns,size=345, to node-8
#
# [time-0.806334;node-1;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.6,source ip=10.0.0.2,source seqno=40,payload size=345,offset size=345,src time stamp=0.806334,hop time stamp=0.806334,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-3.40951;node-2;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.6,source ip=10.0.0.3,source seqno=171,payload size=345,offset size=345,src time stamp=3.40951,hop time stamp=3.40951,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-12.0213;node-0;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.3,source ip=10.0.0.1,source seqno=602,payload size=345,offset size=345,src time stamp=12.0213,hop time stamp=12.0213,hop ip=10.0.0.1,bundle type=BundlePacket
#
# [time-35.5677;node-7;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.6,source ip=10.0.0.8,source seqno=1780,payload size=345,offset size=345,src time stamp=35.5677,hop time stamp=35.5677,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-48.2396;node-7;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.2,source ip=10.0.0.8,source seqno=2414,payload size=345,offset size=345,src time stamp=48.2396,hop time stamp=48.2396,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-49.409;node-4;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.7,source ip=10.0.0.5,source seqno=2475,payload size=345,offset size=345,src time stamp=49.409,hop time stamp=49.409,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-50.6766;node-1;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.8,source ip=10.0.0.2,source seqno=2536,payload size=345,offset size=345,src time stamp=50.6766,hop time stamp=50.6766,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-55.2969;node-3;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.3,source ip=10.0.0.4,source seqno=2767,payload size=345,offset size=345,src time stamp=55.2969,hop time stamp=55.2969,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-66.3925;node-5;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.9,source ip=10.0.0.6,source seqno=3328,payload size=345,offset size=345,src time stamp=66.3925,hop time stamp=66.3925,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-66.9284;node-8;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.10,source ip=10.0.0.9,source seqno=3352,payload size=345,offset size=345,src time stamp=66.9284,hop time stamp=66.9284,hop ip=10.0.0.9,bundle type=BundlePacket
#
# [time-67.3551;node-6;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.6,source ip=10.0.0.7,source seqno=3376,payload size=345,offset size=345,src time stamp=67.3551,hop time stamp=67.3551,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-67.4097;node-9;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.2,source ip=10.0.0.10,source seqno=3381,payload size=345,offset size=345,src time stamp=67.4097,hop time stamp=67.4097,hop ip=10.0.0.10,bundle type=BundlePacket
#
# [time-71.5126;node-9;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.8,source ip=10.0.0.10,source seqno=3584,payload size=345,offset size=345,src time stamp=71.5126,hop time stamp=71.5126,hop ip=10.0.0.10,bundle type=BundlePacket
#
# [time-73.3058;node-4;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.7,source ip=10.0.0.5,source seqno=3674,payload size=345,offset size=345,src time stamp=73.3058,hop time stamp=73.3058,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-80.8565;node-8;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.6,source ip=10.0.0.9,source seqno=4054,payload size=345,offset size=345,src time stamp=80.8565,hop time stamp=80.8565,hop ip=10.0.0.9,bundle type=BundlePacket
#
# [time-85.401;node-1;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.9,source ip=10.0.0.2,source seqno=4285,payload size=345,offset size=345,src time stamp=85.401,hop time stamp=85.401,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-86.199;node-5;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.8,source ip=10.0.0.6,source seqno=4326,payload size=345,offset size=345,src time stamp=86.199,hop time stamp=86.199,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-88.6624;node-6;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.4,source ip=10.0.0.7,source seqno=4447,payload size=345,offset size=345,src time stamp=88.6624,hop time stamp=88.6624,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-94.0205;node-0;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.4,source ip=10.0.0.1,source seqno=4718,payload size=345,offset size=345,src time stamp=94.0205,hop time stamp=94.0205,hop ip=10.0.0.1,bundle type=BundlePacket
#
# [time-96.9304;node-2;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.8,source ip=10.0.0.3,source seqno=4863,payload size=345,offset size=345,src time stamp=96.9304,hop time stamp=96.9304,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-100.785;node-2;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.8,source ip=10.0.0.3,source seqno=5059,payload size=345,offset size=345,src time stamp=100.785,hop time stamp=100.785,hop ip=10.0.0.3,bundle type=BundlePacket
#
# [time-107.558;node-3;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.6,source ip=10.0.0.4,source seqno=5397,payload size=345,offset size=345,src time stamp=107.558,hop time stamp=107.558,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-107.953;node-5;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.9,source ip=10.0.0.6,source seqno=5418,payload size=345,offset size=345,src time stamp=107.953,hop time stamp=107.953,hop ip=10.0.0.6,bundle type=BundlePacket
#
# [time-112.229;node-6;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.6,source ip=10.0.0.7,source seqno=5633,payload size=345,offset size=345,src time stamp=112.229,hop time stamp=112.229,hop ip=10.0.0.7,bundle type=BundlePacket
#
# [time-117.982;node-0;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.10,source ip=10.0.0.1,source seqno=5923,payload size=345,offset size=345,src time stamp=117.982,hop time stamp=117.982,hop ip=10.0.0.1,bundle type=BundlePacket
#
# [time-125.951;node-4;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.9,source ip=10.0.0.5,source seqno=6321,payload size=345,offset size=345,src time stamp=125.951,hop time stamp=125.951,hop ip=10.0.0.5,bundle type=BundlePacket
#
# [time-147.199;node-3;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.7,source ip=10.0.0.4,source seqno=7386,payload size=345,offset size=345,src time stamp=147.199,hop time stamp=147.199,hop ip=10.0.0.4,bundle type=BundlePacket
#
# [time-149.829;node-8;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.5,source ip=10.0.0.9,source seqno=7517,payload size=345,offset size=345,src time stamp=149.829,hop time stamp=149.829,hop ip=10.0.0.9,bundle type=BundlePacket
#
# [time-151.043;node-9;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.9,source ip=10.0.0.10,source seqno=7578,payload size=345,offset size=345,src time stamp=151.043,hop time stamp=151.043,hop ip=10.0.0.10,bundle type=BundlePacket
#
# [time-151.541;node-7;line-368]ScheduleTx,inToSendBundle(),bp_header=,destination ip=10.0.0.1,source ip=10.0.0.8,source seqno=7604,payload size=345,offset size=345,src time stamp=151.541,hop time stamp=151.541,hop ip=10.0.0.8,bundle type=BundlePacket
#
# [time-233.706;node-7;line-631]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.8,source ip=10.0.0.2,source seqno=2536,payload size=345,offset size=345,src time stamp=3.43193,hop time stamp=1.77177,hop ip=10.0.0.2,bundle type=BundlePacket
#
# [time-233.776;node-1;line-631]NOTE:BundleTrace:Great! one bundle arrive destination! bp_header=,destination ip=10.0.0.2,source ip=10.0.0.8,source seqno=2414,payload size=345,offset size=345,src time stamp=0.994935,hop time stamp=1.77177,hop ip=10.0.0.8,bundle type=BundlePacket
#
# ============= dividing end of parse =============
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# warn_05:this may happen when one pkt scheduled but not successfully hoped
# =============
#  === print your schedule
# [[0, 12.021325669, 2, -1], [0, 117.981550363, 9, -1], [0, 94.020478268, 3, -1], [1, 0.806334457, 5, -1], [1, 50.676573125, 7, 2536], [1, 85.401015942, 8, -1], [2, 3.409505929, 5, -1], [2, 96.930379408, 7, -1], [2, 100.785055403, 7, -1], [3, 55.296858285, 2, -1], [3, 107.558250247, 5, -1], [3, 147.199292754, 6, -1], [4, 49.408970033, 6, -1], [4, 73.305762111, 6, -1], [4, 125.951311731, 8, -1], [5, 66.39254112, 8, -1], [5, 86.198989425, 7, -1], [5, 107.952914708, 8, -1], [6, 67.355142078, 5, -1], [6, 112.228687082, 5, -1], [6, 88.662378134, 3, -1], [7, 35.56773015, 5, -1], [7, 48.239575273, 1, 2414], [7, 151.540515515, 0, -1], [8, 66.928350315, 9, -1], [8, 80.856541053, 5, -1], [8, 149.828988053, 4, -1], [9, 67.409707327, 1, -1], [9, 71.512551808, 7, -1], [9, 151.043038945, 8, -1]]
# =============
#  === print your tosendbundle
# [[1, 0.806334, 5, 40], [2, 3.40951, 5, 171], [0, 12.0213, 2, 602], [7, 35.5677, 5, 1780], [7, 48.2396, 1, 2414], [4, 49.409, 6, 2475], [1, 50.6766, 7, 2536], [3, 55.2969, 2, 2767], [5, 66.3925, 8, 3328], [8, 66.9284, 9, 3352], [6, 67.3551, 5, 3376], [9, 67.4097, 1, 3381], [9, 71.5126, 7, 3584], [4, 73.3058, 6, 3674], [8, 80.8565, 5, 4054], [1, 85.401, 8, 4285], [5, 86.199, 7, 4326], [6, 88.6624, 3, 4447], [0, 94.0205, 3, 4718], [2, 96.9304, 7, 4863], [2, 100.785, 7, 5059], [3, 107.558, 5, 5397], [5, 107.953, 8, 5418], [6, 112.229, 5, 5633], [0, 117.982, 9, 5923], [4, 125.951, 8, 6321], [3, 147.199, 6, 7386], [8, 149.829, 4, 7517], [9, 151.043, 8, 7578], [7, 151.541, 0, 7604]]
# ==============
#  print your x_pkt_trace_map
# {2536: [[233.706, 7, 7, 1, 2536, 3.43193, 1.77177, 'BundlePacket', True, 1]], 2414: [[233.776, 1, 1, 7, 2414, 0.994935, 1.77177, 'BundlePacket', True, 7]]}
# key not exist-40
# key not exist-171
# key not exist-602
# key not exist-1780
# key exist
# key not exist-2475
# key exist
# key not exist-2767
# key not exist-3328
# key not exist-3352
# key not exist-3376
# key not exist-3381
# key not exist-3584
# key not exist-3674
# key not exist-4054
# key not exist-4285
# key not exist-4326
# key not exist-4447
# key not exist-4718
# key not exist-4863
# key not exist-5059
# key not exist-5397
# key not exist-5418
# key not exist-5633
# key not exist-5923
# key not exist-6321
# key not exist-7386
# key not exist-7517
# key not exist-7578
# key not exist-7604
# ===================================================================================================
# ===================== report parse result ================
# 2 / 30 arrived
# ==================
# pkt-seqno:40, trace is:
# received by node-1 at time-0.806334, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-1 to node-5 at time-0.806334
# ==================
# pkt-seqno:171, trace is:
# received by node-2 at time-3.40951, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-2 to node-5 at time-3.40951
# ==================
# pkt-seqno:602, trace is:
# received by node-0 at time-12.0213, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-0 to node-2 at time-12.0213
# ==================
# pkt-seqno:1780, trace is:
# received by node-7 at time-35.5677, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-7 to node-5 at time-35.5677
# ==================
# pkt-seqno:2414, trace is:
# from time-48.2396 => time-1.77177 in node-7
# received by node-1 at time-233.776 destination :)
# arrived destination
#
# schedule is: from node-7 to node-1 at time-48.2396
# ==================
# pkt-seqno:2475, trace is:
# received by node-4 at time-49.409, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-4 to node-6 at time-49.409
# ==================
# pkt-seqno:2536, trace is:
# from time-50.6766 => time-1.77177 in node-1
# received by node-7 at time-233.706 destination :)
# arrived destination
#
# schedule is: from node-1 to node-7 at time-50.6766
# ==================
# pkt-seqno:2767, trace is:
# received by node-3 at time-55.2969, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-3 to node-2 at time-55.2969
# ==================
# pkt-seqno:3328, trace is:
# received by node-5 at time-66.3925, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-5 to node-8 at time-66.3925
# ==================
# pkt-seqno:3352, trace is:
# received by node-8 at time-66.9284, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-8 to node-9 at time-66.9284
# ==================
# pkt-seqno:3376, trace is:
# received by node-6 at time-67.3551, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-6 to node-5 at time-67.3551
# ==================
# pkt-seqno:3381, trace is:
# received by node-9 at time-67.4097, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-9 to node-1 at time-67.4097
# ==================
# pkt-seqno:3584, trace is:
# received by node-9 at time-71.5126, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-9 to node-7 at time-71.5126
# ==================
# pkt-seqno:3674, trace is:
# received by node-4 at time-73.3058, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-4 to node-6 at time-73.3058
# ==================
# pkt-seqno:4054, trace is:
# received by node-8 at time-80.8565, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-8 to node-5 at time-80.8565
# ==================
# pkt-seqno:4285, trace is:
# received by node-1 at time-85.401, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-1 to node-8 at time-85.401
# ==================
# pkt-seqno:4326, trace is:
# received by node-5 at time-86.199, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-5 to node-7 at time-86.199
# ==================
# pkt-seqno:4447, trace is:
# received by node-6 at time-88.6624, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-6 to node-3 at time-88.6624
# ==================
# pkt-seqno:4718, trace is:
# received by node-0 at time-94.0205, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-0 to node-3 at time-94.0205
# ==================
# pkt-seqno:4863, trace is:
# received by node-2 at time-96.9304, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-2 to node-7 at time-96.9304
# ==================
# pkt-seqno:5059, trace is:
# received by node-2 at time-100.785, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-2 to node-7 at time-100.785
# ==================
# pkt-seqno:5397, trace is:
# received by node-3 at time-107.558, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-3 to node-5 at time-107.558
# ==================
# pkt-seqno:5418, trace is:
# received by node-5 at time-107.953, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-5 to node-8 at time-107.953
# ==================
# pkt-seqno:5633, trace is:
# received by node-6 at time-112.229, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-6 to node-5 at time-112.229
# ==================
# pkt-seqno:5923, trace is:
# received by node-0 at time-117.982, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-0 to node-9 at time-117.982
# ==================
# pkt-seqno:6321, trace is:
# received by node-4 at time-125.951, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-4 to node-8 at time-125.951
# ==================
# pkt-seqno:7386, trace is:
# received by node-3 at time-147.199, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-3 to node-6 at time-147.199
# ==================
# pkt-seqno:7517, trace is:
# received by node-8 at time-149.829, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-8 to node-4 at time-149.829
# ==================
# pkt-seqno:7578, trace is:
# received by node-9 at time-151.043, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-9 to node-8 at time-151.043
# ==================
# pkt-seqno:7604, trace is:
# received by node-7 at time-151.541, not destination :(
# this bundle may not be transmit out from source
# not arrived destination
#
# schedule is: from node-7 to node-0 at time-151.541
# {40: [0.806334, 1], 171: [3.40951, 2], 602: [12.0213, 0], 1780: [35.5677, 7], 2414: [48.2396, 7, 1.77177, 233.776, 1, 802.0], 2475: [49.409, 4], 2536: [50.6766, 1, 1.77177, 233.706, 7, 802.0], 2767: [55.2969, 3], 3328: [66.3925, 5], 3352: [66.9284, 8], 3376: [67.3551, 6], 3381: [67.4097, 9], 3584: [71.5126, 9], 3674: [73.3058, 4], 4054: [80.8565, 8], 4285: [85.401, 1], 4326: [86.199, 5], 4447: [88.6624, 6], 4718: [94.0205, 0], 4863: [96.9304, 2], 5059: [100.785, 2], 5397: [107.558, 3], 5418: [107.953, 5], 5633: [112.229, 6], 5923: [117.982, 0], 6321: [125.951, 4], 7386: [147.199, 3], 7517: [149.829, 8], 7578: [151.043, 9], 7604: [151.541, 7]}
# <img src="data:image/png;base64,..." width="640">
# colors count=30
# len of seqno_number_list=30
# range(0, 30)
